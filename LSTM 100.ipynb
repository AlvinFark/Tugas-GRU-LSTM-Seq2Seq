# %%
from collections import Counter

import nltk
import NMT_Model
import nmt_data_utils
import nmt_model_utils

# %%
with open('news-commentary-v8.de-en.en',
          'r',
          encoding = 'utf-8') as f:
    en = f.readlines()
    
with open('news-commentary-v8.de-en.de',
          'r',
          encoding = 'utf-8') as f:
    de = f.readlines()

# %%
# first 5 sentence pairs. 
for line in zip(en[:5], de[:5]):
    print(line, '\n')
# Out:
# ('SAN FRANCISCO – It has never been easy to have a rational conversation about the value of gold.\n', 'SAN FRANCISCO – Es war noch nie leicht, ein rationales Gespräch über den Wert von Gold zu führen.\n')
#
# ('Lately, with gold prices up more than 300% over the last decade, it is harder than ever.\n', 'In letzter Zeit allerdings ist dies schwieriger denn je, ist doch der Goldpreis im letzten Jahrzehnt um über 300 Prozent angestiegen.\n')
#
# ('Just last December, fellow economists Martin Feldstein and Nouriel Roubini each penned op-eds bravely questioning bullish market sentiment, sensibly pointing out gold’s risks.\n', 'Erst letzten Dezember verfassten meine Kollegen Martin Feldstein und Nouriel Roubini Kommentare, in denen sie mutig die vorherrschende optimistische Marktstimmung hinterfragten und sehr überlegt auf die Risiken des Goldes \xa0hinwiesen.\n')
#
# ('Wouldn’t you know it?\n', 'Und es kam, wie es kommen musste.\n')
#
# ('Since their articles appeared, the price of gold has moved up still further.\n', 'Seit der Veröffentlichung ihrer Artikel ist der Goldpreis noch weiter gestiegen.\n')

# %%
# remove unnecessary new lines. 
de = [line.strip() for line in de]
en = [line.strip() for line in en]

# %%
# we will only use sentences of similar lengths in order to make training easier. 
len_en = [len(sent) for sent in en if 20 < len(sent) < 50]
len_dist = Counter(len_en).most_common()
len_dist
# Out:
# [(49, 599),
#  (48, 599),
#  (46, 583),
#  (47, 547),
#  (43, 514),
#  (44, 512),
#  (45, 511),
#  (41, 509),
#  (40, 503),
#  (42, 490),
#  (39, 477),
#  (38, 443),
#  (37, 438),
#  (36, 421),
#  (34, 412),
#  (33, 365),
#  (32, 358),
#  (31, 353),
#  (35, 346),
#  (30, 326),
#  (28, 324),
#  (27, 273),
#  (25, 260),
#  (29, 254),
#  (26, 250),
#  (24, 233),
#  (23, 232),
#  (22, 214),
#  (21, 208)]

# %%
# 11554 sentences that contain betwenn 20 and 50 words.
len(len_en)
# Out:
# 11554

# %%
_de = []
_en = []
for sent_de, sent_en in zip(de, en):
    if 20 < len(sent_en) < 50:
        _de.append(sent_de)
        _en.append(sent_en)

# %%
# but we will not use all 150 000 sentences, only 5000 for the beginning.
text = _en[:2000]
language='english'
lower=True
words = []
tokenized_text = []

for line in text:
    tokenized = nltk.word_tokenize(line, language=language)
    if lower:
        tokenized = [word.lower() for word in tokenized]
    tokenized_text.append(tokenized)
    for word in tokenized:
        words.append(word)

most_common = Counter(words).most_common()
en_preprocessed = tokenized_text
en_most_common = most_common

text = _de[:2000]
language='german'
lower=True
words = []
tokenized_text = []

for line in text:
    tokenized = nltk.word_tokenize(line, language=language)
    if lower:
        tokenized = [word.lower() for word in tokenized]
    tokenized_text.append(tokenized)
    for word in tokenized:
        words.append(word)

most_common = Counter(words).most_common()
de_preprocessed = tokenized_text
de_most_common = most_common

en_preprocessed
# Out:
# [['wouldn', '’', 't', 'you', 'know', 'it', '?'],
#  ['since',
#   'then',
#   ',',
#   'the',
#   'index',
#   'has',
#   'climbed',
#   'above',
#   '10,000',
#   '.'],
#  ['they',
#   'departed',
#   'pledging',
#   'to',
#   'revive',
#   'europe',
#   "'s",
#   'growth',
#   '.'],
#  ['we', "'ve", 'heard', 'that', 'empty', 'promise', 'before', '.'],
#  ['many', 'europeans', 'are', 'sick', 'of', 'british', 'vetoes', '.'],
#  ['precedents', 'exist', 'for', 'this', '.'],
#  ['nato', 'has', 'been', 'flexible', 'since', 'its', 'inception', '.'],
#  ['these', 'precedents', 'can', 'be', 'extended', '.'],
#  ['i', 'am', 'not', 'talking', 'about', 'a', 'two‑speed', 'europe', '.'],
#  ['but', 'i', 'do', "n't", 'want', 'to', 'block', 'their', 'way', '.'],
#  ['elected', 'parliaments', 'do', 'not', 'own', 'our', 'liberties', '.'],
#  ['but', 'the', 'big', 'question', 'remains', ':', 'how', '?'],
#  ['the', 'need', 'for', 'immediate', 'action', 'is', 'clear', '.'],
#  ['the', 'new', 'year', 'is', 'looking', 'grim', '.'],
#  ['france', 'is', 'flat-lining', '(', 'as', 'is', 'britain', ')', '.'],
#  ['italy', 'and', 'spain', 'have', 'sunk', 'into', 'deep', 'recession', '.'],
#  ['greece', 'is', 'in', 'its', 'fifth', 'year', 'of', 'a', 'slump', '.'],
#  ['a', 'big', 'new', 'push', 'for', 'growth', 'is', 'therefore', 'vital', '.'],
#  ['boosting', 'exports', 'is', 'also', 'essential', '.'],
#  ['that', 'brings', 'us', 'to', 'fiscal', 'policy', '.'],
#  ['indeed', ',', 'such', 'hopes', 'were', 'misplaced', '.'],
#  ['in',
#   'fact',
#   ',',
#   'iraqi',
#   'society',
#   'is',
#   'more',
#   'complex',
#   'than',
#   'this',
#   '.'],
#  ['we',
#   'are',
#   'doing',
#   'our',
#   'part',
#   'in',
#   'terms',
#   'of',
#   'burden-sharing',
#   '.'],
#  ['sensible', 'europeans', 'understand', 'that', '.'],
#  ['to',
#   'be',
#   'sure',
#   ',',
#   'some',
#   'of',
#   'our',
#   'neighbors',
#   'are',
#   'difficult',
#   '.'],
#  ['progress', 'on', 'disinflation', 'is', 'similarly', 'impressive', '.'],
#  ['in', 'better', 'shape', ',', 'but', 'not', 'alone', '.'],
#  ['when',
#   'the',
#   'rich',
#   'get',
#   'less',
#   'rich',
#   ',',
#   'the',
#   'poor',
#   'get',
#   'poorer',
#   '.'],
#  ['it', 'all', 'came', 'about', 'in', 'a', 'number', 'of', 'ways', '.'],
#  ['then', 'i', 'got', 'distracted', 'for', 'about', '40', 'years', '.'],
#  ['not', 'all', 'are', 'happy', 'about', 'this', 'american', 'notion', '.'],
#  ['this', 'is', 'the', 'beginning', 'of', 'a', 'new', 'authoritarianism', '.'],
#  ['a', 'diffuse', 'anxiety', 'is', 'gaining', 'ground', '.'],
#  ['but', 'this', ',', 'of', 'course', ',', 'is', 'untrue', '.'],
#  ['could', 'the', 'answer', 'be', 'a', 'bit', 'of', 'both', '?'],
#  ['china', 'is', ';', 'you', 'are', 'not', '.', '”'],
#  ['what', 'do', 'you', 'want', 'back', '?'],
#  ['these', 'principles', 'are', 'clear', '.'],
#  ['in',
#   'the',
#   'short',
#   'term',
#   ',',
#   'time',
#   'may',
#   'be',
#   'on',
#   'russia',
#   '’',
#   's',
#   'side',
#   '.'],
#  ['both',
#   'figures',
#   'are',
#   ',',
#   'again',
#   ',',
#   'the',
#   'lowest',
#   'in',
#   'the',
#   'eu',
#   '.'],
#  ['but', 'the', 'agreement', 'has', 'three', 'major', 'flaws', '.'],
#  ['what', "'s", 'the', 'ordinary', 'european', 'to', 'think', '?'],
#  ['but', 'what', 'is', 'the', 'right', 'level', '?'],
#  ['much', 'the', 'same', 'is', 'true', 'in', 'europe', '.'],
#  ['so', '``', 'no', 'centralization', 'without', 'representation', '.', "''"],
#  ['activities',
#   'of',
#   'eu',
#   'institutions',
#   '(',
#   'percent',
#   'of',
#   'total',
#   ')'],
#  ['europe', 'faces', 'an', 'historic', 'opportunity', '.'],
#  ['but', 'this', 'scenario', 'failed', 'to', 'materialize', '.'],
#  ['this', 'means', 'two', 'things', '.'],
#  ['officially', ',', 'this', 'has', 'not', 'yet', 'been', 'acknowledged', '.'],
#  ['that', 'makes', 'everyone', 'less', 'safe', '.'],
#  ['now', 'the', 'key', 'is', 'to', 'make', 'this', 'effort', 'work', '.'],
#  ['the', 'lessons', 'of', 'history', 'are', 'clear', '.'],
#  ['he', 'was', 'then', 'told', 'to', 'identify', 'himself', '.'],
#  ['that', ',', 'too', ',', 'would', 'not', 'have', 'been', 'unusual', '.'],
#  ['class', 'and', 'race', 'overlap', 'in', 'the', 'us', '.'],
#  ['crowley',
#   'never',
#   'mentioned',
#   'the',
#   'color',
#   'of',
#   'gates',
#   '’',
#   'skin',
#   '.'],
#  ['it',
#   '’',
#   's',
#   '“',
#   'serious',
#   ',',
#   '”',
#   'the',
#   'smitten',
#   'president',
#   'admitted',
#   '.'],
#  ['(', 'sarkozy', 'is', 'now', 'twice', 'divorced', '.', ')'],
#  ['sarkozy', 'could', 'make', 'that', 'dream', 'come', 'true', '.'],
#  ['we', 'already', 'know', 'this', '.'],
#  ['iran', 'is', 'the', 'most', 'current', 'example', 'of', 'this', '.'],
#  ['honni', 'soit', 'qui', 'mal', 'y', 'pense', '!'],
#  ['the', 'cap', 'must', 'be', 'born', 'again', '.'],
#  ['but', 'a', 'much', 'more', 'profound', 're-think', 'is', 'needed', '.'],
#  ['but', 'that', 'attitude', 'is', 'undermining', 'change', '.'],
#  ['this', 'argument', 'is', 'both', 'disingenuous', 'and', 'dishonest', '.'],
#  ['there', 'is', 'a', 'deeper', 'issue', 'at', 'stake', '.'],
#  ['with', 'donor', 'help', ',', 'they', 'can', '.'],
#  ['the', 'current', 'aid', 'structures', 'are', 'inadequate', '.'],
#  ['the', 'time', 'for', 'business', 'as', 'usual', 'is', 'over', '.'],
#  ['meanwhile',
#   ',',
#   'a',
#   'billion',
#   'people',
#   'go',
#   'hungry',
#   'each',
#   'day',
#   '.'],
#  ['it', 'doesn', '’', 't', 'have', 'to', 'be', 'this', 'way', '.'],
#  ['on', 'the', 'contrary', ',', 'everything', 'becomes', 'brighter', '.'],
#  ['this', 'claim', 'was', 'hugely', 'misguided', '.'],
#  ['perhaps', 'they', 'are', 'right', '.'],
#  ['these', 'are', 'all', 'very', 'important', 'issues', '.'],
#  ['but', 'the', 'mere', 'figures', 'are', 'simply', 'not', 'enough', '.'],
#  ['such', 'a', 'basis', 'is', 'not', 'hard', 'to', 'find', '.'],
#  ['the', 'climate', 'problem', 'does', 'not', 'stop', 'at', 'borders', '.'],
#  ['i',
#   'suspect',
#   'that',
#   'many',
#   'will',
#   'agree',
#   'with',
#   'this',
#   'view',
#   '.'],
#  ['these', 'are', ',', 'of', 'course', ',', 'hypothetical', 'questions', '.'],
#  ['we', 'don', '’', 't', 'yet', 'know', 'what', 'is', 'possible', '.'],
#  ['and',
#   'what',
#   'does',
#   'it',
#   'say',
#   'about',
#   'us',
#   'if',
#   'we',
#   'won',
#   '’',
#   't',
#   '?'],
#  ['yet',
#   'their',
#   'regime',
#   'is',
#   'in',
#   'crisis',
#   ',',
#   'and',
#   'they',
#   'know',
#   'it',
#   '.'],
#  ['military', 'reform', 'has', 'been', 'reversed', '.'],
#  ['the',
#   'country',
#   'is',
#   'unruly',
#   ',',
#   'and',
#   'its',
#   'rulers',
#   'know',
#   'it',
#   '.'],
#  ['they', 'have', 'also', 'become', 'disobedient', '.'],
#  ['cherkesov', '’', 's', 'deputy', 'remains', 'in', 'prison', '.'],
#  ['cherkesov',
#   '’',
#   's',
#   'case',
#   'exemplifies',
#   'putin',
#   '’',
#   's',
#   'nightmare',
#   '.'],
#  ['this', 'is', 'putin', '’', 's', 'plan', '.'],
#  ['it', 'is', 'a', 'bizarre', 'ideology', '.'],
#  ['the', 'answer', 'is', ':', 'very', 'poor', '.'],
#  ['israel',
#   '’',
#   's',
#   'main',
#   'concern',
#   'continues',
#   'to',
#   'be',
#   'security',
#   '.'],
#  ['netanyahu', '’', 's', 'project', 'is', 'not', 'moral', '.'],
#  ['time', 'is', 'running', 'out', 'in', 'kosovo', '.'],
#  ['that', 'would', 'be', 'a', 'disastrous', 'step', '.'],
#  ['serbia', 'is', 'even', 'more', 'strongly', 'opposed', '.'],
#  ['i', 'learned', 'this', 'by', 'accident', '.'],
#  ['there', 'are', 'some', 'major', 'themes', '.'],
#  ['hence', 'their', 'impulse', 'to', 'believe', 'in', 'unseen', 'forces', '.'],
#  ['today',
#   ',',
#   'kuchma',
#   'rules',
#   'as',
#   'an',
#   'all-powerful',
#   'president',
#   '.'],
#  ['sopuissant', 'a', 'caesar', 'must', 'be', 'above', 'reproach', '.'],
#  ['as', 'president', ',', 'kuchma', 'is', 'grotesquely', 'unpopular', '.'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'stimulus',
#   'itself',
#   'is',
#   'contractionary',
#   '.'],
#  ['we',
#   'have',
#   'but',
#   'one',
#   'planet',
#   ',',
#   'and',
#   'should',
#   'treasure',
#   'it',
#   '.'],
#  ['public', 'debt', 'continued', 'to', 'grow', '.'],
#  ['the', 'advanced', 'countries', 'have', 'a', 'choice', '.'],
#  ['so', 'falling', 'trust', 'had', 'real', 'economic', 'consequences', '.'],
#  ['this', 'has', 'been', 'positive', 'for', 'the', 'stock', 'market', '.'],
#  ['others', 'are', 'congenitally', 'distrustful', '.'],
#  ['what', 'will', 'reverse', 'it', '?'],
#  ['economists', 'did', 'not', 'predict', 'that', 'event', ',', 'either', '.'],
#  ['but', 'the', 'book', 'is', 'almost', 'entirely', 'non-theoretical', '.'],
#  ['it', 'merely', 'documents', 'recurrent', 'patterns', '.'],
#  ['there', 'is', 'a', 'no', 'easy', 'way', 'out', '.'],
#  ['it', 'is', 'high', 'time', 'to', 'consider', 'novel', 'approaches', '.'],
#  ['this', 'will', 'take', 'some', 'time', 'to', 'implement', '.'],
#  ['they', 'should', 'be', 'unified', 'throughout', 'the', 'region', '.'],
#  ['participation', 'by', 'romania', 'and', 'moldova', 'is', 'optional', '.'],
#  ['but', 'that', 'process', 'has', 'a', 'long', 'way', 'to', 'go', '.'],
#  ['october', '24', 'is', '350', 'day', '.'],
#  ['the', 'melting', 'of', 'arctic', 'ice', 'is', 'one', 'example', '.'],
#  ['other', 'feedback', 'loops', 'pose', 'a', 'similar', 'danger', '.'],
#  ['there', 'is', 'yet', 'another', 'lesson', 'to', 'be', 'learned', '.'],
#  ['all', 'this', 'is', 'perfectly', 'true', '.'],
#  ['will', 'this', 'spell', 'doom', 'for', 'developing', 'countries', '?'],
#  ['first', 'comes', 'growth', 'driven', 'by', 'foreign', 'borrowing', '.'],
#  ['china', 'exemplified', 'this', 'approach', '.'],
#  ['but', 'it', 'wasn', '’', 't', 'just', 'china', '.'],
#  ['it', 'did', 'so', 'with', 'democracy', 'and', 'freedom', '.'],
#  ['american', 'foreign', 'policy', 'reflects', 'that', 'obsession', '.'],
#  ['yet', 'malaria', 'is', 'preventable', 'and', 'treatable', '.'],
#  ['it', 'has', 'so', 'far', 'failed', 'to', 'act', '.'],
#  ['the', 'list', 'goes', 'on', 'and', 'on', '.'],
#  ['but', 'a', 'euro', 'exit', 'would', 'be', 'a', 'messy', 'affair', '.'],
#  ['this',
#   'policy',
#   'can',
#   'also',
#   'help',
#   'on',
#   'the',
#   'fiscal',
#   'front',
#   '.'],
#  ['the', 'same', 'is', 'true', 'of', 'minimum', 'wages', '.'],
#  ['fiscal', 'devaluations', 'already', 'have', 'some', 'advocates', '.'],
#  ['or',
#   'they',
#   'believe',
#   'that',
#   'their',
#   'light',
#   'is',
#   '“',
#   'funny',
#   '.',
#   '”'],
#  ['who', 'decides', 'when', 'something', 'is', 'luxurious', '?'],
#  ['and', 'where', 'does', 'this', 'end', '?'],
#  ['this',
#   'is',
#   'where',
#   'a',
#   'lot',
#   'of',
#   'policymakers',
#   'get',
#   'it',
#   'wrong',
#   '.'],
#  ['can', 'the', 'situation', 'get', 'worse', '?'],
#  ['yes', ',', 'it', 'can', ':', 'much', 'worse', '.'],
#  ['america', "'s", 'appallingly', 'low', 'savings', 'rate', '.'],
#  ['lax', 'accounting', 'standards', '.'],
#  ['here', "'s", 'a', 'plausible', 'scenario', '.'],
#  ['but', 'america', 'today', 'appears', 'less', 'safe', '.'],
#  ['they',
#   "'re",
#   'free',
#   'to',
#   'choose',
#   'where',
#   'to',
#   'put',
#   'their',
#   'money',
#   '.'],
#  ['i', 'am', 'not', 'predicting', 'that', 'this', 'will', 'happen', '.'],
#  ['how', 'is', 'the', 'wassenaar', 'model', 'relevant', 'to', 'brazil', '?'],
#  ['czechoslovakia', 'split', 'into', 'two', 'separate', 'states', '.'],
#  ['none', 'of', 'this', 'holds', 'true', 'today', '.'],
#  ['could', 'any', 'common', 'european', 'state', 'do', 'worse', '?'],
#  ['so', 'they', 'elected', 'one', 'as', 'president', '.'],
#  ['but',
#   'such',
#   'a',
#   'dynamic',
#   'does',
#   'now',
#   'seem',
#   'to',
#   'be',
#   'in',
#   'motion',
#   '.'],
#  ['but', 'how', 'will', 'sarajevo', 'look', 'in', 'five', 'years', '?'],
#  ['the', 'future', 'promises', 'peace', 'without', 'development', '.'],
#  ['but', 'it', 'is', 'now', 'or', 'never', 'for', 'the', 'balkans', '.'],
#  ['the', 'reason', 'is', 'simple', '.'],
#  ['that', 'is', 'the', 'risk', 'today', '.'],
#  ['the', 'soft', 'patch', 'may', 'be', 'closer', 'to', 'a', 'quagmire', '.'],
#  ['that', 'is', 'certainly', 'true', 'of', 'the', 'united', 'states', '.'],
#  ['the', 'odds', 'on', 'either', 'are', 'exceedingly', 'poor', '.'],
#  ['this', 'is', 'because', 'cyprus', 'remains', 'a', 'divided', 'island', '.'],
#  ['but', 'they', 'are', 'reacting', 'to', 'the', 'current', 'situation', '.'],
#  ['fifteen',
#   'years',
#   'later',
#   ',',
#   'no',
#   'country',
#   'has',
#   'done',
#   'that',
#   '.'],
#  ['are', 'china', 'and', 'india', 'being', 'unreasonable', '?'],
#  ['that', 'catastrophe', 'must', 'be', 'forestalled', '.'],
#  ['reykjavik', 'proved', 'that', 'boldness', 'is', 'rewarded', '.'],
#  ['our', 'world', 'remains', 'too', 'militarized', '.'],
#  ['many', 'denounced', 'sharon', "'s", 'plan', 'as', 'a', 'trick', '.'],
#  ['then', 'there', 'are', 'the', 'strategic', 'hawks', '.'],
#  ['he', 'has', 'brought', 'neither', '.'],
#  ['then', 'we', 'squabble', 'about', 'what', 'to', 'do', '.'],
#  ['the', 'time', 'for', 'such', 'laxity', 'is', 'over', '.'],
#  ['that', 'consensus', 'must', 'include', 'the', 'us', '.'],
#  ['intentions', 'do', "n't", 'deter', 'invasions', '.'],
#  ['prevent', 'local', 'conflict', ';'],
#  ['promote', 'human', 'rights', 'and', 'democracy', ';'],
#  ['the', 'impressive', 'gains', 'don', '’', 't', 'stop', 'there', '.'],
#  ['so', 'what', 'is', 'not', 'to', 'like', '?'],
#  ['how', ',', 'you', 'might', 'ask', ',', 'can', 'i', 'say', 'this', '?'],
#  ['but', 'there', 'are', 'two', 'things', 'different', 'about', 'today', '.'],
#  ['second', ',', 'bond', 'investors', 'are', 'being', 'really', 'stupid', '.'],
#  ['they',
#   'are',
#   'willing',
#   'to',
#   'pay',
#   '6',
#   '%',
#   'per',
#   'year',
#   'for',
#   '“',
#   'safety',
#   '.',
#   '”'],
#  ['thus', ',', 'royal', '’', 's', 'program', 'is', 'her', 'popularity', '.'],
#  ['then', 'there', 'are', 'strategic', 'suspicions', '.'],
#  ['does', 'the', 'european', 'union', 'care', '?'],
#  ['the', 'crucial', 'issue', 'is', 'market', 'access', '.'],
#  ['the', 'european', 'commission', 'understands', 'this', '.'],
#  ['herbivorous', 'fish', 'are', 'key', 'players', 'on', 'coral', 'reefs', '.'],
#  ['two',
#   'things',
#   'can',
#   'be',
#   'done',
#   'to',
#   'protect',
#   'coral',
#   'reefs',
#   '.'],
#  ['roughly', '95', '%', 'of', 'our', 'agriculture', 'is', 'hi-tech', '.'],
#  ['what',
#   'israel',
#   'can',
#   'do',
#   ',',
#   'others',
#   'can',
#   'do',
#   'as',
#   'well',
#   '.'],
#  ['nothing', 'could', 'be', 'more', 'incorrect', '.'],
#  ['then', 'france', 'embraced', 'germany', '.'],
#  ['usually', 'france', 'likes', 'to', 'keep', 'its', 'options', 'open', '.'],
#  ['this', 'has', 'obviously', 'caused', 'frustrations', '.'],
#  ['but',
#   'it',
#   'should',
#   'not',
#   'have',
#   'been',
#   'a',
#   'surprise',
#   'to',
#   'anyone',
#   '.'],
#  ['chirac',
#   'and',
#   'schröder',
#   'do',
#   'not',
#   'seem',
#   'to',
#   'grasp',
#   'this',
#   '.'],
#  ['instructors', 'from', 'abroad', 'can', 'not', 'enter', 'gaza', '.'],
#  ['life', 'in', 'gaza', 'has', 'bled', 'away', 'my', 'optimism', '.'],
#  ['my', 'mother', 'is', 'a', 'housekeeper', '.'],
#  ['i', 'have', 'six', 'brothers', 'and', 'three', 'sisters', '.'],
#  ['that', 'was', 'at', 'the', 'height', 'of', 'the', 'peace', 'process', '.'],
#  ['but',
#   'when',
#   'i',
#   'was',
#   'ten',
#   ',',
#   'the',
#   'secondintifada',
#   'began',
#   '.'],
#  ['sometimes',
#   ',',
#   'i',
#   'am',
#   'sorry',
#   'that',
#   'i',
#   'am',
#   'from',
#   'gaza',
#   '.'],
#  ['we', 'are', 'students', ',', 'not', 'soldiers', '.'],
#  ['we', 'are', 'not', 'fighters', 'in', 'this', 'conflict', '.'],
#  ['why', 'doesn', '’', 't', 'israel', 'let', 'us', 'go', 'study', '?'],
#  ['educated',
#   ',',
#   'pushy',
#   'mothers',
#   'make',
#   'all',
#   'the',
#   'difference',
#   '.'],
#  ['but', 'the', 'boom', 'is', 'not', 'uniform', '.'],
#  ['we', 'know', 'how', 'to', 'do', 'this', '.'],
#  ['in',
#   'the',
#   'middle',
#   'east',
#   ',',
#   'we',
#   'must',
#   'break',
#   'the',
#   'stalemate',
#   '.'],
#  ['palestinians', 'deserve', 'a', 'state', '.'],
#  ['israel', 'needs', 'security', '.'],
#  ['syria', 'is', 'a', 'special', 'concern', '.'],
#  ['the', 'moment', 'to', 'act', 'is', 'now', '.'],
#  ['the', 'violence', 'must', 'stop', '.'],
#  ['let', 'our', 'common', 'agenda', 'begin', '.'],
#  ['batten', 'down', 'the', 'hatches', '.'],
#  ['each', 'of', 'us', 'senses', 'this', 'challenge', 'almost', 'daily', '.'],
#  ['but', 'time', 'is', 'running', 'very', 'short', '.'],
#  ['now', 'the', 'corporate', 'sector', 'has', 'two', 'faces', '.'],
#  ['two', 'wrongs', 'don', '’', 't', 'make', 'a', 'right', '.'],
#  ['more',
#   'than',
#   'the',
#   'usual',
#   '“',
#   'blame',
#   'game',
#   '”',
#   'is',
#   'at',
#   'work',
#   'here',
#   '.'],
#  ['only', 'consumption', 'is', 'lagging', '.'],
#  ['how',
#   'will',
#   'the',
#   'ecb',
#   'react',
#   'to',
#   'better',
#   'economic',
#   'news',
#   '?'],
#  ['this', 'raises', 'an', 'interesting', 'point', '.'],
#  ['let',
#   '’',
#   's',
#   'begin',
#   'with',
#   'why',
#   'the',
#   'euro',
#   'needs',
#   'to',
#   'fall',
#   '.'],
#  ['the', 'first', 'concerns', 'the', 'market', 'response', '.'],
#  ['yet', 'koizumi', 'remains', 'defiant', '.'],
#  ['bilateral', 'relations', 'were', 'frozen', '.'],
#  ['admittedly', ',', 'sometimes', 'time', 'is', 'a', 'luxury', '.'],
#  ['figures', 'for', 'the', 'ictr', 'are', 'only', 'slightly', 'better', '.'],
#  ['but', 'such', 'agreement', 'is', 'extraordinary', '.'],
#  ['alas', ',', 'the', 'revolution', 'soon', 'bogged', 'down', '.'],
#  ['they', 'will', 'most', 'likely', 'succeed', '.'],
#  ['the', 'diet', '’', 's', 'role', 'was', 'merely', 'pro', 'forma', '.'],
#  ['so', 'the', 'lesson', 'from', 'the', 'recession', 'is', 'clear', '.'],
#  ['opportunism',
#   'has',
#   'had',
#   'its',
#   'share',
#   'in',
#   'this',
#   ',',
#   'of',
#   'course',
#   '.'],
#  ['moreover', ',', 'kundera', '’', 's', 'case', 'is', 'hardly', 'unique', '.'],
#  ['this', 'is', 'not', 'only', 'dangerous', ',', 'but', 'incoherent', '.'],
#  ['finally', ',', 'the', 'idea', 'is', 'impracticable', '.'],
#  ['this', 'is', 'the', 'thrust', 'of', 'mccain', '’', 's', 'message', '.'],
#  ['this', 'is', 'crazy', 'and', 'unhistorical', '.'],
#  ['to', 'see', 'why', ',', 'consider', 'nigeria', '.'],
#  ['it', 'was', 'also', 'a', 'matter', 'of', 'national', 'pride', '.'],
#  ['but', 'that', 'did', 'not', 'happen', '.'],
#  ['only', 'the', 'ecb', 'can', 'provide', 'this', 'insurance', '.'],
#  ['it', 'now', 'needs', 'to', 'be', 'implemented', '.'],
#  ['spanish', 'borrowing', 'costs', 'are', 'also', 'rising', '.'],
#  ['greece', 'is', 'clearly', 'insolvent', '.'],
#  ['this', 'can', 'happen', 'in', 'a', 'number', 'of', 'ways', '.'],
#  ['then', ',', 'there', 'is', 'the', 'issue', 'of', 'trust', '.'],
#  ['are', 'we', 'going', 'to', 'be', 'in', 'a', 'war', '?'],
#  ['on',
#   'a',
#   'third',
#   'issue',
#   ',',
#   'the',
#   'results',
#   'so',
#   'far',
#   'are',
#   'mixed',
#   '.'],
#  ['over-diagnosis', 'of', 'bipolar', 'disorder', 'has', 'costs', '.'],
#  ['we',
#   'have',
#   'seen',
#   'evidence',
#   'of',
#   'this',
#   'in',
#   'our',
#   'practice',
#   '.'],
#  ['the', 'idea', 'is', 'compelling', '.'],
#  ['but', 'the', 'ipo', 'soon', 'sunk', 'miserably', '.'],
#  ['could', 'the', 'opposite', 'happen', '?'],
#  ['actual', 'imf', 'equilibrium', 'rate'],
#  ['dollar/euro', '(', '$', '/_', ')', '0.88', '1.26'],
#  ['yen/euro', '(', '-/_', ')', '93.1', '113.3'],
#  ['they', 'keep', 'the', 'world', 'growing', '!'],
#  ['yes', ',', 'the', 'euro', 'can', 'tend', 'toward', 'dollar', 'parity', '.'],
#  ['it', 'has', 'no', 'chance', 'to', 'shine', '.'],
#  ['now', 'they', 'are', 'a', 'global', 'obsession', '.'],
#  ['noodles', 'are', 'beating', 'spaghetti', '.'],
#  ['some', 'of', 'this', 'is', 'unsurprising', '.'],
#  ['that', 'is', 'far', 'harder', 'to', 'judge', '.'],
#  ['this', 'is', 'risky', 'speculation', '.'],
#  ['white', 'balloons', 'were', 'launched', 'everywhere', '.'],
#  ['it', 'is', 'perhaps', 'a', 'beginning', '.'],
#  ['first', ',', 'heavy', 'tv', 'viewing', 'brings', 'little', 'pleasure', '.'],
#  ['the',
#   'same',
#   ',',
#   'of',
#   'course',
#   ',',
#   'has',
#   'happened',
#   'to',
#   'politics',
#   '.'],
#  ['even',
#   'war',
#   'can',
#   'be',
#   'rolled',
#   'out',
#   'as',
#   'a',
#   'new',
#   'product',
#   '.'],
#  ['at',
#   'the',
#   'very',
#   'least',
#   ',',
#   'we',
#   'can',
#   'minimize',
#   'those',
#   'dangers',
#   '.'],
#  ['of', 'course', ',', 'the', 'alternative', 'is', 'no', 'safer', '.'],
#  ['everyone',
#   'agrees',
#   'that',
#   'iran',
#   'has',
#   'the',
#   'right',
#   'to',
#   'do',
#   'so',
#   '.'],
#  ['these', 'are', 'violent', 'times', '.'],
#  ['ruthless', 'leaders', 'mobilize', 'disoriented', 'followers', '.'],
#  ['it', 'has', 'to', 'do', 'with', 'israel', '.'],
#  ['it', 'is', 'linked', 'to', 'israel', '.'],
#  ['this', 'might', 'be', 'done', 'in', 'several', 'ways', '.'],
#  ['but', 'it', 'is', 'not', 'monolithic', '.'],
#  ['such', 'policies', 'might', 'include', ':'],
#  ['its', 'interventionist', 'measures', 'won', '’', 't', 'work', '.'],
#  ['there',
#   'is',
#   'no',
#   'time',
#   'to',
#   'lose',
#   'in',
#   'trying',
#   'something',
#   'new',
#   '.'],
#  ['food', 'riots', 'are', 'mounting', '.'],
#  ['the', 'idea', 'is', 'basic', 'and', 'well', 'known', '.'],
#  ['other', 'low-income', 'countries', 'should', 'follow', 'suit', '.'],
#  ['at', 'bottom', ',', 'the', 'problem', 'is', 'one', 'of', 'legitimacy', '.'],
#  ['good', 'feelings', 'abound', '.'],
#  ['russia',
#   'will',
#   'hold',
#   'a',
#   'presidential',
#   'election',
#   'in',
#   '2012',
#   '.'],
#  ['the', 'president', '’', 's', 'statement', 'was', 'unexpected', '.'],
#  ['society', 'will', 'support', 'him', '.'],
#  ['the', 'standard', 'of', 'living', 'was', 'low', '.'],
#  ['this', 'is', 'one', 'unclaimed', 'opportunity', '.'],
#  ['the', 'us', 'has', 'made', 'profound', 'missteps', 'recently', '.'],
#  ['why', 'are', 'these', 'new', 'bodies', 'needed', '?'],
#  ['far', 'more', 'needs', 'to', 'be', 'done', '.'],
#  ['it', 'is', 'cheap', 'because', 'it', 'is', 'plentiful', '.'],
#  ['it', 'is', 'time', 'to', 'embrace', 'them', '.'],
#  ['after', 'all', ',', 'today', '’', 's', 'models', 'work', '.'],
#  ['consider', 'the', 'brain', ',', 'for', 'example', '.'],
#  ['independent', 'thinking', 'is', 'an', 'underestimated', 'factor', '.'],
#  ['or', 'if', 'you', 'wish', ',', 'discovered', '.'],
#  ['the', 'main', 'problems', 'are', 'easily', 'identified', '.'],
#  ['these', 'issues', 'will', 'not', 'be', 'resolved', 'overnight', '.'],
#  ['leu', 'can', 'not', 'be', 'used', 'to', 'make', 'weapons', '.'],
#  ['but', 'this', 'can', 'only', 'be', 'a', 'first', 'step', '.'],
#  ['but',
#   'the',
#   'us',
#   'should',
#   'not',
#   'succumb',
#   'to',
#   'this',
#   'temptation',
#   '.'],
#  ['in',
#   'fact',
#   ',',
#   'democracy',
#   'is',
#   'in',
#   'deep',
#   'trouble',
#   'in',
#   'america',
#   '.'],
#  ['obama', 'has', 'the', 'right', 'vision', '.'],
#  ['in', '2005', ',', 'we', 'can', 'begin', 'to', 'change', 'direction', '.'],
#  ['what', 'we', 'learned', 'is', 'easily', 'summarized', '.'],
#  ['therein', 'lies', 'the', 'path', 'to', 'sustained', 'peace', '.'],
#  ['or', 'will', 'it', 'be', '“', 'excellent', 'in', 'parts', '”', '?'],
#  ['the', 'probable', 'answer', 'is', ':', 'both', '.'],
#  ['the', 'situation', 'in', 'libya', 'today', 'is', 'not', 'identical', '.'],
#  ['but', 'qaddafi', 'is', 'shrewd', '.'],
#  ['we', 'can', 'not', 'wait', 'for', 'that', 'to', 'happen', '.'],
#  ['china', 'and', 'russia', 'have', 'expressed', 'reservations', '.'],
#  ['on', 'that', 'front', ',', 'there', 'are', 'promising', 'signs', '.'],
#  ['the', 'arab', 'league', 'has', 'endorsed', 'a', 'similar', 'proposal', '.'],
#  ['fresh', 'water', 'is', 'one', 'such', 'area', '.'],
#  ['water', 'flows', 'on', 'the', 'surface', 'and', 'underground', '.'],
#  ['moreover', ',', 'demand', 'for', 'water', 'changes', 'over', 'time', '.'],
#  ['these', 'are', 'eminently', 'negotiable', 'issues', '.'],
#  ['everything', 'else', 'can', 'be', 'worked', 'out', '.'],
#  ['water', 'is', 'the', 'essence', 'of', 'life', '.'],
#  ['cooperating',
#   'to',
#   'secure',
#   'it',
#   'is',
#   'the',
#   'only',
#   'way',
#   'forward',
#   '.'],
#  ['last',
#   'year',
#   ',',
#   'there',
#   'were',
#   'two',
#   'sides',
#   'to',
#   'the',
#   'debate',
#   '.'],
#  ['if',
#   'so',
#   ',',
#   'a',
#   'correction',
#   'can',
#   'not',
#   'be',
#   'too',
#   'far',
#   'behind',
#   '.'],
#  ['this', 'idea', 'has', 'logic', 'behind', 'it', '.'],
#  ['yet', 'no', 'live', 'apes', 'were', 'used', '.'],
#  ['but', 'he', 'also', 'understood', 'the', 'ethical', 'issue', '.'],
#  ['that', '’', 's', 'exploitative', '.', '”'],
#  ['this', 'divergence', 'is', 'mirrored', 'in', 'public', 'finances', '.'],
#  ['adjustments', 'will', 'need', 'to', 'be', 'made', '.'],
#  ['but', 'even', 'there', ',', 'risks', 'lurk', '.'],
#  ['so', 'security', 'vigilance', 'is', 'essential', '.'],
#  ['so',
#   'where',
#   'are',
#   'the',
#   'calls',
#   'for',
#   'woodward',
#   '’',
#   's',
#   'arrest',
#   '?'],
#  ['the', 'associated', 'press', 'refuses', 'to', 'comment', 'on', 'him', '.'],
#  ['but', 'that', 'mission', 'now', 'seems', 'lost', 'in', 'america', '.'],
#  ['in', '2003', ',', 'it', 'was', 'sars', '.'],
#  ['there',
#   'are',
#   'more',
#   'bacteria',
#   'than',
#   'any',
#   'other',
#   'life',
#   'form',
#   '.'],
#  ['prions', 'are', 'a', 'relatively', 'new', 'discovery', '.'],
#  ['in', 'practical', 'terms', ',', 'how', 'should', 'it', 'be', 'built', '?'],
#  ['this', 'is', 'not', 'as', 'difficult', 'as', 'it', 'sounds', '.'],
#  ['the', 'key', 'is', 'to', 'harness', 'existing', 'infrastructure', '.'],
#  ['can', 'a', 'public', 'figure', 'have', 'a', 'private', 'life', '?'],
#  ['growth', ',', 'indeed', ',', 'is', 'accelerating', '.'],
#  ['this', 'year', 'it', 'will', 'be', 'nearly', 'eliminated', '.'],
#  ['the', 'last', 'real', 'worry', 'was', 'the', 'foreign', 'balance', '.'],
#  ['we', 'have', 'been', 'here', 'before', '.'],
#  ['developed', 'countries', 'did', 'not', 'learn', '.'],
#  ['that', 'has', 'not', 'happened', '.'],
#  ['but', 'there', 'is', 'a', 'wider', 'lesson', '.'],
#  ['and', 'yet', 'that', 'could', 'very', 'well', 'happen', '.'],
#  ['this', 'can', 'be', 'achieved', '.'],
#  ['the', 'same', 'should', 'apply', 'to', 'turkey', '.'],
#  ['why', 'not', 'in', 'iraqi', 'kurdistan', '?'],
#  ['today', ',', 'both', 'factors', 'have', 'changed', '.'],
#  ['the', 'perception', 'of', 'military', 'parity', 'has', 'altered', '.'],
#  ['this', 'is', 'turkey', '’', 's', 'moment', 'of', 'truth', '.'],
#  ['but', 'the', 'situation', 'is', 'not', 'irretrievable', '.'],
#  ['yet', 'they', 'have', 'not', 'saved', 'us', '.'],
#  ['is', 'there', 'a', 'different', 'way', '?'],
#  ['do',
#   'we',
#   'want',
#   'to',
#   'save',
#   'ourselves',
#   'and',
#   'our',
#   'children',
#   '?'],
#  ['why', 'didn', '’', 't', 'we', 'say', 'so', '?'],
#  ['the', 'world', 'is', 'poised', 'to', 'act', '.'],
#  ['the', 'extremist', 'positions', 'are', 'clear', '.'],
#  ['no', 'land-for-peace', 'deal', 'will', 'satisfy', 'either', 'side', '.'],
#  ['the', 'moderates', 'are', 'understandably', 'wary', '.'],
#  ['but', 'this', 'largely', 'ignored', 'the', 'role', 'of', 'extremists', '.'],
#  ['that', 'dynamic', 'is', 'still', 'at', 'work', '.'],
#  ['the',
#   'roadmap',
#   'is',
#   '--',
#   'so',
#   'far',
#   '--',
#   'silent',
#   'on',
#   'this',
#   'issue',
#   '.'],
#  ['but', 'moderates', 'raised', 'red', 'flags', ',', 'too', '.'],
#  ['the', 'kanjorski', 'amendment', 'is', 'a', 'very', 'big', 'stick', '.'],
#  ['but',
#   'the',
#   'army',
#   'as',
#   'a',
#   'whole',
#   'is',
#   'not',
#   'anti-democratic',
#   '.'],
#  ['paris', '–', 'russia', 'is', 'not', 'egypt', '.'],
#  ['and', 'not', 'all', 'russians', 'are', 'in', 'the', 'streets', '.'],
#  ['that', 'applies', 'to', 'russia', ',', 'too', '.'],
#  ['but', 'this', 'comparison', 'has', 'limits', '.'],
#  ['it', 'is', 'past', 'time', 'to', 'move', 'forward', '.'],
#  ['others',
#   'returned',
#   'home',
#   'and',
#   'were',
#   'welcomed',
#   'as',
#   'heroes',
#   '.'],
#  ['we', 'saudis', 'have', 'failed', 'to', 'do', 'the', 'same', '.'],
#  ['educated', 'hijazis', 'ask', 'only', 'for', 'modest', 'reforms', '.'],
#  ['yet', 'even', 'moderation', 'is', 'dismissed', 'by', 'the', 'al-saud', '.'],
#  ['inclusion', 'is', 'the', 'less', 'dangerous', 'path', '.'],
#  ['those', 'risks', 'will', 'not', 'go', 'away', '.'],
#  ['the', 'big', 'one', 'will', 'one', 'day', 'strike', 'california', '.'],
#  ['the', 'concept', 'is', 'simple', '.'],
#  ['(', 'cancer-preventing', 'tomatoes', ',', 'take', 'notice', '.', ')'],
#  ['but', 'none', 'of', 'this', 'can', 'be', 'relied', 'upon', '.'],
#  ['so', ',', 'what', 'needs', 'to', 'be', 'done', '?'],
#  ['first', ',', 'eurozone', 'banks', 'have', 'to', 'be', 'recapitalized', '.'],
#  ['but', 'we', 'are', 'where', 'we', 'are', '.'],
#  ['this', 'is', 'a', 'recipe', 'for', 'trouble', '.'],
#  ['the', 'world', 'has', 'a', 'stake', 'in', 'their', 'resolution', '.'],
#  ['unresolved', ',', 'the', 'crisis', 'will', 'spare', 'no', 'one', '.'],
#  ['there',
#   'have',
#   'been',
#   'few',
#   'convictions',
#   'for',
#   'these',
#   'crimes',
#   '.'],
#  ['so', 'other', 'policies', 'are', 'needed', 'to', 'restore', 'growth', '.'],
#  ['it', 'seems', 'the', 'story', 'never', 'ends', '.'],
#  ['they', 'are', 'also', 'facing', 'huge', 'uncertainties', '.'],
#  ['that', 'is', 'largely', 'the', 'job', 'of', 'government', '.'],
#  ['the',
#   'us',
#   'is',
#   'not',
#   'the',
#   'only',
#   'economy',
#   'in',
#   'this',
#   'equation',
#   '.'],
#  ['this', 'will', 'have', 'to', 'change', '.'],
#  ['this', 'time', 'we', 'will', 'need', 'global', 'cooperation', '.'],
#  ['consider', 'also', 'the', 'credit', 'markets', '.'],
#  ['the', 'challenges', 'facing', 'both', 'are', 'monumental', '.'],
#  ['that', 'pattern', 'is', 'much', 'less', 'prevalent', 'in', 'europe', '.'],
#  ['initially',
#   ',',
#   'the',
#   'new',
#   'arrangement',
#   'worked',
#   'very',
#   'well',
#   '.'],
#  ['the', 'country', 'thus', 'had', 'problems', 'exporting', '.'],
#  ['it', 'developed', 'external', 'deficits', 'and', 'growth', 'slowed', '.'],
#  ['now',
#   ',',
#   'it',
#   'is',
#   'moving',
#   'into',
#   'pakistan',
#   'and',
#   'west',
#   'asia',
#   '.'],
#  ['this', 'explains', 'high', 'economic', 'growth', 'rates', '.'],
#  ['what', 'can', 'even', 'more', 'isolation', 'achieve', '?'],
#  ['i', 'was', 'in', 'pakistan', 'as', 'a', 'state', 'guest', '.'],
#  ['this', 'has', 'spread', 'a', 'sense', 'of', 'unfairness', '.'],
#  ['look', 'at', 'our', 'television', 'programs', '.'],
#  ['that', 'pattern', 'reflected', 'cold', 'war', 'imperatives', '.'],
#  ['dissenting', 'views', 'found', 'little', 'traction', '.'],
#  ['vote-buying', 'became', 'increasingly', 'insufficient', '.'],
#  ['by', '2001', ',', 'the', 'cold', 'war', 'was', 'long', 'over', '.'],
#  ['thailand', '’', 's', 'demographics', 'also', 'changed', '.'],
#  ['we', 'live', 'in', 'an', 'era', 'of', 'low', 'predictability', '.'],
#  ['the', 'world', 'appears', 'in', 'constant', 'flux', '.'],
#  ['the', 'challenges', 'are', 'immense', '.'],
#  ['but', 'there', 'are', 'ways', 'to', 'waste', 'less', '.'],
#  ['transparency', 'in', 'procurement', 'works', 'wonders', '.'],
#  ['so', ',', 'too', ',', 'does', 'private', 'sector', 'involvement', '.'],
#  ['that', 'is', 'in', 'the', 'common', 'interest', '.'],
#  ['here', 'is', 'a', 'list', 'of', 'things', 'to', 'watch', 'for', '.'],
#  ['will', 'the', 'us', 'response', 'be', '“', 'bold', '”', 'enough', '?'],
#  ['will', 'europe', 'get', 'its', 'act', 'together', '?'],
#  ['this', 'could', 'have', 'been', 'europe', '’', 's', 'moment', '.'],
#  ['will', 'china', 'hold', 'together', '?'],
#  ['will', 'there', 'be', 'enough', 'global', 'economic', 'cooperation', '?'],
#  ['the',
#   'imf',
#   'has',
#   'not',
#   'been',
#   'immune',
#   'to',
#   'this',
#   'treatment',
#   '.'],
#  ['ultimately', ',', 'development', 'is', 'about', 'people', '.'],
#  ['reality', 'is', 'more', 'complex', '.'],
#  ['nostalgia', 'is', 'not', 'what', 'it', 'used', 'to', 'be', '.'],
#  ['and', 'now', 'we', 'are', 'back', 'to', 'reality', '.'],
#  ['this', 'is', 'a', 'strikingly', 'bad', 'idea', '.'],
#  ['fundamental', 'political', 'reform', 'is', 'needed', '.'],
#  ['true', ',', 'arab', 'leaders', 'differ', 'over', 'tactics', '.'],
#  ['but',
#   ',',
#   'the',
#   'irish',
#   'story',
#   'has',
#   'not',
#   'had',
#   'a',
#   'happy',
#   'ending',
#   '.'],
#  ['i', 'asked', 'them', 'to', 'set', 'priorities', 'for', 'the', 'world', '.'],
#  ['all', 'important', 'problems', '.'],
#  ['each', 'should', 'be', 'tackled', '.'],
#  ['the', 'ambassadors', 'showed', 'courage', '.'],
#  ['communicable', 'diseases'],
#  ['scaled-up', 'basic', 'health', 'services'],
#  ['community-managed', 'water', 'supply', 'and', 'sanitation'],
#  ['malnutrition', 'and', 'hunger'],
#  ['improving', 'infant', 'and', 'child', 'nutrition'],
#  ['malnutrition', 'and', 'hunger'],
#  ['communicable', 'diseases'],
#  ['communicable', 'diseases'],
#  ['malnutrition', 'and', 'hunger'],
#  ['reducing', 'micro', 'nutrient', 'deficiencies'],
#  ['subsidies', 'and', 'trade', 'barriers'],
#  ['optimistic', 'doha', ':', '50', '%', 'liberalization'],
#  ['improve', 'quality', '/', 'systemic', 'reforms'],
#  ['small-scale', 'water', 'technology', 'for', 'livelihoods'],
#  ['expand', 'demand', 'for', 'schooling'],
#  ['malnutrition', 'and', 'hunger'],
#  ['migration', 'for', 'development'],
#  ['re-using', 'waste', 'water', 'for', 'agriculture'],
#  ['guest', 'worker', 'policies'],
#  ['sustainable', 'food', 'and', 'fish', 'production', 'in', 'wetlands'],
#  ['grassroots', 'monitoring', 'and', 'service', 'delivery'],
#  ['active', 'immigration', 'policies'],
#  ['subsidies', 'and', 'trade', 'barriers'],
#  ['pessimistic', 'doha', ':', '25', '%', 'liberalization'],
#  ['aid', 'as', 'conflict', 'prevention'],
#  ['reform', 'of', 'revenue', 'collection'],
#  ['financial', 'instability'],
#  ['financial', 'instability'],
#  ['re-regulate', 'domestic', 'financial', 'markets'],
#  ['shortening', 'conflicts', ':', 'natural', 'resource', 'tracking'],
#  ['financial', 'instability'],
#  ['reimpose', 'capital', 'controls'],
#  ['financial', 'instability'],
#  ['adopt', 'a', 'common', 'currency'],
#  ['subsidies', 'and', 'trade', 'barriers'],
#  ['full', 'reform', ':', '100', '%', 'liberalization'],
#  ['value-at-risk', 'carbon', 'tax'],
#  ['a',
#   'carbon',
#   'tax',
#   'starting',
#   'at',
#   '$',
#   '2',
#   'and',
#   'ending',
#   'at',
#   '$',
#   '20'],
#  ['you',
#   'need',
#   'to',
#   'login',
#   'in',
#   'order',
#   'to',
#   'leave',
#   'a',
#   'comment',
#   '.'],
#  ['enter', 'and', 'post', 'your', 'comment', '.'],
#  ['2', ')', 'paragraph', 'commentplease', 'log', 'in', 'first', '.'],
#  ['then',
#   'click',
#   'to',
#   'the',
#   'left',
#   'of',
#   'the',
#   'desired',
#   'paragraph',
#   '.'],
#  ['enter', 'and', 'post', 'your', 'comment', '.'],
#  ['your', 'name', 'is', 'required', '.'],
#  ['your', 'email', 'is', 'required', '.'],
#  ['your', 'friend', "'s", 'name', 'is', 'required', '.'],
#  ['your', 'friend', "'s", 'email', 'is', 'required', '.'],
#  ['a', 'message', 'is', 'required', '.'],
#  ['the', 'email', 'was', 'sent', 'successfully', '.'],
#  ['but', 'google', '’', 's', 'plan', 'had', 'a', 'catch', '.'],
#  ['they', 'do', 'not', 'derive', 'from', 'a', 'social', 'contract', '.'],
#  ['indeed',
#   ',',
#   'they',
#   'are',
#   'part',
#   'of',
#   'what',
#   'makes',
#   'us',
#   'human',
#   '.'],
#  ['each', 'of', 'us', 'may', 'enjoy', 'rights', '.'],
#  ['europe', ',', 'by', 'contrast', ',', 'is', 'clearly', 'lagging', '.'],
#  ['should', 'europeans', 'be', 'worried', '?'],
#  ['this', 'process', 'is', 'starting', 'in', 'europe', 'only', 'now', '.'],
#  ['obviously', ',', 'such', 'a', 'comparison', 'has', 'its', 'limits', '.'],
#  ['today', ',', 'we', 'also', 'share', 'a', 'common', 'enemy', '.'],
#  ['they', 'will', 'not', 'negotiate', 'a', 'separate', 'peace', '.'],
#  ['who', 'decides', 'what', 'is', 'free', 'and', 'fair', '?'],
#  ['i', '’', 've', 'learned', 'my', 'lesson', 'about', 'musharraf', '.'],
#  ['the', 'same', 'is', 'true', 'of', 'democracy', '.'],
#  ['perhaps', ',', 'but', 'this', 'is', 'probably', 'a', 'red', 'herring', '.'],
#  ['these', 'anxieties', 'have', 'too', 'often', 'been', 'ignored', '.'],
#  ['the',
#   'muslim',
#   'threat',
#   'is',
#   ',',
#   'of',
#   'course',
#   ',',
#   'not',
#   'a',
#   'fantasy',
#   '.'],
#  ['nothing', 'good', 'ever', 'came', 'from', 'that', '.'],
#  ['the', 'warrant', 'was', 'no', 'leap', 'forward', '.'],
#  ['in',
#   'this',
#   'case',
#   ',',
#   'justice',
#   'comes',
#   'with',
#   'poisoned',
#   'arrows',
#   '.'],
#  ['a',
#   'law',
#   'that',
#   'can',
#   'not',
#   'be',
#   'enforced',
#   'deters',
#   'no',
#   'one',
#   '.'],
#  ['in', 'fact', ',', 'it', 'weakens', 'respect', 'for', 'law', '.'],
#  ['indeed',
#   ',',
#   'it',
#   'is',
#   'likely',
#   'to',
#   'prolong',
#   'wicked',
#   'regimes',
#   '.'],
#  ['international', 'law', 'is', 'the', 'conscience', 'of', 'mankind', '.'],
#  ['i',
#   'call',
#   'this',
#   'strategy',
#   'the',
#   '“',
#   'watershed',
#   'doctrine',
#   '.',
#   '”'],
#  ['we', 'find', 'watersheds', 'throughout', 'american', 'history', '.'],
#  ['but', 'arms-control', 'skeptics', 'take', 'issue', 'with', 'this', '.'],
#  ['it', 'all', 'depends', 'on', 'the', 'path', 'chosen', '.'],
#  ['new', 'york', '–', 'the', 'world', 'is', 'at', 'a', 'crossroads', '.'],
#  ['the', 'world', 'should', 'not', 'accept', 'the', 'status', 'quo', '.'],
#  ['market',
#   'logic',
#   ',',
#   'it',
#   'is',
#   'argued',
#   ',',
#   'dictates',
#   'this',
#   'result',
#   '.'],
#  ['but',
#   'this',
#   'premise',
#   'is',
#   'wrong',
#   ',',
#   'for',
#   'three',
#   'reasons',
#   '.'],
#  ['in', 'the', 'end', ',', 'that', 'will', 'be', 'a', 'good', 'thing', '.'],
#  ['it', 'has', 'fostered', 'regional-scale', 'infrastructure', '.'],
#  ['we',
#   'are',
#   ',',
#   'in',
#   'short',
#   ',',
#   'moving',
#   'to',
#   'a',
#   'multi-polar',
#   'world',
#   '.'],
#  ['so', 'you', 'thought', 'this', 'year', 'was', 'bad', '!'],
#  ['2009', 'began', 'with', 'the', 'flattening', 'of', 'gaza', '.'],
#  ['greed', 'was', 'just', 'taking', 'a', 'temporary', 'break', '.'],
#  ['he', '’', 'll', 'certainly', 'have', 'his', 'work', 'cut', 'out', '.'],
#  ['let', '’', 's', 'be', 'clear', 'about', 'what', 'is', 'happening', '.'],
#  ['weaker', 'economies', 'will', 'also', 'feel', 'the', 'pinch', '.'],
#  ['anything',
#   'short',
#   'of',
#   'that',
#   'would',
#   'be',
#   'very',
#   'bad',
#   'news',
#   '.'],
#  ['what', 'explains', 'this', 'odd', 'behavior', '?'],
#  ['not', 'blind', 'faith', 'in', 'technology', '.'],
#  ['nobody', 'can', 'be', 'sure', 'that', 'it', 'will', 'work', 'either', '.'],
#  ['such', 'efforts', 'are', 'getting', 'discretely', 'underway', '.'],
#  ['russia',
#   '’',
#   's',
#   'early',
#   '``',
#   'nyet',
#   "''",
#   'may',
#   'not',
#   'be',
#   'the',
#   'last',
#   'word',
#   '.'],
#  ['but', 'what', 'about', 'china', '?'],
#  ['it', 'is', 'also', 'bad', 'news', 'for', 'america', 'and', 'china', '.'],
#  ['american', 'populism', 'will', 'meet', 'chinese', 'pride', '.'],
#  ['just', '27', '%', 'chose', 'america', '.'],
#  ['a', 'full-scale', 'trade', 'war', 'is', 'unlikely', '.'],
#  ['but', 'these', 'spasms', 'will', 'not', 'revive', 'the', 'corpse', '.'],
#  ['this', 'is', 'somewhat', 'reassuring', '.'],
#  ['why', 'is', 'the', 'adb', 'constricting', 'its', 'agenda', '?'],
#  ['as',
#   'food',
#   'prices',
#   'rise',
#   ',',
#   'so',
#   'is',
#   'hunger',
#   'and',
#   'poverty',
#   '.'],
#  ['all',
#   'of',
#   'these',
#   'are',
#   'good',
#   ',',
#   'but',
#   'they',
#   'are',
#   'insufficient',
#   '.'],
#  ['his', 'was', 'the', 'aristocracy', 'of', 'the', 'spirit', '.'],
#  ['that', 'neglect', 'is', 'a', 'human', 'tragedy', '.'],
#  ['consider', 'a', 'couple', 'of', 'notorious', 'examples', '.'],
#  ['these', 'measures', 'are', 'achievable', 'by', '2010', '.'],
#  ['as', "goldstone's", 'report', 'makes', 'clear', ':'],
#  ['but', 'what', 'else', 'is', 'aid', 'if', 'it', 'is', 'not', 'revenue', '?'],
#  ['the',
#   'balance',
#   'sheet',
#   'is',
#   'improved',
#   'by',
#   '$',
#   '500',
#   'million',
#   '.'],
#  ['but', 'in', 'most', 'cases', ',', 'this', 'is', 'not', 'possible', '.'],
#  ['we', 'see', 'five', 'keys', 'to', 'recovery', ':'],
#  ['this', 'is', ',', 'in', 'part', ',', 'inevitable', '.'],
#  ['that', 'has', 'now', 'changed', '.'],
#  ['and', 'this', 'is', 'just', 'the', 'baseline', 'scenario', '.'],
#  ['these', 'need', 'to', 'adapt', ',', 'too', '.'],
#  ['what', 'of', 'the', 'large', 'advanced', 'countries', '?'],
#  ['the', 'political', 'narrative', 'runs', 'in', 'parallel', '.'],
#  ['it', 'is', 'also', 'often', 'ignored', '.'],
#  ['much', 'less', 'work', 'has', 'been', 'devoted', 'to', 'adaptation', '.'],
#  ['farmers', 'will', 'choose', 'plants', 'that', 'thrive', 'in', 'heat', '.'],
#  ['poor', 'countries', 'will', 'be', 'hit', 'harder', ',', 'however', '.'],
#  ['the', 'sovereign-debt', 'crisis', 'is', 'well', 'known', '.'],
#  ['greece', 'essentially', 'defaulted', 'on', 'some', 'obligations', '.'],
#  ['the', 'immediate', 'causes', 'are', 'well', 'known', '.'],
#  ['the', 'subtext', 'is', 'clear', ':', 'be', 'like', 'us', 'now', '.'],
#  ['modesty', 'is', 'a', 'virtue', 'in', 'private', 'life', '.'],
#  ['in',
#   'most',
#   'cases',
#   ',',
#   'neither',
#   'can',
#   'be',
#   'remedied',
#   'overnight',
#   '.'],
#  ['but',
#   'they',
#   'remain',
#   'in',
#   'existence',
#   'three',
#   'decades',
#   'later',
#   '.'],
#  ['in',
#   'fact',
#   ',',
#   'they',
#   'are',
#   'so',
#   'right',
#   'that',
#   'they',
#   'are',
#   'wrong',
#   '.'],
#  ['that',
#   '’',
#   's',
#   'not',
#   'a',
#   'lot',
#   'of',
#   'bang',
#   'for',
#   'the',
#   'buck',
#   '.'],
#  ['we', 'can', 'do', 'the', 'same', 'for', 'clean', 'energy', '.'],
#  ['the', 'younger', 'the', 'girl', ',', 'the', 'higher', 'the', 'price', '.'],
#  ['yet', 'women', 'are', 'precious', 'in', 'their', 'own', 'way', '.'],
#  ['illegal', 'logging', 'crews', 'number', '200', 'or', 'more', '.'],
#  ['they', 'have', 'chain', 'saws', 'and', 'trucks', '.'],
#  ['unloved', 'little', 'girls', 'fare', 'the', 'worst', '.'],
#  ['but',
#   'note',
#   'that',
#   'it',
#   'occurred',
#   'near',
#   'a',
#   'health',
#   'facility',
#   '.'],
#  ['opium', 'is', 'choking', 'afghan', 'society', '.'],
#  ['within', 'afghanistan', ',', 'drug', 'addiction', 'is', 'rising', '.'],
#  ['farmers', 'are', 'a', 'different', 'story', '.'],
#  ['that', 'situation', 'needs', 'to', 'be', 'reversed', '.'],
#  ['we', 'can', 'not', 'afford', 'to', 'fail', 'in', 'afghanistan', '.'],
#  ['these', 'may', 'seem', 'to', 'be', 'distinct', 'issues', '.'],
#  ['in', 'fact', ',', 'they', 'are', 'linked', '.'],
#  ['hunger', 'is', 'omnipresent', '.'],
#  ['nor', 'should', 'they', 'have', 'to', '.'],
#  ['rich', 'countries', 'need', 'to', 'lead', 'the', 'way', '.'],
#  ['no', 'amount', 'of', 'money', 'will', 'undo', 'the', 'damage', 'done', '.'],
#  ['it', 'was', 'that', 'word', '``', 'development', "''", 'again', '.'],
#  ['do',
#   'we',
#   'really',
#   '``',
#   'develop',
#   "''",
#   'leaders',
#   'or',
#   'countries',
#   '?'],
#  ['but', 'perhaps', 'he', 'knows', 'better', '.'],
#  ['was', 'kofi', 'annan', '``', 'developed', '?', "''"],
#  ['countries', 'like', 'ghana', 'do', 'not', 'lack', 'enterprise', '.'],
#  ['markets', 'and', 'personal', 'initiative', 'are', 'pervasive', '.'],
#  ['globalization', 'must', 'not', 'be', 'allowed', 'to', 'blind', 'us', '.'],
#  ['rarely', 'have', 'i', 'been', 'so', 'profoundly', 'moved', '.'],
#  ['uganda', 'was', 'the', 'epicenter', 'of', 'the', 'aids', 'epidemic', '.'],
#  ['yet', 'uganda', 'is', 'also', 'a', 'success', 'story', '.'],
#  ['meanwhile', ',', 'money', 'for', 'treatment', 'is', 'drying', 'up', '.'],
#  ['worldwide', ',', 'the', 'number', 'is', 'about', '10', 'million', '.'],
#  ['those', 'who', 'rallied', 'to', 'the', 'fight', 'are', 'alarmed', '.'],
#  ['surely', 'we', 'can', 'do', 'better', '.'],
#  ['the', 'war', 'was', 'over', '.', 'but', 'not', 'for', 'me', '.'],
#  ['i', 'became', 'an', 'expert', 'in', 'tank', 'warfare', '.'],
#  ['i', 'have', 'no', 'regrets', ',', 'i', 'offer', 'no', 'apologies', '.'],
#  ['injustice', 'provokes', 'children', 'to', 'pick', 'up', 'guns', '.'],
#  ['of', 'course', ',', 'no', 'child', 'should', 'go', 'to', 'war', '.'],
#  ['i', 'survived', 'and', 'learned', '.'],
#  ['i', 'learned', 'the', 'limits', 'of', 'the', 'gun', '.'],
#  ['yet', 'most', 'died', 'in', 'combat', 'or', 'of', 'aids', '.'],
#  ['domestic', 'capital', 'markets', 'were', 'non-existent', '.'],
#  ['litigation', 'can', 'be', 'costly', 'and', 'hazardous', '.'],
#  ['meles', 'was', 'certainly', 'both', '.'],
#  ['africa', 'has', 'about', '50', 'billion', 'tons', '.'],
#  ['britain', 'nationalizes', 'its', 'banks', '.'],
#  ['but',
#   'haven',
#   '’',
#   't',
#   'we',
#   'heard',
#   'this',
#   'all',
#   'before',
#   'in',
#   'africa',
#   '?'],
#  ['that', 'allegiance', 'is', 'misplaced', '.'],
#  ['what', 'it', 'does', 'not', 'require', 'is', 'a', 'currency', 'union', '.'],
#  ['but', 'there', 'is', 'a', 'remedy', 'at', 'hand', '.'],
#  ['this', 'policy', 'poses', 'two', 'practical', 'problems', '.'],
#  ['so', 'why', 'are', "n't", 'africans', 'celebrating', '?'],
#  ['but',
#   'graft',
#   'and',
#   'theft',
#   'are',
#   'not',
#   'the',
#   'only',
#   'problems',
#   '.'],
#  ['the', 'call', 'went', 'unheeded', '.'],
#  ['why', 'does', 'africa', 'remain', 'poor', '?'],
#  ['without',
#   'her',
#   'help',
#   ',',
#   'i',
#   'might',
#   'not',
#   'have',
#   'farmed',
#   'at',
#   'all',
#   '.'],
#  ['even',
#   'with',
#   'mother',
#   '’',
#   's',
#   'help',
#   ',',
#   'i',
#   'have',
#   'worries',
#   '.'],
#  ['one', 'key', 'tool', 'is', 'the', 'mobile', 'phone', '.'],
#  ['certain',
#   'crops',
#   'can',
#   'be',
#   'grown',
#   'in',
#   'their',
#   'own',
#   'homes',
#   '.'],
#  ['but',
#   'the',
#   'facts',
#   'on',
#   'the',
#   'ground',
#   'do',
#   'not',
#   'bear',
#   'this',
#   'out',
#   '.'],
#  ['nor', 'is', 'the', 'icc', 'a', 'foreign', 'body', '.'],
#  ['arafat', 'never', 'really', 'agreed', 'to', 'share', 'power', '.'],
#  ['that', 'is', 'the', 'problem', '.', "''"],
#  ['but', 'at', 'some', 'point', ',', 'arafat', 'will', 'depart', '.'],
#  ['this',
#   'problem',
#   'will',
#   'not',
#   'go',
#   'away',
#   'when',
#   'arafat',
#   'does',
#   '.'],
#  ['human', 'migration', 'is', 'as', 'old', 'as', 'history', '.'],
#  ['what', 'then', 'is', 'the', 'alternative', 'to', 'assimilation', '?'],
#  ['but', 'it', 'can', 'not', 'be', 'had', 'for', 'nothing', '.'],
#  ['there', 'are', 'alternative', 'strategies', '.'],
#  ['the', 'eib', 'should', 'expand', 'its', 'lending', '.'],
#  ['and', 'the', 'crisis', 'itself', 'almost', 'surely', 'will', 'spread', '.'],
#  ['but', 'that', 'is', 'what', 'europe', 'is', 'doing', '.'],
#  ['fortunately', ',', 'there', 'is', 'an', 'alternative', '.'],
#  ['ultimately', ',', 'chernobyl', 'changed', 'the', 'world', '.'],
#  ['international', 'support', 'for', 'our', 'efforts', 'is', 'crucial', '.'],
#  ['we', 'are', 'a', 'european', 'nation', '.'],
#  ['every', 'case', 'has', 'its', 'own', 'defining', 'features', '.'],
#  ['they', 'had', 'good', 'reasons', 'to', 'complain', '.'],
#  ['a',
#   'second',
#   'general',
#   'issue',
#   'has',
#   'to',
#   'do',
#   'with',
#   'priorities',
#   '.'],
#  ['the', 'second', 'imperative', 'is', 'the', 'rule', 'of', 'law', '.'],
#  ['this', 'is', 'notably', 'the', 'case', 'in', 'economic', 'terms', '.'],
#  ['no', 'single', 'instrument', 'will', 'work', 'everywhere', '.'],
#  ['seoul', '–', 'korea', 'is', 'a', 'unique', 'country', '.'],
#  ['call', 'itfast-forward', 'modernization', '.'],
#  ['indeed', ',', 'the', 'revolution', 'is', 'already', 'upon', 'us', '.'],
#  ['take', 'the', 'example', 'of', 'computers', '.'],
#  ['this', 'conflict', 'exists', 'globally', '.'],
#  ['so',
#   'long',
#   'as',
#   'these',
#   'ideas',
#   'clash',
#   ',',
#   'violence',
#   'will',
#   'lurk',
#   '.'],
#  ['the', 'implications', 'are', 'clear', '.'],
#  ['efforts', 'to', 'do', 'so', 'usually', 'ended', 'disastrously', '.'],
#  ['not', 'only', 'political', 'forces', 'need', 'to', 'be', 'checked', '.'],
#  ['this', 'was', 'the', 'golden', 'age', 'of', 'finance', '.'],
#  ['is', 'this', 'a', 'short-term', 'phenomenon', '?'],
#  ['will', 'financial', '“', 'deepening', '”', 'continue', '?'],
#  ['financial-sector', 'returns', 'are', 'likely', 'to', 'be', 'lower', '.'],
#  ['that', 'will', 'not', 'be', 'easy', '.'],
#  ['let', '’', 's', 'start', 'with', 'the', 'united', 'states', '.'],
#  ['but', 'these', 'complaints', 'miss', 'the', 'point', '.'],
#  ['still', ',', 'a', 'central', 'paradox', 'plagues', 'the', 'mdgs', '.'],
#  ['this', 'kind', 'of', 'reorientation', 'will', 'not', 'be', 'easy', '.'],
#  ['the', 'trends', 'are', 'similar', 'elsewhere', 'in', 'europe', '.'],
#  ['the', 'priorities', 'are', 'clear', '.'],
#  ['but', 'examples', 'of', 'smart', 'migration', 'practices', 'abound', '.'],
#  ['land-mines', 'defile', 'the', 'countryside', '.'],
#  ['afghanistan', 'is', 'no', 'place', 'for', 'quick', 'fixes', '.'],
#  ['rebuilding', 'the', 'country', 'can', 'not', 'be', 'done', 'cheaply', '.'],
#  ['but', 'stripped', 'they', 'must', 'be', '.'],
#  ['reasonableness', 'does', 'not', 'always', 'yield', 'results', '.'],
#  ['there', 'are', 'bright', 'spots', ',', 'of', 'course', '.'],
#  ['none',
#   'of',
#   'this',
#   'detracts',
#   'from',
#   'the',
#   'resilience',
#   'factor',
#   '.'],
#  ['and', 'now', 'it', 'risks', 'missing', 'another', 'important', 'clue', '.'],
#  ['the', 'novel', 'is', 'blinding', ',', 'by', 'claudio', 'magris', '.'],
#  ['unfortunately', ',', 'that', 'is', 'no', 'surprise', '.'],
#  ['new',
#   'york',
#   '–',
#   'the',
#   'critics',
#   'of',
#   'foreign',
#   'aid',
#   'are',
#   'wrong',
#   '.'],
# ...
#  ['the', 'story', 'goes', 'back', 'to', 'the', 'recession', 'of', '2001', '.'],
#  ['that', 'is', 'certainly', 'true', 'of', 'greenspan', '.'],
#  ['it', 'is', 'also', 'filled', 'with', 'propaganda', '.'],
#  ['for', '40', 'years', ',', 'compassion', 'in', 'politics', 'receded', '.'],
#  ['bill',
#   'clinton',
#   'continued',
#   'those',
#   'cuts',
#   'in',
#   'the',
#   '1990',
#   '’',
#   's',
#   '.'],
#  ['the', 'world', 'should', 'beware', '.'],
#  ['this', 'reinforces', 'the', 'stalemate', '.'],
#  ['obama', 'has', 'dramatically', 'increased', 'spending', '.'],
#  ['in', 'fact', ',', 'it', 'had', 'deep', 'roots', '.'],
#  ['the', 'household', 'sector', 'is', 'especially', 'important', '.'],
#  ['that', 'means', 'forgoing', 'some', 'government', 'services', '.'],
#  ['•', 'additional', 'deficit', 'spending', ';'],
#  ['but', 'will', 'congress', 'act', 'quickly', '?'],
#  ['don', '’', 't', 'hold', 'your', 'breath', '.'],
#  ['it', 'has', 'not', 'always', 'been', 'this', 'way', '.'],
#  ['it', 'backs', 'the', 'ethiopian', 'army', 'in', 'somalia', '.'],
#  ['it', 'occupies', 'iraq', 'and', 'afghanistan', '.'],
#  ['it', 'threatens', 'to', 'bomb', 'iran', '.'],
#  ['naturally', ',', 'many', 'join', 'radical', 'causes', '.'],
#  ['we', 'all', 'breathe', 'the', 'same', 'air', '.'],
#  ['but', 'what', 'are', 'they', 'really', 'buying', '?'],
#  ['and', 'that', 'is', 'not', 'something', 'you', 'want', 'to', 'buy', '.'],
#  ['after',
#   'all',
#   ',',
#   'the',
#   'united',
#   'states',
#   'had',
#   'been',
#   'attacked',
#   '.'],
#  ['that', 'message', 'is', 'bad', 'news', 'for', 'american', 'diplomacy', '.'],
#  ['countries', 'take', 'others', '’', 'advice', 'for', 'many', 'reasons', '.'],
#  ['but', 'what', 'if', 'there', 'is', 'no', 'money', 'to', 'offer', '?'],
#  ['but',
#   'there',
#   'was',
#   'no',
#   'response',
#   'from',
#   'the',
#   'us',
#   'government',
#   '.'],
#  ['she', 'has', 'never', 'recanted', '.'],
#  ['it', 'is', 'still', 'not', 'too', 'late', '.'],
#  ['it', 'need', 'only', 'seize', 'the', 'g-zero', 'moment', '.'],
#  ['sometimes', 'reason', 'does', 'prevail', '.'],
#  ['we',
#   'scratch',
#   'our',
#   'heads',
#   'about',
#   'america',
#   '’',
#   's',
#   'gun',
#   'laws',
#   '.'],
#  ['it', 'is', 'hugely', 'expensive', '.'],
#  ['the', 'poor', 'go', 'unprotected', '.'],
#  ['too', 'many', 'of', 'the', 'sick', 'are', 'untreated', '.'],
#  ['communism', 'in', 'toronto', 'and', 'london', '?'],
#  ['but', 'no', 'bubble', 'can', 'expand', 'forever', '.'],
#  ['there', 'is', 'a', 'macro-story', 'and', 'a', 'micro-story', 'here', '.'],
#  ['the', 'macro-story', 'is', 'simple', ',', 'but', 'dramatic', '.'],
#  ['the', 'micro-story', 'is', 'more', 'dramatic', '.'],
#  ['in',
#   'the',
#   'face',
#   'of',
#   'such',
#   'uncertainty',
#   ',',
#   'markets',
#   'froze',
#   '.'],
#  ['for', 'where', 'should', 'they', 'park', 'their', 'money', '?'],
#  ['this', 'raises', 'serious', 'ethical', 'questions', '.'],
#  ['accountability', 'is', 'also', 'being', 'flouted', '.'],
#  ['others', 'should', 'feel', 'encouraged', 'to', 'follow', 'suit', '.'],
#  ['another', 'six', 'months', 'should', 'not', 'be', 'lost', '.'],
#  ['here',
#   ',',
#   'too',
#   ',',
#   'another',
#   'six',
#   'months',
#   'should',
#   'not',
#   'be',
#   'lost',
#   '.'],
#  ['another', 'six', 'months', 'have', 'been', 'lost', '.'],
#  ['but', 'the', 'us', 'government', 'won', '’', 't', 'address', 'them', '.'],
#  ['that', 'america', 'may', 'be', 'gone', 'for', 'good', '.'],
#  ['the', 'opening', 'was', 'less', 'than', 'it', 'seemed', '.'],
#  ['for',
#   'cambodia',
#   ',',
#   'the',
#   'figure',
#   'would',
#   'be',
#   'about',
#   '62',
#   '%',
#   '.'],
#  ['it', 'was', 'imperative', 'that', 'such', 'unity', 'be', 'destroyed', '.'],
#  ['the', 'cause', 'is', 'no', 'secret', '.'],
#  ['none', 'of', 'this', 'can', 'occur', 'in', 'a', 'vacuum', '.'],
#  ['yet',
#   'the',
#   'us',
#   'found',
#   'a',
#   'way',
#   'to',
#   'finesse',
#   'this',
#   'problem',
#   '.'],
#  ['there', 'are', 'obvious', 'reasons', 'for', 'this', '.'],
#  ['but', 'don', '’', 't', 'count', 'on', 'it', '.'],
#  ['let',
#   'us',
#   'hope',
#   'that',
#   'it',
#   'will',
#   'be',
#   'short',
#   'and',
#   'shallow',
#   '.'],
#  ['this',
#   'view',
#   'seems',
#   'intuitively',
#   'correct',
#   ',',
#   'but',
#   'is',
#   'it',
#   '?'],
#  ['the', 'gargantuan', 'us', 'trade', 'deficit', '?'],
#  ['at', 'some', 'point', ',', 'the', 'party', 'is', 'going', 'to', 'end', '.'],
#  ['can', 'the', 'end', 'come', 'abruptly', 'in', '2006', '?'],
#  ['in',
#   'the',
#   'united',
#   'states',
#   ',',
#   'this',
#   'is',
#   'truer',
#   'than',
#   'ever',
#   '.'],
#  ['it', 'must', 'be', 'cut', ',', 'but', 'how', '?'],
#  ['the', 'result', 'is', 'a', 'dangerous', 'paradox', '.'],
#  ['it', 'makes', 'sense', 'to', 'tax', 'them', 'more', '.'],
#  ['this',
#   'month',
#   ',',
#   'they',
#   'succeeded',
#   ',',
#   'at',
#   'least',
#   'for',
#   'now',
#   '.'],
#  ['in',
#   'the',
#   'end',
#   ',',
#   'i',
#   'don',
#   '’',
#   't',
#   'think',
#   'they',
#   'will',
#   'succeed',
#   '.'],
#  ['but',
#   'make',
#   'no',
#   'mistake',
#   ':',
#   'both',
#   'parties',
#   'are',
#   'implicated',
#   '.'],
#  ['that', 'sum', 'will', 'not', 'come', 'from', 'the', 'poor', '.'],
#  ['obama',
#   'swept',
#   'to',
#   'power',
#   'on',
#   'the',
#   'promise',
#   'of',
#   'change',
#   '.'],
#  ['so', 'far', 'there', 'has', 'been', 'none', '.'],
#  ['this', ',', 'too', ',', 'will', 'take', 'time', '.'],
#  ['yet', 'the', 'time', 'for', 'change', 'will', 'come', '.'],
#  ['i', 'believe', 'that', 'they', 'will', 'be', 'proved', 'wrong', '.'],
#  ['in', 'the', 'end', ',', 'our', 'hopes', 'were', 'frustrated', '.'],
#  ['very', 'little', 'was', 'added', 'to', 'current', 'spending', '.'],
#  ['this', 'is', 'especially', 'true', 'of', 'bachmann', '.'],
#  ['they', 'use', 'emotive', 'rhetoric', '.'],
#  ['they', 'create', 'an', '“', 'us', 'versus', 'them', '”', 'scenario', '.'],
#  ['this', 'reasoning', 'resonates', 'with', 'the', 'us', 'public', '.'],
#  ['indeed',
#   ',',
#   'america',
#   '’',
#   's',
#   'major',
#   'threat',
#   'is',
#   'from',
#   'within',
#   '.'],
#  ['exports', 'top', 'the', 'list', 'of', 'possibilities', '.'],
#  ['the', 'same', 'is', 'true', 'of', 'services', '.'],
#  ['the', 'withdrawal', 'plan', 'is', 'causing', 'countless', 'worries', '.'],
#  ['militarily', ',', 'this', 'argument', 'does', 'make', 'sense', '.'],
#  ['the', 'net', 'saving', 'rate', 'fell', 'to', 'near', 'zero', '.'],
#  ['mortgages', 'became', 'more', 'widely', 'available', '.'],
#  ['the', 'stock', 'market', 'dropped', 'sharply', '.'],
#  ['this', 'is', 'easy', 'to', 'demonstrate', '.'],
#  ['so',
#   'the',
#   'equation',
#   'is',
#   'simple',
#   ':',
#   '5.5',
#   '%',
#   '-1.5',
#   '%',
#   '-3.5',
#   '%',
#   '=',
#   '0.5',
#   '%',
#   '.'],
#  ['but', 'why', 'does', 'this', 'seem', 'so', 'surprising', '?'],
#  ['it', 'is', 'a', 'community', 'of', 'human', 'beings', '.'],
#  ['memories', 'of', 'the', 'great', 'depression', 'are', 'dying', 'out', '.'],
#  ['now', 'the', 'west', 'is', 'paying', 'the', 'price', '.'],
#  ['i', 'see', 'a', 'very', 'different', 'picture', '.'],
#  ['i', 'really', 'do', 'not', 'know', '.'],
#  ['i', 'think', 'this', 'judgment', 'is', 'wrong', '.'],
#  ['there', 'is', 'no', 'market', 'discipline', '.'],
#  ['we', 'can', 'not', 'afford', 'to', 'let', 'that', 'happen', '.'],
#  ['frighteningly', ',', 'the', 'russians', 'were', 'likely', 'correct', '.'],
#  ['madrid', '–', 'the', 'pacific', 'or', 'the', 'middle', 'east', '?'],
#  ['but', 'how', 'can', 'this', 'be', 'achieved', '?'],
#  ['us', 'public', 'opinion', 'seems', 'to', 'confirm', 'this', '.'],
#  ['consider', 'the', 'middle', 'east', '.'],
#  ['japan',
#   'and',
#   'canada',
#   'have',
#   'said',
#   'they',
#   'plan',
#   'to',
#   'do',
#   'so',
#   '.'],
#  ['of',
#   'course',
#   ',',
#   'the',
#   'us',
#   'lobbies',
#   'would',
#   'have',
#   'none',
#   'of',
#   'it',
#   '.'],
#  ['but', 'it', 'is', 'too', 'early', 'to', 'celebrate', '.'],
#  ['the',
#   'united',
#   'states',
#   'is',
#   'now',
#   'caught',
#   'in',
#   'such',
#   'a',
#   'bind',
#   '.'],
#  ['obama', 'emphasized', 'these', 'themes', 'for', 'good', 'reason', '.'],
#  ['the', 'truth', 'of', 'us', 'politics', 'today', 'is', 'simple', '.'],
#  ['both', 'parties', 'therefore', 'cater', 'to', 'their', 'wishes', '.'],
#  ['first',
#   ',',
#   'it',
#   'has',
#   'contributed',
#   'to',
#   'rising',
#   'oil',
#   'prices',
#   '.'],
#  ['the', 'war', 'changed', 'that', 'equation', '.'],
#  ['instead',
#   ',',
#   'much',
#   'of',
#   'it',
#   'will',
#   'find',
#   'its',
#   'way',
#   'abroad',
#   '.'],
#  ['when',
#   'america',
#   'went',
#   'to',
#   'war',
#   ',',
#   'there',
#   'was',
#   'a',
#   'deficit',
#   '.'],
#  ['the', 'numbers', 'are', 'hard', 'to', 'believe', '.'],
#  ['there', 'is', 'also', 'the', 'promise', 'of', 'new', 'institutions', '.'],
#  ['america', 'should', 'take', 'note', '.'],
#  ['clearly', ',', 'the', 'nuclear', 'door', 'is', 'being', 'reopened', '.'],
#  ['that', 'seems', 'to', 'be', 'happening', '.'],
#  ['none', 'of', 'them', 'has', 'ever', 'been', 'put', 'on', 'trial', '.'],
#  ['they',
#   'were',
#   'left',
#   'there',
#   'for',
#   '18',
#   'or',
#   '24',
#   'hours',
#   ',',
#   'or',
#   'more',
#   '.'],
#  ['but', 'the', 'cia', 'has', 'made', 'mistakes', 'before', '.'],
#  ['the', 'basic', 'situation', 'has', 'been', 'clear', 'for', 'years', '.'],
#  ['rainfall', 'patterns', 'are', 'changing', '.'],
#  ['deserts', 'and', 'dry', 'regions', 'are', 'becoming', 'drier', '.'],
#  ['but', 'the', 'effort', 'needs', 'to', 'start', 'now', '.'],
#  ['she', 'even', 'had', 'an', 'oil', 'tanker', 'named', 'after', 'her', '.'],
#  ['what', 'comes', 'after', 'iraq', '?'],
#  ['the', 'danger', 'of', 'their', 'approach', 'is', 'now', 'obvious', '.'],
#  ['these', 'are', 'not', 'problems', 'you', 'can', 'leave', 'overseas', '.'],
#  ['they', 'follow', 'you', 'home', '.'],
#  ['chaudhuri', 'had', 'a', 'point', '.'],
#  ['like', 'chaudhuri', ',', 'kagan', 'is', 'an', 'engaging', 'writer', '.'],
#  ['his', 'arguments', 'sound', 'reasonable', '.'],
#  ['this', 'is', 'the', 'conceit', 'of', 'all', 'great', 'powers', '.'],
#  ['how', 'can', 'things', 'have', 'come', 'to', 'this', 'america', '?'],
#  ['but', 'the', 'term', 'is', 'confusing', '.'],
#  ['many', 'considered', 'it', 'a', 'global', 'hegemon', '.'],
#  ['now',
#   'many',
#   'have',
#   'gone',
#   'back',
#   'to',
#   'believing',
#   'in',
#   'decline',
#   '.'],
#  ['how',
#   'can',
#   'we',
#   'know',
#   'if',
#   'these',
#   'predictions',
#   'are',
#   'correct',
#   '?'],
#  ['what', 'resources', 'will', 'produce', 'power', '?'],
#  ['power', 'always', 'depends', 'on', 'context', '.'],
#  ['in',
#   'this',
#   'sense',
#   ',',
#   'power',
#   'becomes',
#   'a',
#   'positive',
#   'sum',
#   'game',
#   '.'],
#  ['ultimately',
#   ',',
#   'america',
#   '’',
#   's',
#   'vital',
#   'interests',
#   'prevailed',
#   '.'],
#  ['is', 'such', 'an', 'amnesty', 'a', 'good', 'idea', '?'],
#  ['these', 'are', 'weighty', 'questions', '.'],
#  ['an', 'incomplete', 'list', 'of', 'his', 'crimes', 'includes', ':'],
#  ['he', 'could', 'not', 'move', 'freely', '.'],
#  ['amnesty', 'for', 'saddam', 'hussein', 'is', 'simply', 'intolerable', '.'],
#  ['unfortunately', ',', 'reform', 'was', 'derailed', 'in', '2005', '.'],
#  ['this', 'is', 'a', 'historic', 'fallacy', '.'],
#  ['tolerance', 'and', 'religious', 'freedom', 'must', 'be', 'mutual', '.'],
#  ['no', 'core', 'problem', 'was', 'really', 'tackled', '.'],
#  ['was', 'it', 'capitulating', 'to', 'american', 'hegemony', '?'],
#  ['but', 'what', 'is', 'the', 'reality', 'here', '?'],
#  ['sofear', 'of', 'a', 'panic', 'cancreate', 'a', 'panic', '.'],
#  ['but', 'did', 'the', 'reforms', 'go', 'far', 'enough', '?'],
#  ['these', 'banks', 'areilliquid', 'but', 'notinsolvent', '.'],
#  ['the', 'central', 'bank', 'can', 'help', 'with', 'familiar', 'tools', '.'],
#  ['or', 'perhaps', 'it', 'is', 'not', 'so', 'new', 'after', 'all', '.'],
#  ['they', ',', 'too', ',', 'thirst', 'for', 'freedom', '.'],
#  ['but',
#   'this',
#   'would',
#   'lead',
#   'to',
#   'an',
#   'even',
#   'greater',
#   'tragedy',
#   '.'],
#  ['in', 'fact', ',', 'the', 'exact', 'opposite', 'is', 'true', '.'],
#  ['they', 'need', 'it', 'to', 'talk', 'to', 'their', 'adversaries', '.'],
#  ['the', 'us', 'might', 'also', 'learn', 'from', 'other', 'examples', '.'],
#  ['we', 'have', 'great', 'differences', 'today', '.'],
#  ['djindjic', 'remained', 'pragmatic', ',', 'never', 'doctrinaire', '.'],
#  ['only',
#   'prosperity',
#   'and',
#   'a',
#   '``',
#   'european',
#   'serbia',
#   "''",
#   'mattered',
#   '.'],
#  ['did', 'these', 'short', 'cuts', 'help', 'incite', 'his', 'death', '?'],
#  ['once', 'again', ',', 'serbs', 'face', 'such', 'a', 'moment', '.'],
#  ['but',
#   'it',
#   'is',
#   'the',
#   'eu',
#   'that',
#   'is',
#   'proving',
#   'most',
#   'complicit',
#   '.'],
#  ['but', 'europe', 'can', 'fight', 'back', '.'],
#  ['that', 'risk', 'materialized', 'with', 'the', 'iraq', 'war', '.'],
#  ['this',
#   'is',
#   'the',
#   'stuff',
#   'of',
#   'dictatorship',
#   ',',
#   'not',
#   'democracy',
#   '.'],
#  ['they',
#   'can',
#   'do',
#   'so',
#   'very',
#   'easily',
#   ':',
#   'by',
#   'following',
#   'the',
#   'law',
#   '.'],
#  ['how', 'wrong', 'frum', 'now', 'seems', '.'],
#  ['the', 'british', 'government', 'did', 'say', 'that', '.', "''"],
#  ['but', 'bush', 'did', 'nothing', 'of', 'the', 'sort', '.'],
#  ['but', 'the', 'crisis', 'has', 'invigorated', 'the', 'imf', '.'],
#  ['how',
#   'will',
#   'it',
#   'choose',
#   'to',
#   'deploy',
#   'its',
#   'newfound',
#   'power',
#   '?'],
#  ['this', 'is', 'an', 'important', 'moment', 'for', 'the', 'imf', '.'],
#  ['gore',
#   'also',
#   'frets',
#   'about',
#   'the',
#   'future',
#   'of',
#   'polar',
#   'bears',
#   '.'],
#  ['gore', 'has', 'helped', 'the', 'world', 'to', 'worry', '.'],
#  ['three', 'million', 'lives', 'will', 'be', 'lost', 'to', 'hiv/aids', '.'],
#  ['gore', 'has', 'a', 'very', 'different', 'approach', '.'],
#  ['few', 'expect', 'that', 'to', 'happen', '.'],
#  ['should', 'anything', 'be', 'done', 'about', 'this', '?'],
#  ['they', 'argue', 'that', 'only', 'poverty', 'reduction', 'matters', '.'],
#  ['now', ',', 'all', 'can', 'see', 'these', 'income', 'differences', '.'],
#  ['the',
#   'us',
#   'is',
#   'now',
#   'ground',
#   'zero',
#   'for',
#   'global',
#   'inflation',
#   '.'],
#  ['so', 'what', 'happens', 'next', '?'],
#  ['terrorism', 'is', 'an', 'existential', 'threat', '.'],
#  ['the', 'operation', "'s", 'success', 'was', 'no', 'accident', '.'],
#  ['still', ',', 'i', 'am', 'not', 'complacent', '.'],
#  ['but',
#   'esdp',
#   'is',
#   'not',
#   'at',
#   'the',
#   'core',
#   'of',
#   'our',
#   'efforts',
#   '.'],
#  ['regional', 'conflicts', 'cause', 'anger', 'and', 'resentment', '.'],
#  ['the', 'eu', 'will', 'be', 'tough', 'on', 'terrorism', '.'],
#  ['these', 'are', 'not', 'two', 'fights', ',', 'but', 'one', '.'],
#  ['such', 'complacency', 'is', 'premature', '.'],
#  ['but',
#   'that',
#   'putsch',
#   ',',
#   'thankfully',
#   ',',
#   'ended',
#   'as',
#   'a',
#   'farce',
#   '.'],
#  ['this', 'is', 'not', 'a', 'novel', 'phenomenon', '.'],
#  ['political', 'maps', 'are', 'never', 'carved', 'in', 'stone', '.'],
#  ['stanford',
#   '–',
#   'well',
#   ',',
#   'america',
#   'is',
#   'involved',
#   'at',
#   'last',
#   '.'],
#  ['there', 'is', 'little', 'time', 'to', 'waste', '.'],
#  ['and',
#   'yet',
#   'renewed',
#   'war',
#   'in',
#   'sudan',
#   'is',
#   'not',
#   'inevitable',
#   '.'],
#  ['keep', 'the', 'pressure', 'on', 'them', '.'],
#  ['support', 'the', 'peace', 'process', '.'],
#  ['your', 'voice', 'can', 'prevent', 'a', 'war', '.'],
#  ['there', 'are', 'hard', 'choices', 'to', 'be', 'made', '.'],
#  ['but', 'other', 'things', 'were', 'not', 'equal', '.'],
#  ['but', 'conglomeratization', 'takes', 'time', '.'],
#  ['the', 'bush', 'administration', 'cut', 'taxes', '.'],
#  ['again', ',', 'these', 'were', 'not', 'outright', 'policy', 'mistakes', '.'],
#  ['but', ',', 'either', 'way', ',', 'there', 'will', 'be', 'downsizing', '.'],
#  ['us', 'households', 'will', 'have', 'to', 'start', 'saving', 'again', '.'],
#  ['we', 'are', 'not', 'going', 'to', 'change', 'human', 'nature', '.'],
#  ['we', 'can', 'not', 'make', 'investors', 'less', 'greedy', '.'],
#  ['this', 'trend', 'is', 'not', 'hard', 'to', 'understand', '.'],
#  ['a', 'few', 'key', 'indicators', 'appear', 'to', 'support', 'this', '.'],
#  ['but', 'history', 'never', 'truly', 'repeats', 'itself', '.'],
#  ['this', 'is', 'when', 'feelings', 'of', 'fear', 'arise', '.'],
#  ['this', 'was', 'always', 'bad', 'history', '.'],
#  ['what', 'about', 'inflation', 'targeting', '?'],
#  ...]

# %%
len(en_preprocessed), len(de_preprocessed)
# Out:
# (2000, 2000)

# %%
# for some of the sentences there is not german or english counterpart, i.e. only an empy array []
# therefore we will remove those sentence pairs.
en_preprocessed_clean, de_preprocessed_clean = [], []

for sent_en, sent_de in zip(en_preprocessed, de_preprocessed):
    if sent_en != [] and sent_de != []:
        en_preprocessed_clean.append(sent_en)
        de_preprocessed_clean.append(sent_de)
    else:
        continue

# %%
len(en_preprocessed_clean), len(de_preprocessed_clean)
# Out:
# (1992, 1992)

# %%
for e, d in zip(en_preprocessed_clean, de_preprocessed_clean[:5]):
    print('English:\n', e)
    print('German:\n', d, '\n'*3)
# Out:
# English:
#  ['wouldn', '’', 't', 'you', 'know', 'it', '?']
# German:
#  ['und', 'es', 'kam', ',', 'wie', 'es', 'kommen', 'musste', '.']
#
#
#
# English:
#  ['since', 'then', ',', 'the', 'index', 'has', 'climbed', 'above', '10,000', '.']
# German:
#  ['seit', 'damals', 'ist', 'er', 'auf', 'über', '10.000', 'punkte', 'gestiegen', '.']
#
#
#
# English:
#  ['they', 'departed', 'pledging', 'to', 'revive', 'europe', "'s", 'growth', '.']
# German:
#  ['mit', 'der', 'zusicherung', ',', 'das', 'wachstum', 'in', 'europa', 'wieder', 'zu', 'beleben', ',', 'gingen', 'sie', 'auseinander', '.']
#
#
#
# English:
#  ['we', "'ve", 'heard', 'that', 'empty', 'promise', 'before', '.']
# German:
#  ['dieses', 'leere', 'versprechen', 'haben', 'wir', 'schon', 'einmal', 'gehört', '.']
#
#
#
# English:
#  ['many', 'europeans', 'are', 'sick', 'of', 'british', 'vetoes', '.']
# German:
#  ['viele', 'europäer', 'sind', 'die', 'britischen', 'vetos', 'leid', '.']

# %%
en_most_common[:15], len(en_most_common), len(de_most_common)
# Out:
# ([('.', 1747),
#   ('the', 648),
#   ('is', 559),
#   (',', 437),
#   ('to', 297),
#   ('this', 258),
#   ('a', 239),
#   ('but', 234),
#   ('of', 213),
#   ('not', 197),
#   ('in', 193),
#   ('are', 192),
#   ('?', 184),
#   ('it', 182),
#   ('be', 161)],
#  3174,
#  7078)

# %%
# now we can create oyr lookup dicts for english and german, i.e. our vocab. 
# we will also include special tokens, later on used in the model. 
specials = ["<unk>", "<s>", "</s>", '<pad>']

en_word2ind, en_ind2word, en_vocab_size = nmt_data_utils.create_vocab(en_most_common, specials)
de_word2ind, de_ind2word, de_vocab_size = nmt_data_utils.create_vocab(de_most_common, specials)

# %%
# in order to feed the sentences to the network, we have to convert them to ints, corresponding to their indices
# in the lookup dicts. 
# we reverse the source language sentences, i.e. the english sentences as this alleviates learning for the seq2seq 
# model. Apart from this we also include EndOfSentence and StartOfSentence tags, which are needed as well. 
en_inds, en_unknowns = nmt_data_utils.convert_to_inds(en_preprocessed_clean, en_word2ind, reverse = True, eos = True)
de_inds, de_unknowns = nmt_data_utils.convert_to_inds(de_preprocessed_clean, de_word2ind, sos = True, eos = True)

# %%
[nmt_data_utils.convert_to_words(sentence, en_ind2word) for sentence in  en_inds[:2]]
# Out:
# [['?', 'it', 'know', 'you', 't', '’', 'wouldn', '</s>'],
#  ['.',
#   '10,000',
#   'above',
#   'climbed',
#   'has',
#   'index',
#   'the',
#   ',',
#   'then',
#   'since',
#   '</s>']]

# %%
[nmt_data_utils.convert_to_words(sentence, de_ind2word) for sentence in  de_inds[:2]]
# Out:
# [['<s>',
#   'und',
#   'es',
#   'kam',
#   ',',
#   'wie',
#   'es',
#   'kommen',
#   'musste',
#   '.',
#   '</s>'],
#  ['<s>',
#   'seit',
#   'damals',
#   'ist',
#   'er',
#   'auf',
#   'über',
#   '10.000',
#   'punkte',
#   'gestiegen',
#   '.',
#   '</s>']]

# %%
# hyperparams. 
# those are probably not perfect, but work fine for now. 
num_layers_encoder = 4
num_layers_decoder = 4
rnn_size_encoder = 128
rnn_size_decoder = 128
embedding_dim = 300

batch_size = 64
epochs = 100
clip = 5
keep_probability = 0.8
learning_rate = 0.01
learning_rate_decay_steps = 1000
learning_rate_decay = 0.9

# %%
# create the graph and train the model. 
nmt_model_utils.reset_graph()

nmt = NMT_Model.NMT(en_word2ind,
                    en_ind2word,
                    de_word2ind,
                    de_ind2word,
                    './models/local_one/my_model',
                    'TRAIN',
                    embedding_dim = embedding_dim,
                    num_layers_encoder = num_layers_encoder,
                    num_layers_decoder = num_layers_decoder,
                    batch_size = batch_size,
                    clip = clip,
                    keep_probability = keep_probability,
                    learning_rate = learning_rate,
                    epochs = epochs,
                    rnn_size_encoder = rnn_size_encoder,
                    rnn_size_decoder = rnn_size_decoder, 
                    learning_rate_decay_steps = learning_rate_decay_steps,
                    learning_rate_decay = learning_rate_decay)

nmt.build_graph()
nmt.train(en_inds, de_inds)
# Out:
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\ASUS\Documents\NMT_Model.py:106: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\ASUS\Documents\NMT_Model.py:181: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\ASUS\Documents\NMT_Model.py:331: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# Graph built.
# -------------------- Epoch 0 of 100 --------------------
# Iteration: 0 of 31	train_loss: 8.8653
# Iteration: 2 of 31	train_loss: 8.4463
# Iteration: 4 of 31	train_loss: 7.1339
# Iteration: 6 of 31	train_loss: 6.8159
# Iteration: 8 of 31	train_loss: 7.0711
# Iteration: 10 of 31	train_loss: 7.0807
# Iteration: 12 of 31	train_loss: 7.0201
# Iteration: 14 of 31	train_loss: 6.8361
# Iteration: 16 of 31	train_loss: 6.9670
# Iteration: 18 of 31	train_loss: 7.0574
# Iteration: 20 of 31	train_loss: 6.8662
# Iteration: 22 of 31	train_loss: 7.0604
# Iteration: 24 of 31	train_loss: 6.8980
# Iteration: 26 of 31	train_loss: 6.9197
# Iteration: 28 of 31	train_loss: 6.9503
# Iteration: 30 of 31	train_loss: 6.8232
# Iteration: 31 of 31	train_loss: 7.0771
# Average Score for this Epoch: 7.169303894042969
# --- new best score ---
#
#
# -------------------- Epoch 1 of 100 --------------------
# Iteration: 0 of 31	train_loss: 6.0073
# Iteration: 2 of 31	train_loss: 6.4457
# Iteration: 4 of 31	train_loss: 6.4075
# Iteration: 6 of 31	train_loss: 6.3022
# Iteration: 8 of 31	train_loss: 6.4283
# Iteration: 10 of 31	train_loss: 6.4720
# Iteration: 12 of 31	train_loss: 6.4719
# Iteration: 14 of 31	train_loss: 6.6273
# Iteration: 16 of 31	train_loss: 6.6254
# Iteration: 18 of 31	train_loss: 6.5437
# Iteration: 20 of 31	train_loss: 6.6219
# Iteration: 22 of 31	train_loss: 6.5978
# Iteration: 24 of 31	train_loss: 6.4457
# Iteration: 26 of 31	train_loss: 6.6926
# Iteration: 28 of 31	train_loss: 6.3469
# Iteration: 30 of 31	train_loss: 6.5616
# Iteration: 31 of 31	train_loss: 6.2893
# Average Score for this Epoch: 6.498200416564941
# --- new best score ---
#
#
# -------------------- Epoch 2 of 100 --------------------
# Iteration: 0 of 31	train_loss: 6.2045
# Iteration: 2 of 31	train_loss: 6.2120
# Iteration: 4 of 31	train_loss: 6.2892
# Iteration: 6 of 31	train_loss: 6.1993
# Iteration: 8 of 31	train_loss: 6.6417
# Iteration: 10 of 31	train_loss: 6.3098
# Iteration: 12 of 31	train_loss: 6.3899
# Iteration: 14 of 31	train_loss: 6.3526
# Iteration: 16 of 31	train_loss: 6.3894
# Iteration: 18 of 31	train_loss: 6.4196
# Iteration: 20 of 31	train_loss: 6.4791
# Iteration: 22 of 31	train_loss: 6.4452
# Iteration: 24 of 31	train_loss: 6.4825
# Iteration: 26 of 31	train_loss: 6.4772
# Iteration: 28 of 31	train_loss: 6.4664
# Iteration: 30 of 31	train_loss: 6.4766
# Iteration: 31 of 31	train_loss: 6.5592
# Average Score for this Epoch: 6.410079479217529
# --- new best score ---
#
#
# -------------------- Epoch 3 of 100 --------------------
# Iteration: 0 of 31	train_loss: 6.1041
# Iteration: 2 of 31	train_loss: 6.2020
# Iteration: 4 of 31	train_loss: 6.0941
# Iteration: 6 of 31	train_loss: 6.3007
# Iteration: 8 of 31	train_loss: 6.2940
# Iteration: 10 of 31	train_loss: 6.3077
# Iteration: 12 of 31	train_loss: 6.3193
# Iteration: 14 of 31	train_loss: 6.3930
# Iteration: 16 of 31	train_loss: 6.3121
# Iteration: 18 of 31	train_loss: 6.3846
# Iteration: 20 of 31	train_loss: 6.4173
# Iteration: 22 of 31	train_loss: 6.3335
# Iteration: 24 of 31	train_loss: 6.5301
# Iteration: 26 of 31	train_loss: 6.6071
# Iteration: 28 of 31	train_loss: 6.0890
# Iteration: 30 of 31	train_loss: 6.6544
# Iteration: 31 of 31	train_loss: 6.5392
# Average Score for this Epoch: 6.321743011474609
# --- new best score ---
#
#
# -------------------- Epoch 4 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.8166
# Iteration: 2 of 31	train_loss: 6.2185
# Iteration: 4 of 31	train_loss: 6.2220
# Iteration: 6 of 31	train_loss: 6.2613
# Iteration: 8 of 31	train_loss: 6.2236
# Iteration: 10 of 31	train_loss: 6.3318
# Iteration: 12 of 31	train_loss: 6.2995
# Iteration: 14 of 31	train_loss: 6.2515
# Iteration: 16 of 31	train_loss: 6.3240
# Iteration: 18 of 31	train_loss: 5.9616
# Iteration: 20 of 31	train_loss: 6.3630
# Iteration: 22 of 31	train_loss: 6.3924
# Iteration: 24 of 31	train_loss: 6.1876
# Iteration: 26 of 31	train_loss: 6.2652
# Iteration: 28 of 31	train_loss: 6.4317
# Iteration: 30 of 31	train_loss: 6.3327
# Iteration: 31 of 31	train_loss: 6.3404
# Average Score for this Epoch: 6.231605052947998
# --- new best score ---
#
#
# -------------------- Epoch 5 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.8792
# Iteration: 2 of 31	train_loss: 5.9510
# Iteration: 4 of 31	train_loss: 6.0030
# Iteration: 6 of 31	train_loss: 6.1407
# Iteration: 8 of 31	train_loss: 6.1139
# Iteration: 10 of 31	train_loss: 6.1521
# Iteration: 12 of 31	train_loss: 5.8766
# Iteration: 14 of 31	train_loss: 6.0724
# Iteration: 16 of 31	train_loss: 6.3053
# Iteration: 18 of 31	train_loss: 6.2099
# Iteration: 20 of 31	train_loss: 6.0045
# Iteration: 22 of 31	train_loss: 6.3024
# Iteration: 24 of 31	train_loss: 6.3396
# Iteration: 26 of 31	train_loss: 6.4388
# Iteration: 28 of 31	train_loss: 6.4931
# Iteration: 30 of 31	train_loss: 6.4120
# Iteration: 31 of 31	train_loss: 6.1770
# Average Score for this Epoch: 6.155817985534668
# --- new best score ---
#
#
# -------------------- Epoch 6 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.9795
# Iteration: 2 of 31	train_loss: 5.9098
# Iteration: 4 of 31	train_loss: 5.7364
# Iteration: 6 of 31	train_loss: 5.8089
# Iteration: 8 of 31	train_loss: 6.0826
# Iteration: 10 of 31	train_loss: 6.0308
# Iteration: 12 of 31	train_loss: 6.0036
# Iteration: 14 of 31	train_loss: 6.1119
# Iteration: 16 of 31	train_loss: 6.2347
# Iteration: 18 of 31	train_loss: 6.1552
# Iteration: 20 of 31	train_loss: 6.2790
# Iteration: 22 of 31	train_loss: 6.1305
# Iteration: 24 of 31	train_loss: 6.0180
# Iteration: 26 of 31	train_loss: 6.1656
# Iteration: 28 of 31	train_loss: 5.9797
# Iteration: 30 of 31	train_loss: 6.1254
# Iteration: 31 of 31	train_loss: 6.2276
# Average Score for this Epoch: 6.077038764953613
# --- new best score ---
#
#
# -------------------- Epoch 7 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.4664
# Iteration: 2 of 31	train_loss: 5.9574
# Iteration: 4 of 31	train_loss: 5.8121
# Iteration: 6 of 31	train_loss: 5.9419
# Iteration: 8 of 31	train_loss: 5.9821
# Iteration: 10 of 31	train_loss: 5.8944
# Iteration: 12 of 31	train_loss: 6.2822
# Iteration: 14 of 31	train_loss: 6.0512
# Iteration: 16 of 31	train_loss: 6.1870
# Iteration: 18 of 31	train_loss: 5.9481
# Iteration: 20 of 31	train_loss: 6.2107
# Iteration: 22 of 31	train_loss: 6.3617
# Iteration: 24 of 31	train_loss: 6.2235
# Iteration: 26 of 31	train_loss: 6.0859
# Iteration: 28 of 31	train_loss: 5.9916
# Iteration: 30 of 31	train_loss: 5.7031
# Iteration: 31 of 31	train_loss: 5.8459
# Average Score for this Epoch: 5.9936323165893555
# --- new best score ---
#
#
# -------------------- Epoch 8 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.7087
# Iteration: 2 of 31	train_loss: 5.6267
# Iteration: 4 of 31	train_loss: 5.6880
# Iteration: 6 of 31	train_loss: 5.7537
# Iteration: 8 of 31	train_loss: 5.6504
# Iteration: 10 of 31	train_loss: 5.8859
# Iteration: 12 of 31	train_loss: 6.1064
# Iteration: 14 of 31	train_loss: 6.0362
# Iteration: 16 of 31	train_loss: 5.9480
# Iteration: 18 of 31	train_loss: 5.7712
# Iteration: 20 of 31	train_loss: 6.0542
# Iteration: 22 of 31	train_loss: 6.0999
# Iteration: 24 of 31	train_loss: 6.0365
# Iteration: 26 of 31	train_loss: 6.2196
# Iteration: 28 of 31	train_loss: 6.3820
# Iteration: 30 of 31	train_loss: 6.2125
# Iteration: 31 of 31	train_loss: 5.7989
# Average Score for this Epoch: 5.948691368103027
# --- new best score ---
#
#
# -------------------- Epoch 9 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.5143
# Iteration: 2 of 31	train_loss: 5.6022
# Iteration: 4 of 31	train_loss: 5.5508
# Iteration: 6 of 31	train_loss: 5.6598
# Iteration: 8 of 31	train_loss: 5.8133
# Iteration: 10 of 31	train_loss: 6.0931
# Iteration: 12 of 31	train_loss: 5.9373
# Iteration: 14 of 31	train_loss: 5.9695
# Iteration: 16 of 31	train_loss: 6.1822
# Iteration: 18 of 31	train_loss: 5.6402
# Iteration: 20 of 31	train_loss: 6.0561
# Iteration: 22 of 31	train_loss: 5.9738
# Iteration: 24 of 31	train_loss: 6.2379
# Iteration: 26 of 31	train_loss: 5.9118
# Iteration: 28 of 31	train_loss: 5.8296
# Iteration: 30 of 31	train_loss: 6.1404
# Iteration: 31 of 31	train_loss: 5.7751
# Average Score for this Epoch: 5.872281551361084
# --- new best score ---
#
#
# -------------------- Epoch 10 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.3265
# Iteration: 2 of 31	train_loss: 5.7305
# Iteration: 4 of 31	train_loss: 5.6356
# Iteration: 6 of 31	train_loss: 5.7657
# Iteration: 8 of 31	train_loss: 5.6418
# Iteration: 10 of 31	train_loss: 5.7560
# Iteration: 12 of 31	train_loss: 5.8382
# Iteration: 14 of 31	train_loss: 5.6769
# Iteration: 16 of 31	train_loss: 5.9092
# Iteration: 18 of 31	train_loss: 5.6197
# Iteration: 20 of 31	train_loss: 5.9338
# Iteration: 22 of 31	train_loss: 6.0726
# Iteration: 24 of 31	train_loss: 6.0339
# Iteration: 26 of 31	train_loss: 6.0751
# Iteration: 28 of 31	train_loss: 5.8979
# Iteration: 30 of 31	train_loss: 6.0149
# Iteration: 31 of 31	train_loss: 5.5307
# Average Score for this Epoch: 5.806166648864746
# --- new best score ---
#
#
# -------------------- Epoch 11 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.6147
# Iteration: 2 of 31	train_loss: 5.7653
# Iteration: 4 of 31	train_loss: 5.6784
# Iteration: 6 of 31	train_loss: 5.6592
# Iteration: 8 of 31	train_loss: 5.7173
# Iteration: 10 of 31	train_loss: 5.8456
# Iteration: 12 of 31	train_loss: 5.8472
# Iteration: 14 of 31	train_loss: 5.4846
# Iteration: 16 of 31	train_loss: 5.7502
# Iteration: 18 of 31	train_loss: 5.5929
# Iteration: 20 of 31	train_loss: 5.7958
# Iteration: 22 of 31	train_loss: 5.9729
# Iteration: 24 of 31	train_loss: 5.8460
# Iteration: 26 of 31	train_loss: 5.7991
# Iteration: 28 of 31	train_loss: 5.9985
# Iteration: 30 of 31	train_loss: 6.0757
# Iteration: 31 of 31	train_loss: 5.8015
# Average Score for this Epoch: 5.7524495124816895
# --- new best score ---
#
#
# -------------------- Epoch 12 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.5500
# Iteration: 2 of 31	train_loss: 5.4937
# Iteration: 4 of 31	train_loss: 5.7344
# Iteration: 6 of 31	train_loss: 5.5537
# Iteration: 8 of 31	train_loss: 5.4432
# Iteration: 10 of 31	train_loss: 5.6910
# Iteration: 12 of 31	train_loss: 5.7565
# Iteration: 14 of 31	train_loss: 5.6625
# Iteration: 16 of 31	train_loss: 5.7814
# Iteration: 18 of 31	train_loss: 5.5636
# Iteration: 20 of 31	train_loss: 5.4708
# Iteration: 22 of 31	train_loss: 5.7967
# Iteration: 24 of 31	train_loss: 5.8542
# Iteration: 26 of 31	train_loss: 5.8948
# Iteration: 28 of 31	train_loss: 5.7548
# Iteration: 30 of 31	train_loss: 5.8393
# Iteration: 31 of 31	train_loss: 5.6651
# Average Score for this Epoch: 5.673013687133789
# --- new best score ---
#
#
# -------------------- Epoch 13 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.3905
# Iteration: 2 of 31	train_loss: 5.3809
# Iteration: 4 of 31	train_loss: 5.4978
# Iteration: 6 of 31	train_loss: 5.4147
# Iteration: 8 of 31	train_loss: 5.6777
# Iteration: 10 of 31	train_loss: 5.7377
# Iteration: 12 of 31	train_loss: 5.6900
# Iteration: 14 of 31	train_loss: 5.3953
# Iteration: 16 of 31	train_loss: 5.6466
# Iteration: 18 of 31	train_loss: 5.6749
# Iteration: 20 of 31	train_loss: 5.4154
# Iteration: 22 of 31	train_loss: 5.7568
# Iteration: 24 of 31	train_loss: 5.6632
# Iteration: 26 of 31	train_loss: 5.3557
# Iteration: 28 of 31	train_loss: 5.9260
# Iteration: 30 of 31	train_loss: 5.7624
# Iteration: 31 of 31	train_loss: 5.6052
# Average Score for this Epoch: 5.592546463012695
# --- new best score ---
#
#
# -------------------- Epoch 14 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.3229
# Iteration: 2 of 31	train_loss: 5.6127
# Iteration: 4 of 31	train_loss: 5.5418
# Iteration: 6 of 31	train_loss: 5.4265
# Iteration: 8 of 31	train_loss: 5.5783
# Iteration: 10 of 31	train_loss: 5.4917
# Iteration: 12 of 31	train_loss: 5.8430
# Iteration: 14 of 31	train_loss: 5.6543
# Iteration: 16 of 31	train_loss: 5.9075
# Iteration: 18 of 31	train_loss: 5.4552
# Iteration: 20 of 31	train_loss: 5.2338
# Iteration: 22 of 31	train_loss: 5.2783
# Iteration: 24 of 31	train_loss: 5.4616
# Iteration: 26 of 31	train_loss: 5.8304
# Iteration: 28 of 31	train_loss: 5.6396
# Iteration: 30 of 31	train_loss: 5.7885
# Iteration: 31 of 31	train_loss: 5.4298
# Average Score for this Epoch: 5.52067756652832
# --- new best score ---
#
#
# -------------------- Epoch 15 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.4336
# Iteration: 2 of 31	train_loss: 5.3463
# Iteration: 4 of 31	train_loss: 5.3311
# Iteration: 6 of 31	train_loss: 5.3432
# Iteration: 8 of 31	train_loss: 5.3271
# Iteration: 10 of 31	train_loss: 5.5724
# Iteration: 12 of 31	train_loss: 5.5687
# Iteration: 14 of 31	train_loss: 5.3547
# Iteration: 16 of 31	train_loss: 5.6397
# Iteration: 18 of 31	train_loss: 5.6644
# Iteration: 20 of 31	train_loss: 5.4575
# Iteration: 22 of 31	train_loss: 5.1469
# Iteration: 24 of 31	train_loss: 5.1754
# Iteration: 26 of 31	train_loss: 5.4549
# Iteration: 28 of 31	train_loss: 5.5768
# Iteration: 30 of 31	train_loss: 5.5863
# Iteration: 31 of 31	train_loss: 5.5580
# Average Score for this Epoch: 5.476025104522705
# --- new best score ---
#
#
# -------------------- Epoch 16 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.1754
# Iteration: 2 of 31	train_loss: 5.3604
# Iteration: 4 of 31	train_loss: 5.1898
# Iteration: 6 of 31	train_loss: 5.3319
# Iteration: 8 of 31	train_loss: 5.3036
# Iteration: 10 of 31	train_loss: 5.1263
# Iteration: 12 of 31	train_loss: 5.5344
# Iteration: 14 of 31	train_loss: 5.2016
# Iteration: 16 of 31	train_loss: 5.4583
# Iteration: 18 of 31	train_loss: 5.3501
# Iteration: 20 of 31	train_loss: 5.6420
# Iteration: 22 of 31	train_loss: 5.4045
# Iteration: 24 of 31	train_loss: 5.5321
# Iteration: 26 of 31	train_loss: 5.4340
# Iteration: 28 of 31	train_loss: 5.6089
# Iteration: 30 of 31	train_loss: 5.5025
# Iteration: 31 of 31	train_loss: 5.3539
# Average Score for this Epoch: 5.417840957641602
# --- new best score ---
#
#
# -------------------- Epoch 17 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.1713
# Iteration: 2 of 31	train_loss: 5.1686
# Iteration: 4 of 31	train_loss: 5.2671
# Iteration: 6 of 31	train_loss: 5.2961
# Iteration: 8 of 31	train_loss: 5.6109
# Iteration: 10 of 31	train_loss: 5.2769
# Iteration: 12 of 31	train_loss: 5.2554
# Iteration: 14 of 31	train_loss: 5.2247
# Iteration: 16 of 31	train_loss: 5.0182
# Iteration: 18 of 31	train_loss: 5.4454
# Iteration: 20 of 31	train_loss: 5.6186
# Iteration: 22 of 31	train_loss: 5.4431
# Iteration: 24 of 31	train_loss: 5.2431
# Iteration: 26 of 31	train_loss: 5.7433
# Iteration: 28 of 31	train_loss: 5.4801
# Iteration: 30 of 31	train_loss: 5.2917
# Iteration: 31 of 31	train_loss: 5.2876
# Average Score for this Epoch: 5.350543022155762
# --- new best score ---
#
#
# -------------------- Epoch 18 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.9016
# Iteration: 2 of 31	train_loss: 5.2784
# Iteration: 4 of 31	train_loss: 5.1539
# Iteration: 6 of 31	train_loss: 5.1099
# Iteration: 8 of 31	train_loss: 5.3132
# Iteration: 10 of 31	train_loss: 5.3005
# Iteration: 12 of 31	train_loss: 5.4459
# Iteration: 14 of 31	train_loss: 5.4224
# Iteration: 16 of 31	train_loss: 5.5011
# Iteration: 18 of 31	train_loss: 5.1750
# Iteration: 20 of 31	train_loss: 5.3760
# Iteration: 22 of 31	train_loss: 5.2476
# Iteration: 24 of 31	train_loss: 5.4469
# Iteration: 26 of 31	train_loss: 5.5463
# Iteration: 28 of 31	train_loss: 5.6332
# Iteration: 30 of 31	train_loss: 5.5181
# Iteration: 31 of 31	train_loss: 4.8796
# Average Score for this Epoch: 5.303221702575684
# --- new best score ---
#
#
# -------------------- Epoch 19 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.1240
# Iteration: 2 of 31	train_loss: 5.0241
# Iteration: 4 of 31	train_loss: 5.4014
# Iteration: 6 of 31	train_loss: 4.7928
# Iteration: 8 of 31	train_loss: 5.2449
# Iteration: 10 of 31	train_loss: 5.0314
# Iteration: 12 of 31	train_loss: 5.1574
# Iteration: 14 of 31	train_loss: 5.4303
# Iteration: 16 of 31	train_loss: 5.1252
# Iteration: 18 of 31	train_loss: 5.3112
# Iteration: 20 of 31	train_loss: 5.2106
# Iteration: 22 of 31	train_loss: 5.2349
# Iteration: 24 of 31	train_loss: 5.3945
# Iteration: 26 of 31	train_loss: 5.2620
# Iteration: 28 of 31	train_loss: 5.5403
# Iteration: 30 of 31	train_loss: 5.2601
# Iteration: 31 of 31	train_loss: 4.9401
# Average Score for this Epoch: 5.248141288757324
# --- new best score ---
#
#
# -------------------- Epoch 20 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.0565
# Iteration: 2 of 31	train_loss: 5.1237
# Iteration: 4 of 31	train_loss: 5.2559
# Iteration: 6 of 31	train_loss: 4.9933
# Iteration: 8 of 31	train_loss: 4.9784
# Iteration: 10 of 31	train_loss: 5.1183
# Iteration: 12 of 31	train_loss: 5.2101
# Iteration: 14 of 31	train_loss: 5.0369
# Iteration: 16 of 31	train_loss: 5.2375
# Iteration: 18 of 31	train_loss: 5.1550
# Iteration: 20 of 31	train_loss: 5.2413
# Iteration: 22 of 31	train_loss: 5.3220
# Iteration: 24 of 31	train_loss: 5.4668
# Iteration: 26 of 31	train_loss: 5.1562
# Iteration: 28 of 31	train_loss: 4.9693
# Iteration: 30 of 31	train_loss: 5.4612
# Iteration: 31 of 31	train_loss: 5.2048
# Average Score for this Epoch: 5.2084197998046875
# --- new best score ---
#
#
# -------------------- Epoch 21 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.9629
# Iteration: 2 of 31	train_loss: 4.8248
# Iteration: 4 of 31	train_loss: 5.0662
# Iteration: 6 of 31	train_loss: 4.8944
# Iteration: 8 of 31	train_loss: 5.0232
# Iteration: 10 of 31	train_loss: 5.1920
# Iteration: 12 of 31	train_loss: 5.0789
# Iteration: 14 of 31	train_loss: 5.2763
# Iteration: 16 of 31	train_loss: 5.1863
# Iteration: 18 of 31	train_loss: 5.4285
# Iteration: 20 of 31	train_loss: 5.0557
# Iteration: 22 of 31	train_loss: 5.4121
# Iteration: 24 of 31	train_loss: 5.3182
# Iteration: 26 of 31	train_loss: 5.2475
# Iteration: 28 of 31	train_loss: 5.1382
# Iteration: 30 of 31	train_loss: 5.2324
# Iteration: 31 of 31	train_loss: 5.0245
# Average Score for this Epoch: 5.154926300048828
# --- new best score ---
#
#
# -------------------- Epoch 22 of 100 --------------------
# Iteration: 0 of 31	train_loss: 5.0525
# Iteration: 2 of 31	train_loss: 4.7952
# Iteration: 4 of 31	train_loss: 4.8413
# Iteration: 6 of 31	train_loss: 5.1005
# Iteration: 8 of 31	train_loss: 5.2119
# Iteration: 10 of 31	train_loss: 5.0909
# Iteration: 12 of 31	train_loss: 5.3379
# Iteration: 14 of 31	train_loss: 5.1814
# Iteration: 16 of 31	train_loss: 5.0271
# Iteration: 18 of 31	train_loss: 5.0962
# Iteration: 20 of 31	train_loss: 5.2724
# Iteration: 22 of 31	train_loss: 5.0698
# Iteration: 24 of 31	train_loss: 5.1921
# Iteration: 26 of 31	train_loss: 4.9971
# Iteration: 28 of 31	train_loss: 5.3640
# Iteration: 30 of 31	train_loss: 5.3052
# Iteration: 31 of 31	train_loss: 5.0570
# Average Score for this Epoch: 5.104687690734863
# --- new best score ---
#
#
# -------------------- Epoch 23 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.9898
# Iteration: 2 of 31	train_loss: 4.9734
# Iteration: 4 of 31	train_loss: 5.0423
# Iteration: 6 of 31	train_loss: 4.7405
# Iteration: 8 of 31	train_loss: 4.8617
# Iteration: 10 of 31	train_loss: 5.1096
# Iteration: 12 of 31	train_loss: 5.2981
# Iteration: 14 of 31	train_loss: 5.2067
# Iteration: 16 of 31	train_loss: 5.3029
# Iteration: 18 of 31	train_loss: 5.1432
# Iteration: 20 of 31	train_loss: 4.8629
# Iteration: 22 of 31	train_loss: 5.2378
# Iteration: 24 of 31	train_loss: 5.0739
# Iteration: 26 of 31	train_loss: 5.3257
# Iteration: 28 of 31	train_loss: 5.4421
# Iteration: 30 of 31	train_loss: 5.0864
# Iteration: 31 of 31	train_loss: 4.8322
# Average Score for this Epoch: 5.055637836456299
# --- new best score ---
#
#
# -------------------- Epoch 24 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5416
# Iteration: 2 of 31	train_loss: 4.8394
# Iteration: 4 of 31	train_loss: 4.9401
# Iteration: 6 of 31	train_loss: 5.1601
# Iteration: 8 of 31	train_loss: 4.7304
# Iteration: 10 of 31	train_loss: 5.1254
# Iteration: 12 of 31	train_loss: 4.7386
# Iteration: 14 of 31	train_loss: 5.0476
# Iteration: 16 of 31	train_loss: 5.0383
# Iteration: 18 of 31	train_loss: 4.7959
# Iteration: 20 of 31	train_loss: 5.1374
# Iteration: 22 of 31	train_loss: 5.0611
# Iteration: 24 of 31	train_loss: 4.9946
# Iteration: 26 of 31	train_loss: 5.0974
# Iteration: 28 of 31	train_loss: 4.8276
# Iteration: 30 of 31	train_loss: 5.2473
# Iteration: 31 of 31	train_loss: 4.7943
# Average Score for this Epoch: 4.998185634613037
# --- new best score ---
#
#
# -------------------- Epoch 25 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.9876
# Iteration: 2 of 31	train_loss: 4.8007
# Iteration: 4 of 31	train_loss: 4.9968
# Iteration: 6 of 31	train_loss: 4.9941
# Iteration: 8 of 31	train_loss: 4.7222
# Iteration: 10 of 31	train_loss: 4.7319
# Iteration: 12 of 31	train_loss: 4.7187
# Iteration: 14 of 31	train_loss: 5.0731
# Iteration: 16 of 31	train_loss: 5.0378
# Iteration: 18 of 31	train_loss: 4.7704
# Iteration: 20 of 31	train_loss: 4.7767
# Iteration: 22 of 31	train_loss: 5.1699
# Iteration: 24 of 31	train_loss: 5.0763
# Iteration: 26 of 31	train_loss: 5.1301
# Iteration: 28 of 31	train_loss: 5.0058
# Iteration: 30 of 31	train_loss: 5.3376
# Iteration: 31 of 31	train_loss: 4.8569
# Average Score for this Epoch: 4.9547929763793945
# --- new best score ---
#
#
# -------------------- Epoch 26 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.8129
# Iteration: 2 of 31	train_loss: 4.7690
# Iteration: 4 of 31	train_loss: 4.7029
# Iteration: 6 of 31	train_loss: 4.9111
# Iteration: 8 of 31	train_loss: 5.2103
# Iteration: 10 of 31	train_loss: 4.9214
# Iteration: 12 of 31	train_loss: 4.8764
# Iteration: 14 of 31	train_loss: 4.6114
# Iteration: 16 of 31	train_loss: 4.7610
# Iteration: 18 of 31	train_loss: 5.1600
# Iteration: 20 of 31	train_loss: 4.7100
# Iteration: 22 of 31	train_loss: 4.8938
# Iteration: 24 of 31	train_loss: 5.1083
# Iteration: 26 of 31	train_loss: 4.9285
# Iteration: 28 of 31	train_loss: 5.1316
# Iteration: 30 of 31	train_loss: 4.8982
# Iteration: 31 of 31	train_loss: 4.7674
# Average Score for this Epoch: 4.886694431304932
# --- new best score ---
#
#
# -------------------- Epoch 27 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.7756
# Iteration: 2 of 31	train_loss: 4.7735
# Iteration: 4 of 31	train_loss: 4.6290
# Iteration: 6 of 31	train_loss: 4.8507
# Iteration: 8 of 31	train_loss: 4.9216
# Iteration: 10 of 31	train_loss: 4.9343
# Iteration: 12 of 31	train_loss: 4.5311
# Iteration: 14 of 31	train_loss: 4.9716
# Iteration: 16 of 31	train_loss: 4.9696
# Iteration: 18 of 31	train_loss: 5.0663
# Iteration: 20 of 31	train_loss: 4.9135
# Iteration: 22 of 31	train_loss: 5.0362
# Iteration: 24 of 31	train_loss: 4.9583
# Iteration: 26 of 31	train_loss: 4.9478
# Iteration: 28 of 31	train_loss: 4.9021
# Iteration: 30 of 31	train_loss: 4.9111
# Iteration: 31 of 31	train_loss: 4.7191
# Average Score for this Epoch: 4.860458850860596
# --- new best score ---
#
#
# -------------------- Epoch 28 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.6927
# Iteration: 2 of 31	train_loss: 4.8663
# Iteration: 4 of 31	train_loss: 4.5990
# Iteration: 6 of 31	train_loss: 4.9610
# Iteration: 8 of 31	train_loss: 4.5346
# Iteration: 10 of 31	train_loss: 4.6825
# Iteration: 12 of 31	train_loss: 4.6003
# Iteration: 14 of 31	train_loss: 4.8936
# Iteration: 16 of 31	train_loss: 4.7054
# Iteration: 18 of 31	train_loss: 5.0219
# Iteration: 20 of 31	train_loss: 4.9747
# Iteration: 22 of 31	train_loss: 4.8350
# Iteration: 24 of 31	train_loss: 4.8210
# Iteration: 26 of 31	train_loss: 5.0209
# Iteration: 28 of 31	train_loss: 4.8098
# Iteration: 30 of 31	train_loss: 4.7396
# Iteration: 31 of 31	train_loss: 4.6432
# Average Score for this Epoch: 4.807560443878174
# --- new best score ---
#
#
# -------------------- Epoch 29 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.7558
# Iteration: 2 of 31	train_loss: 4.5991
# Iteration: 4 of 31	train_loss: 4.8351
# Iteration: 6 of 31	train_loss: 4.7847
# Iteration: 8 of 31	train_loss: 4.8336
# Iteration: 10 of 31	train_loss: 4.7530
# Iteration: 12 of 31	train_loss: 4.7503
# Iteration: 14 of 31	train_loss: 4.8550
# Iteration: 16 of 31	train_loss: 4.6906
# Iteration: 18 of 31	train_loss: 4.4441
# Iteration: 20 of 31	train_loss: 4.5957
# Iteration: 22 of 31	train_loss: 4.6865
# Iteration: 24 of 31	train_loss: 4.8505
# Iteration: 26 of 31	train_loss: 4.8554
# Iteration: 28 of 31	train_loss: 4.6690
# Iteration: 30 of 31	train_loss: 4.6778
# Iteration: 31 of 31	train_loss: 4.7457
# Average Score for this Epoch: 4.768044471740723
# --- new best score ---
#
#
# -------------------- Epoch 30 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.7010
# Iteration: 2 of 31	train_loss: 4.7827
# Iteration: 4 of 31	train_loss: 5.0304
# Iteration: 6 of 31	train_loss: 4.5321
# Iteration: 8 of 31	train_loss: 4.3845
# Iteration: 10 of 31	train_loss: 4.5311
# Iteration: 12 of 31	train_loss: 4.7123
# Iteration: 14 of 31	train_loss: 4.6562
# Iteration: 16 of 31	train_loss: 4.6435
# Iteration: 18 of 31	train_loss: 4.8626
# Iteration: 20 of 31	train_loss: 4.8174
# Iteration: 22 of 31	train_loss: 4.7114
# Iteration: 24 of 31	train_loss: 4.6799
# Iteration: 26 of 31	train_loss: 4.7943
# Iteration: 28 of 31	train_loss: 4.8284
# Iteration: 30 of 31	train_loss: 4.9416
# Iteration: 31 of 31	train_loss: 4.7359
# Average Score for this Epoch: 4.725493431091309
# --- new best score ---
#
#
# -------------------- Epoch 31 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5355
# Iteration: 2 of 31	train_loss: 4.4735
# Iteration: 4 of 31	train_loss: 4.8709
# Iteration: 6 of 31	train_loss: 4.9097
# Iteration: 8 of 31	train_loss: 4.4368
# Iteration: 10 of 31	train_loss: 4.9114
# Iteration: 12 of 31	train_loss: 4.5346
# Iteration: 14 of 31	train_loss: 4.6893
# Iteration: 16 of 31	train_loss: 4.6002
# Iteration: 18 of 31	train_loss: 4.5740
# Iteration: 20 of 31	train_loss: 4.8022
# Iteration: 22 of 31	train_loss: 4.4231
# Iteration: 24 of 31	train_loss: 4.8455
# Iteration: 26 of 31	train_loss: 4.7897
# Iteration: 28 of 31	train_loss: 4.7966
# Iteration: 30 of 31	train_loss: 5.0604
# Iteration: 31 of 31	train_loss: 4.4242
# Average Score for this Epoch: 4.688981533050537
# --- new best score ---
#
#
# -------------------- Epoch 32 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5427
# Iteration: 2 of 31	train_loss: 4.3742
# Iteration: 4 of 31	train_loss: 4.4218
# Iteration: 6 of 31	train_loss: 4.6794
# Iteration: 8 of 31	train_loss: 4.8490
# Iteration: 10 of 31	train_loss: 4.5508
# Iteration: 12 of 31	train_loss: 4.6236
# Iteration: 14 of 31	train_loss: 4.5842
# Iteration: 16 of 31	train_loss: 5.0297
# Iteration: 18 of 31	train_loss: 4.5315
# Iteration: 20 of 31	train_loss: 4.9178
# Iteration: 22 of 31	train_loss: 4.6462
# Iteration: 24 of 31	train_loss: 4.5831
# Iteration: 26 of 31	train_loss: 4.5001
# Iteration: 28 of 31	train_loss: 4.9596
# Iteration: 30 of 31	train_loss: 4.5786
# Iteration: 31 of 31	train_loss: 4.5402
# Average Score for this Epoch: 4.645637512207031
# --- new best score ---
#
#
# -------------------- Epoch 33 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.4943
# Iteration: 2 of 31	train_loss: 4.5926
# Iteration: 4 of 31	train_loss: 4.3797
# Iteration: 6 of 31	train_loss: 4.3066
# Iteration: 8 of 31	train_loss: 4.7604
# Iteration: 10 of 31	train_loss: 4.6206
# Iteration: 12 of 31	train_loss: 4.4474
# Iteration: 14 of 31	train_loss: 4.6197
# Iteration: 16 of 31	train_loss: 4.6777
# Iteration: 18 of 31	train_loss: 4.6583
# Iteration: 20 of 31	train_loss: 4.7818
# Iteration: 22 of 31	train_loss: 4.6590
# Iteration: 24 of 31	train_loss: 4.7633
# Iteration: 26 of 31	train_loss: 4.5871
# Iteration: 28 of 31	train_loss: 4.5202
# Iteration: 30 of 31	train_loss: 4.5649
# Iteration: 31 of 31	train_loss: 4.5441
# Average Score for this Epoch: 4.617339611053467
# --- new best score ---
#
#
# -------------------- Epoch 34 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.6749
# Iteration: 2 of 31	train_loss: 4.4745
# Iteration: 4 of 31	train_loss: 4.4628
# Iteration: 6 of 31	train_loss: 4.5066
# Iteration: 8 of 31	train_loss: 4.6261
# Iteration: 10 of 31	train_loss: 4.2110
# Iteration: 12 of 31	train_loss: 4.9423
# Iteration: 14 of 31	train_loss: 4.5267
# Iteration: 16 of 31	train_loss: 4.5506
# Iteration: 18 of 31	train_loss: 4.5347
# Iteration: 20 of 31	train_loss: 4.7475
# Iteration: 22 of 31	train_loss: 4.7736
# Iteration: 24 of 31	train_loss: 4.3969
# Iteration: 26 of 31	train_loss: 4.7820
# Iteration: 28 of 31	train_loss: 4.7444
# Iteration: 30 of 31	train_loss: 4.6250
# Iteration: 31 of 31	train_loss: 4.6397
# Average Score for this Epoch: 4.583913803100586
# --- new best score ---
#
#
# -------------------- Epoch 35 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.0434
# Iteration: 2 of 31	train_loss: 4.3894
# Iteration: 4 of 31	train_loss: 4.5193
# Iteration: 6 of 31	train_loss: 4.4822
# Iteration: 8 of 31	train_loss: 4.2743
# Iteration: 10 of 31	train_loss: 4.3812
# Iteration: 12 of 31	train_loss: 4.7595
# Iteration: 14 of 31	train_loss: 4.7558
# Iteration: 16 of 31	train_loss: 4.7529
# Iteration: 18 of 31	train_loss: 4.6756
# Iteration: 20 of 31	train_loss: 4.8173
# Iteration: 22 of 31	train_loss: 4.7297
# Iteration: 24 of 31	train_loss: 4.6977
# Iteration: 26 of 31	train_loss: 4.7366
# Iteration: 28 of 31	train_loss: 4.6220
# Iteration: 30 of 31	train_loss: 4.7707
# Iteration: 31 of 31	train_loss: 4.1869
# Average Score for this Epoch: 4.546910285949707
# --- new best score ---
#
#
# -------------------- Epoch 36 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5962
# Iteration: 2 of 31	train_loss: 4.6821
# Iteration: 4 of 31	train_loss: 4.6222
# Iteration: 6 of 31	train_loss: 4.3352
# Iteration: 8 of 31	train_loss: 4.4903
# Iteration: 10 of 31	train_loss: 4.5644
# Iteration: 12 of 31	train_loss: 4.5146
# Iteration: 14 of 31	train_loss: 4.5531
# Iteration: 16 of 31	train_loss: 4.2275
# Iteration: 18 of 31	train_loss: 4.6474
# Iteration: 20 of 31	train_loss: 4.5354
# Iteration: 22 of 31	train_loss: 4.3421
# Iteration: 24 of 31	train_loss: 4.4447
# Iteration: 26 of 31	train_loss: 4.6106
# Iteration: 28 of 31	train_loss: 4.6975
# Iteration: 30 of 31	train_loss: 4.7346
# Iteration: 31 of 31	train_loss: 4.5478
# Average Score for this Epoch: 4.525844097137451
# --- new best score ---
#
#
# -------------------- Epoch 37 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5977
# Iteration: 2 of 31	train_loss: 4.2155
# Iteration: 4 of 31	train_loss: 4.6465
# Iteration: 6 of 31	train_loss: 4.3689
# Iteration: 8 of 31	train_loss: 4.5565
# Iteration: 10 of 31	train_loss: 4.5578
# Iteration: 12 of 31	train_loss: 4.2414
# Iteration: 14 of 31	train_loss: 4.4744
# Iteration: 16 of 31	train_loss: 4.6397
# Iteration: 18 of 31	train_loss: 4.2595
# Iteration: 20 of 31	train_loss: 4.1452
# Iteration: 22 of 31	train_loss: 4.5627
# Iteration: 24 of 31	train_loss: 4.4401
# Iteration: 26 of 31	train_loss: 4.4064
# Iteration: 28 of 31	train_loss: 4.4794
# Iteration: 30 of 31	train_loss: 4.8185
# Iteration: 31 of 31	train_loss: 4.4091
# Average Score for this Epoch: 4.502603530883789
# --- new best score ---
#
#
# -------------------- Epoch 38 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.2539
# Iteration: 2 of 31	train_loss: 4.3628
# Iteration: 4 of 31	train_loss: 4.4401
# Iteration: 6 of 31	train_loss: 4.3263
# Iteration: 8 of 31	train_loss: 4.4743
# Iteration: 10 of 31	train_loss: 4.9179
# Iteration: 12 of 31	train_loss: 4.2922
# Iteration: 14 of 31	train_loss: 4.5001
# Iteration: 16 of 31	train_loss: 4.6070
# Iteration: 18 of 31	train_loss: 4.6704
# Iteration: 20 of 31	train_loss: 4.2844
# Iteration: 22 of 31	train_loss: 4.2062
# Iteration: 24 of 31	train_loss: 4.4843
# Iteration: 26 of 31	train_loss: 4.6055
# Iteration: 28 of 31	train_loss: 4.0798
# Iteration: 30 of 31	train_loss: 4.4701
# Iteration: 31 of 31	train_loss: 4.3565
# Average Score for this Epoch: 4.469448089599609
# --- new best score ---
#
#
# -------------------- Epoch 39 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.1995
# Iteration: 2 of 31	train_loss: 4.5546
# Iteration: 4 of 31	train_loss: 4.5060
# Iteration: 6 of 31	train_loss: 4.5001
# Iteration: 8 of 31	train_loss: 4.5099
# Iteration: 10 of 31	train_loss: 4.2878
# Iteration: 12 of 31	train_loss: 4.5528
# Iteration: 14 of 31	train_loss: 4.3846
# Iteration: 16 of 31	train_loss: 4.6675
# Iteration: 18 of 31	train_loss: 4.3503
# Iteration: 20 of 31	train_loss: 4.3803
# Iteration: 22 of 31	train_loss: 4.4238
# Iteration: 24 of 31	train_loss: 4.4643
# Iteration: 26 of 31	train_loss: 4.2587
# Iteration: 28 of 31	train_loss: 4.0497
# Iteration: 30 of 31	train_loss: 4.4869
# Iteration: 31 of 31	train_loss: 4.1633
# Average Score for this Epoch: 4.442392349243164
# --- new best score ---
#
#
# -------------------- Epoch 40 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.2069
# Iteration: 2 of 31	train_loss: 4.4800
# Iteration: 4 of 31	train_loss: 4.4152
# Iteration: 6 of 31	train_loss: 4.3965
# Iteration: 8 of 31	train_loss: 4.1863
# Iteration: 10 of 31	train_loss: 4.3733
# Iteration: 12 of 31	train_loss: 4.3769
# Iteration: 14 of 31	train_loss: 4.4142
# Iteration: 16 of 31	train_loss: 4.5371
# Iteration: 18 of 31	train_loss: 4.2235
# Iteration: 20 of 31	train_loss: 4.5580
# Iteration: 22 of 31	train_loss: 4.2284
# Iteration: 24 of 31	train_loss: 4.5474
# Iteration: 26 of 31	train_loss: 4.7420
# Iteration: 28 of 31	train_loss: 4.7131
# Iteration: 30 of 31	train_loss: 4.6893
# Iteration: 31 of 31	train_loss: 4.1555
# Average Score for this Epoch: 4.422485828399658
# --- new best score ---
#
#
# -------------------- Epoch 41 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.0113
# Iteration: 2 of 31	train_loss: 4.4851
# Iteration: 4 of 31	train_loss: 4.1569
# Iteration: 6 of 31	train_loss: 4.2791
# Iteration: 8 of 31	train_loss: 4.4457
# Iteration: 10 of 31	train_loss: 4.0743
# Iteration: 12 of 31	train_loss: 4.4387
# Iteration: 14 of 31	train_loss: 4.4968
# Iteration: 16 of 31	train_loss: 4.2016
# Iteration: 18 of 31	train_loss: 3.9296
# Iteration: 20 of 31	train_loss: 4.6117
# Iteration: 22 of 31	train_loss: 4.5546
# Iteration: 24 of 31	train_loss: 4.5913
# Iteration: 26 of 31	train_loss: 4.4559
# Iteration: 28 of 31	train_loss: 4.5273
# Iteration: 30 of 31	train_loss: 4.6469
# Iteration: 31 of 31	train_loss: 3.8336
# Average Score for this Epoch: 4.389203071594238
# --- new best score ---
#
#
# -------------------- Epoch 42 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.4725
# Iteration: 2 of 31	train_loss: 4.5061
# Iteration: 4 of 31	train_loss: 4.3469
# Iteration: 6 of 31	train_loss: 3.9066
# Iteration: 8 of 31	train_loss: 4.1848
# Iteration: 10 of 31	train_loss: 4.5375
# Iteration: 12 of 31	train_loss: 4.4338
# Iteration: 14 of 31	train_loss: 4.4454
# Iteration: 16 of 31	train_loss: 4.4453
# Iteration: 18 of 31	train_loss: 4.1530
# Iteration: 20 of 31	train_loss: 4.5027
# Iteration: 22 of 31	train_loss: 4.1236
# Iteration: 24 of 31	train_loss: 4.4919
# Iteration: 26 of 31	train_loss: 4.1995
# Iteration: 28 of 31	train_loss: 4.3183
# Iteration: 30 of 31	train_loss: 4.3053
# Iteration: 31 of 31	train_loss: 4.5007
# Average Score for this Epoch: 4.382875442504883
# --- new best score ---
#
#
# -------------------- Epoch 43 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5009
# Iteration: 2 of 31	train_loss: 4.0252
# Iteration: 4 of 31	train_loss: 4.3675
# Iteration: 6 of 31	train_loss: 4.1030
# Iteration: 8 of 31	train_loss: 4.4287
# Iteration: 10 of 31	train_loss: 4.3093
# Iteration: 12 of 31	train_loss: 4.3528
# Iteration: 14 of 31	train_loss: 4.5483
# Iteration: 16 of 31	train_loss: 4.2827
# Iteration: 18 of 31	train_loss: 4.6195
# Iteration: 20 of 31	train_loss: 4.4013
# Iteration: 22 of 31	train_loss: 4.5710
# Iteration: 24 of 31	train_loss: 4.5304
# Iteration: 26 of 31	train_loss: 4.5876
# Iteration: 28 of 31	train_loss: 4.3341
# Iteration: 30 of 31	train_loss: 4.2962
# Iteration: 31 of 31	train_loss: 4.5874
# Average Score for this Epoch: 4.364894866943359
# --- new best score ---
#
#
# -------------------- Epoch 44 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.0808
# Iteration: 2 of 31	train_loss: 3.9738
# Iteration: 4 of 31	train_loss: 4.6103
# Iteration: 6 of 31	train_loss: 4.4396
# Iteration: 8 of 31	train_loss: 4.0320
# Iteration: 10 of 31	train_loss: 4.0142
# Iteration: 12 of 31	train_loss: 4.6390
# Iteration: 14 of 31	train_loss: 4.2262
# Iteration: 16 of 31	train_loss: 4.4529
# Iteration: 18 of 31	train_loss: 4.5169
# Iteration: 20 of 31	train_loss: 4.4780
# Iteration: 22 of 31	train_loss: 4.4801
# Iteration: 24 of 31	train_loss: 4.5409
# Iteration: 26 of 31	train_loss: 4.6553
# Iteration: 28 of 31	train_loss: 3.9441
# Iteration: 30 of 31	train_loss: 4.3938
# Iteration: 31 of 31	train_loss: 4.1625
# Average Score for this Epoch: 4.32390022277832
# --- new best score ---
#
#
# -------------------- Epoch 45 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.0980
# Iteration: 2 of 31	train_loss: 4.2489
# Iteration: 4 of 31	train_loss: 4.3942
# Iteration: 6 of 31	train_loss: 4.0579
# Iteration: 8 of 31	train_loss: 4.3267
# Iteration: 10 of 31	train_loss: 4.4076
# Iteration: 12 of 31	train_loss: 4.2030
# Iteration: 14 of 31	train_loss: 3.9182
# Iteration: 16 of 31	train_loss: 4.2822
# Iteration: 18 of 31	train_loss: 4.2849
# Iteration: 20 of 31	train_loss: 4.4226
# Iteration: 22 of 31	train_loss: 4.3420
# Iteration: 24 of 31	train_loss: 4.3789
# Iteration: 26 of 31	train_loss: 4.0568
# Iteration: 28 of 31	train_loss: 4.0975
# Iteration: 30 of 31	train_loss: 4.4041
# Iteration: 31 of 31	train_loss: 4.0517
# Average Score for this Epoch: 4.306139945983887
# --- new best score ---
#
#
# -------------------- Epoch 46 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.5194
# Iteration: 2 of 31	train_loss: 4.0951
# Iteration: 4 of 31	train_loss: 4.0100
# Iteration: 6 of 31	train_loss: 4.2321
# Iteration: 8 of 31	train_loss: 4.2241
# Iteration: 10 of 31	train_loss: 4.3373
# Iteration: 12 of 31	train_loss: 4.2013
# Iteration: 14 of 31	train_loss: 4.0486
# Iteration: 16 of 31	train_loss: 4.4726
# Iteration: 18 of 31	train_loss: 4.4791
# Iteration: 20 of 31	train_loss: 4.2245
# Iteration: 22 of 31	train_loss: 4.1164
# Iteration: 24 of 31	train_loss: 4.3676
# Iteration: 26 of 31	train_loss: 4.3584
# Iteration: 28 of 31	train_loss: 4.4497
# Iteration: 30 of 31	train_loss: 4.2943
# Iteration: 31 of 31	train_loss: 4.5765
# Average Score for this Epoch: 4.302920341491699
# --- new best score ---
#
#
# -------------------- Epoch 47 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.0272
# Iteration: 2 of 31	train_loss: 4.0772
# Iteration: 4 of 31	train_loss: 4.0995
# Iteration: 6 of 31	train_loss: 4.2861
# Iteration: 8 of 31	train_loss: 4.2980
# Iteration: 10 of 31	train_loss: 4.5054
# Iteration: 12 of 31	train_loss: 4.3835
# Iteration: 14 of 31	train_loss: 4.2577
# Iteration: 16 of 31	train_loss: 4.4659
# Iteration: 18 of 31	train_loss: 3.8515
# Iteration: 20 of 31	train_loss: 4.3867
# Iteration: 22 of 31	train_loss: 4.5984
# Iteration: 24 of 31	train_loss: 4.1568
# Iteration: 26 of 31	train_loss: 3.7609
# Iteration: 28 of 31	train_loss: 4.1615
# Iteration: 30 of 31	train_loss: 4.6985
# Iteration: 31 of 31	train_loss: 3.9504
# Average Score for this Epoch: 4.263037204742432
# --- new best score ---
#
#
# -------------------- Epoch 48 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.2119
# Iteration: 2 of 31	train_loss: 4.3657
# Iteration: 4 of 31	train_loss: 3.8453
# Iteration: 6 of 31	train_loss: 4.4882
# Iteration: 8 of 31	train_loss: 3.9203
# Iteration: 10 of 31	train_loss: 4.0258
# Iteration: 12 of 31	train_loss: 4.3681
# Iteration: 14 of 31	train_loss: 4.3612
# Iteration: 16 of 31	train_loss: 4.1589
# Iteration: 18 of 31	train_loss: 4.3936
# Iteration: 20 of 31	train_loss: 4.2757
# Iteration: 22 of 31	train_loss: 3.8408
# Iteration: 24 of 31	train_loss: 4.6758
# Iteration: 26 of 31	train_loss: 4.6066
# Iteration: 28 of 31	train_loss: 4.1883
# Iteration: 30 of 31	train_loss: 4.5918
# Iteration: 31 of 31	train_loss: 4.1351
# Average Score for this Epoch: 4.243043899536133
# --- new best score ---
#
#
# -------------------- Epoch 49 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.2493
# Iteration: 2 of 31	train_loss: 4.2360
# Iteration: 4 of 31	train_loss: 4.2471
# Iteration: 6 of 31	train_loss: 4.3872
# Iteration: 8 of 31	train_loss: 4.1885
# Iteration: 10 of 31	train_loss: 4.2572
# Iteration: 12 of 31	train_loss: 4.2215
# Iteration: 14 of 31	train_loss: 4.4021
# Iteration: 16 of 31	train_loss: 4.1007
# Iteration: 18 of 31	train_loss: 4.4065
# Iteration: 20 of 31	train_loss: 4.1639
# Iteration: 22 of 31	train_loss: 4.2742
# Iteration: 24 of 31	train_loss: 4.3357
# Iteration: 26 of 31	train_loss: 4.3956
# Iteration: 28 of 31	train_loss: 4.5420
# Iteration: 30 of 31	train_loss: 4.4759
# Iteration: 31 of 31	train_loss: 4.4342
# Average Score for this Epoch: 4.239203453063965
# --- new best score ---
#
#
# -------------------- Epoch 50 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.1877
# Iteration: 2 of 31	train_loss: 3.7931
# Iteration: 4 of 31	train_loss: 4.3174
# Iteration: 6 of 31	train_loss: 3.9586
# Iteration: 8 of 31	train_loss: 3.9007
# Iteration: 10 of 31	train_loss: 4.0787
# Iteration: 12 of 31	train_loss: 4.1925
# Iteration: 14 of 31	train_loss: 4.1691
# Iteration: 16 of 31	train_loss: 4.3383
# Iteration: 18 of 31	train_loss: 4.2849
# Iteration: 20 of 31	train_loss: 4.5090
# Iteration: 22 of 31	train_loss: 4.3076
# Iteration: 24 of 31	train_loss: 4.6643
# Iteration: 26 of 31	train_loss: 4.2931
# Iteration: 28 of 31	train_loss: 4.2341
# Iteration: 30 of 31	train_loss: 4.4071
# Iteration: 31 of 31	train_loss: 4.2771
# Average Score for this Epoch: 4.219595909118652
# --- new best score ---
#
#
# -------------------- Epoch 51 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.2966
# Iteration: 2 of 31	train_loss: 4.0080
# Iteration: 4 of 31	train_loss: 4.0988
# Iteration: 6 of 31	train_loss: 4.1779
# Iteration: 8 of 31	train_loss: 4.4062
# Iteration: 10 of 31	train_loss: 4.1975
# Iteration: 12 of 31	train_loss: 4.1257
# Iteration: 14 of 31	train_loss: 4.4183
# Iteration: 16 of 31	train_loss: 3.8533
# Iteration: 18 of 31	train_loss: 4.1142
# Iteration: 20 of 31	train_loss: 4.2799
# Iteration: 22 of 31	train_loss: 4.0728
# Iteration: 24 of 31	train_loss: 4.2385
# Iteration: 26 of 31	train_loss: 4.3517
# Iteration: 28 of 31	train_loss: 4.1716
# Iteration: 30 of 31	train_loss: 4.6897
# Iteration: 31 of 31	train_loss: 4.3159
# Average Score for this Epoch: 4.19740629196167
# --- new best score ---
#
#
# -------------------- Epoch 52 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.1713
# Iteration: 2 of 31	train_loss: 4.0669
# Iteration: 4 of 31	train_loss: 4.1637
# Iteration: 6 of 31	train_loss: 3.9236
# Iteration: 8 of 31	train_loss: 4.4622
# Iteration: 10 of 31	train_loss: 4.6340
# Iteration: 12 of 31	train_loss: 4.4396
# Iteration: 14 of 31	train_loss: 3.8435
# Iteration: 16 of 31	train_loss: 4.4400
# Iteration: 18 of 31	train_loss: 4.0873
# Iteration: 20 of 31	train_loss: 4.3588
# Iteration: 22 of 31	train_loss: 4.4827
# Iteration: 24 of 31	train_loss: 4.1887
# Iteration: 26 of 31	train_loss: 4.0018
# Iteration: 28 of 31	train_loss: 4.2048
# Iteration: 30 of 31	train_loss: 4.3589
# Iteration: 31 of 31	train_loss: 4.3354
# Average Score for this Epoch: 4.190978050231934
# --- new best score ---
#
#
# -------------------- Epoch 53 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.0689
# Iteration: 2 of 31	train_loss: 4.0836
# Iteration: 4 of 31	train_loss: 4.3475
# Iteration: 6 of 31	train_loss: 3.8160
# Iteration: 8 of 31	train_loss: 4.1049
# Iteration: 10 of 31	train_loss: 4.1928
# Iteration: 12 of 31	train_loss: 4.1745
# Iteration: 14 of 31	train_loss: 4.2496
# Iteration: 16 of 31	train_loss: 3.8278
# Iteration: 18 of 31	train_loss: 4.4053
# Iteration: 20 of 31	train_loss: 3.9485
# Iteration: 22 of 31	train_loss: 4.6550
# Iteration: 24 of 31	train_loss: 4.4626
# Iteration: 26 of 31	train_loss: 4.0422
# Iteration: 28 of 31	train_loss: 4.6798
# Iteration: 30 of 31	train_loss: 4.1026
# Iteration: 31 of 31	train_loss: 4.1312
# Average Score for this Epoch: 4.16793155670166
# --- new best score ---
#
#
# -------------------- Epoch 54 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.1503
# Iteration: 2 of 31	train_loss: 4.0967
# Iteration: 4 of 31	train_loss: 4.0510
# Iteration: 6 of 31	train_loss: 3.8351
# Iteration: 8 of 31	train_loss: 4.0517
# Iteration: 10 of 31	train_loss: 3.9150
# Iteration: 12 of 31	train_loss: 4.0808
# Iteration: 14 of 31	train_loss: 4.5147
# Iteration: 16 of 31	train_loss: 4.2637
# Iteration: 18 of 31	train_loss: 3.9392
# Iteration: 20 of 31	train_loss: 4.3869
# Iteration: 22 of 31	train_loss: 4.2062
# Iteration: 24 of 31	train_loss: 4.4605
# Iteration: 26 of 31	train_loss: 4.0891
# Iteration: 28 of 31	train_loss: 4.1570
# Iteration: 30 of 31	train_loss: 4.3024
# Iteration: 31 of 31	train_loss: 4.0971
# Average Score for this Epoch: 4.146094799041748
# --- new best score ---
#
#
# -------------------- Epoch 55 of 100 --------------------
# Iteration: 0 of 31	train_loss: 4.3519
# Iteration: 2 of 31	train_loss: 4.0384
# Iteration: 4 of 31	train_loss: 4.0520
# Iteration: 6 of 31	train_loss: 4.2102
# Iteration: 8 of 31	train_loss: 4.0157
# Iteration: 10 of 31	train_loss: 3.9009
# Iteration: 12 of 31	train_loss: 4.0954
# Iteration: 14 of 31	train_loss: 4.3097
# Iteration: 16 of 31	train_loss: 4.2581
# Iteration: 18 of 31	train_loss: 4.2752
# Iteration: 20 of 31	train_loss: 3.8599
# Iteration: 22 of 31	train_loss: 4.1509
# Iteration: 24 of 31	train_loss: 4.3037
# Iteration: 26 of 31	train_loss: 4.1776
# Iteration: 28 of 31	train_loss: 4.3152
# Iteration: 30 of 31	train_loss: 4.3871
# Iteration: 31 of 31	train_loss: 4.2322
# Average Score for this Epoch: 4.147322654724121
# -------------------- Epoch 56 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.9764
# Iteration: 2 of 31	train_loss: 4.3133
# Iteration: 4 of 31	train_loss: 4.1407
# Iteration: 6 of 31	train_loss: 4.1264
# Iteration: 8 of 31	train_loss: 4.3156
# Iteration: 10 of 31	train_loss: 4.1709
# Iteration: 12 of 31	train_loss: 3.7630
# Iteration: 14 of 31	train_loss: 4.2869
# Iteration: 16 of 31	train_loss: 4.1004
# Iteration: 18 of 31	train_loss: 4.4175
# Iteration: 20 of 31	train_loss: 3.9593
# Iteration: 22 of 31	train_loss: 4.3706
# Iteration: 24 of 31	train_loss: 3.9869
# Iteration: 26 of 31	train_loss: 3.6174
# Iteration: 28 of 31	train_loss: 4.2352
# Iteration: 30 of 31	train_loss: 4.2458
# Iteration: 31 of 31	train_loss: 3.9203
# Average Score for this Epoch: 4.09603214263916
# --- new best score ---
#
#
# -------------------- Epoch 57 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8290
# Iteration: 2 of 31	train_loss: 4.3649
# Iteration: 4 of 31	train_loss: 4.0553
# Iteration: 6 of 31	train_loss: 3.9263
# Iteration: 8 of 31	train_loss: 4.0624
# Iteration: 10 of 31	train_loss: 3.9538
# Iteration: 12 of 31	train_loss: 4.1661
# Iteration: 14 of 31	train_loss: 4.1478
# Iteration: 16 of 31	train_loss: 3.9716
# Iteration: 18 of 31	train_loss: 4.2606
# Iteration: 20 of 31	train_loss: 4.0675
# Iteration: 22 of 31	train_loss: 4.6136
# Iteration: 24 of 31	train_loss: 3.8875
# Iteration: 26 of 31	train_loss: 4.3115
# ...
# Iteration: 20 of 31	train_loss: 3.9314
# Iteration: 22 of 31	train_loss: 3.9064
# Iteration: 24 of 31	train_loss: 3.7854
# Iteration: 26 of 31	train_loss: 3.6132
# Iteration: 28 of 31	train_loss: 3.8635
# Iteration: 30 of 31	train_loss: 3.4500
# Iteration: 31 of 31	train_loss: 4.0610
# Average Score for this Epoch: 3.786715030670166
# --- new best score ---
#
#
# -------------------- Epoch 81 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8586
# Iteration: 2 of 31	train_loss: 3.7902
# Iteration: 4 of 31	train_loss: 3.7938
# Iteration: 6 of 31	train_loss: 3.6610
# Iteration: 8 of 31	train_loss: 3.5995
# Iteration: 10 of 31	train_loss: 3.8946
# Iteration: 12 of 31	train_loss: 3.4576
# Iteration: 14 of 31	train_loss: 3.8333
# Iteration: 16 of 31	train_loss: 3.7856
# Iteration: 18 of 31	train_loss: 3.7017
# Iteration: 20 of 31	train_loss: 3.7142
# Iteration: 22 of 31	train_loss: 3.9227
# Iteration: 24 of 31	train_loss: 3.7567
# Iteration: 26 of 31	train_loss: 3.6157
# Iteration: 28 of 31	train_loss: 3.9520
# Iteration: 30 of 31	train_loss: 3.7895
# Iteration: 31 of 31	train_loss: 3.8273
# Average Score for this Epoch: 3.775130271911621
# --- new best score ---
#
#
# -------------------- Epoch 82 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.5296
# Iteration: 2 of 31	train_loss: 3.6011
# Iteration: 4 of 31	train_loss: 3.9553
# Iteration: 6 of 31	train_loss: 3.6297
# Iteration: 8 of 31	train_loss: 3.6362
# Iteration: 10 of 31	train_loss: 3.7202
# Iteration: 12 of 31	train_loss: 3.4855
# Iteration: 14 of 31	train_loss: 3.8943
# Iteration: 16 of 31	train_loss: 3.7220
# Iteration: 18 of 31	train_loss: 3.9434
# Iteration: 20 of 31	train_loss: 4.2321
# Iteration: 22 of 31	train_loss: 3.7169
# Iteration: 24 of 31	train_loss: 4.0396
# Iteration: 26 of 31	train_loss: 3.3870
# Iteration: 28 of 31	train_loss: 3.9700
# Iteration: 30 of 31	train_loss: 4.1913
# Iteration: 31 of 31	train_loss: 3.3553
# Average Score for this Epoch: 3.7491817474365234
# --- new best score ---
#
#
# -------------------- Epoch 83 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8182
# Iteration: 2 of 31	train_loss: 3.6042
# Iteration: 4 of 31	train_loss: 3.5430
# Iteration: 6 of 31	train_loss: 3.3701
# Iteration: 8 of 31	train_loss: 3.6802
# Iteration: 10 of 31	train_loss: 3.8275
# Iteration: 12 of 31	train_loss: 3.6459
# Iteration: 14 of 31	train_loss: 3.4770
# Iteration: 16 of 31	train_loss: 3.7121
# Iteration: 18 of 31	train_loss: 4.0331
# Iteration: 20 of 31	train_loss: 3.9357
# Iteration: 22 of 31	train_loss: 3.9716
# Iteration: 24 of 31	train_loss: 3.4009
# Iteration: 26 of 31	train_loss: 3.9690
# Iteration: 28 of 31	train_loss: 4.0112
# Iteration: 30 of 31	train_loss: 3.9389
# Iteration: 31 of 31	train_loss: 3.8707
# Average Score for this Epoch: 3.776123285293579
# -------------------- Epoch 84 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.6487
# Iteration: 2 of 31	train_loss: 3.5653
# Iteration: 4 of 31	train_loss: 3.3559
# Iteration: 6 of 31	train_loss: 3.6089
# Iteration: 8 of 31	train_loss: 3.9005
# Iteration: 10 of 31	train_loss: 3.7254
# Iteration: 12 of 31	train_loss: 3.6146
# Iteration: 14 of 31	train_loss: 3.6187
# Iteration: 16 of 31	train_loss: 3.6064
# Iteration: 18 of 31	train_loss: 3.8752
# Iteration: 20 of 31	train_loss: 3.9567
# Iteration: 22 of 31	train_loss: 3.8791
# Iteration: 24 of 31	train_loss: 3.9813
# Iteration: 26 of 31	train_loss: 4.0539
# Iteration: 28 of 31	train_loss: 3.7279
# Iteration: 30 of 31	train_loss: 3.9994
# Iteration: 31 of 31	train_loss: 3.7579
# Average Score for this Epoch: 3.747119426727295
# --- new best score ---
#
#
# -------------------- Epoch 85 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.3271
# Iteration: 2 of 31	train_loss: 3.5753
# Iteration: 4 of 31	train_loss: 3.8160
# Iteration: 6 of 31	train_loss: 3.6561
# Iteration: 8 of 31	train_loss: 3.9000
# Iteration: 10 of 31	train_loss: 3.7385
# Iteration: 12 of 31	train_loss: 3.5811
# Iteration: 14 of 31	train_loss: 3.6082
# Iteration: 16 of 31	train_loss: 3.2230
# Iteration: 18 of 31	train_loss: 3.8511
# Iteration: 20 of 31	train_loss: 3.7262
# Iteration: 22 of 31	train_loss: 3.8721
# Iteration: 24 of 31	train_loss: 3.5745
# Iteration: 26 of 31	train_loss: 3.8819
# Iteration: 28 of 31	train_loss: 3.8580
# Iteration: 30 of 31	train_loss: 3.9592
# Iteration: 31 of 31	train_loss: 3.4388
# Average Score for this Epoch: 3.7212867736816406
# --- new best score ---
#
#
# -------------------- Epoch 86 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.9128
# Iteration: 2 of 31	train_loss: 3.6224
# Iteration: 4 of 31	train_loss: 3.7741
# Iteration: 6 of 31	train_loss: 3.8434
# Iteration: 8 of 31	train_loss: 3.8762
# Iteration: 10 of 31	train_loss: 3.6574
# Iteration: 12 of 31	train_loss: 3.7662
# Iteration: 14 of 31	train_loss: 3.5597
# Iteration: 16 of 31	train_loss: 3.5586
# Iteration: 18 of 31	train_loss: 4.0679
# Iteration: 20 of 31	train_loss: 3.7584
# Iteration: 22 of 31	train_loss: 3.5347
# Iteration: 24 of 31	train_loss: 3.6196
# Iteration: 26 of 31	train_loss: 3.8679
# Iteration: 28 of 31	train_loss: 3.7192
# Iteration: 30 of 31	train_loss: 3.8602
# Iteration: 31 of 31	train_loss: 3.8883
# Average Score for this Epoch: 3.7318220138549805
# -------------------- Epoch 87 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.7602
# Iteration: 2 of 31	train_loss: 3.0885
# Iteration: 4 of 31	train_loss: 3.8983
# Iteration: 6 of 31	train_loss: 3.7451
# Iteration: 8 of 31	train_loss: 3.5545
# Iteration: 10 of 31	train_loss: 3.7439
# Iteration: 12 of 31	train_loss: 3.9507
# Iteration: 14 of 31	train_loss: 3.7950
# Iteration: 16 of 31	train_loss: 3.8992
# Iteration: 18 of 31	train_loss: 3.7535
# Iteration: 20 of 31	train_loss: 3.5453
# Iteration: 22 of 31	train_loss: 3.9909
# Iteration: 24 of 31	train_loss: 3.8407
# Iteration: 26 of 31	train_loss: 3.8477
# Iteration: 28 of 31	train_loss: 3.9108
# Iteration: 30 of 31	train_loss: 4.1306
# Iteration: 31 of 31	train_loss: 3.7002
# Average Score for this Epoch: 3.713062286376953
# --- new best score ---
#
#
# -------------------- Epoch 88 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8693
# Iteration: 2 of 31	train_loss: 3.5528
# Iteration: 4 of 31	train_loss: 3.5234
# Iteration: 6 of 31	train_loss: 3.5266
# Iteration: 8 of 31	train_loss: 3.5893
# Iteration: 10 of 31	train_loss: 4.2875
# Iteration: 12 of 31	train_loss: 3.7973
# Iteration: 14 of 31	train_loss: 4.0079
# Iteration: 16 of 31	train_loss: 3.4640
# Iteration: 18 of 31	train_loss: 3.8129
# Iteration: 20 of 31	train_loss: 3.7282
# Iteration: 22 of 31	train_loss: 3.4657
# Iteration: 24 of 31	train_loss: 3.7669
# Iteration: 26 of 31	train_loss: 3.8103
# Iteration: 28 of 31	train_loss: 3.8888
# Iteration: 30 of 31	train_loss: 3.5903
# Iteration: 31 of 31	train_loss: 3.9383
# Average Score for this Epoch: 3.710050582885742
# --- new best score ---
#
#
# -------------------- Epoch 89 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.5143
# Iteration: 2 of 31	train_loss: 3.9709
# Iteration: 4 of 31	train_loss: 3.4246
# Iteration: 6 of 31	train_loss: 3.3119
# Iteration: 8 of 31	train_loss: 3.8156
# Iteration: 10 of 31	train_loss: 4.0110
# Iteration: 12 of 31	train_loss: 3.9320
# Iteration: 14 of 31	train_loss: 3.2026
# Iteration: 16 of 31	train_loss: 3.7602
# Iteration: 18 of 31	train_loss: 3.6238
# Iteration: 20 of 31	train_loss: 3.6767
# Iteration: 22 of 31	train_loss: 3.9130
# Iteration: 24 of 31	train_loss: 3.4587
# Iteration: 26 of 31	train_loss: 3.7146
# Iteration: 28 of 31	train_loss: 3.6625
# Iteration: 30 of 31	train_loss: 3.7714
# Iteration: 31 of 31	train_loss: 3.3658
# Average Score for this Epoch: 3.683741569519043
# --- new best score ---
#
#
# -------------------- Epoch 90 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8502
# Iteration: 2 of 31	train_loss: 3.5392
# Iteration: 4 of 31	train_loss: 3.6956
# Iteration: 6 of 31	train_loss: 3.4281
# Iteration: 8 of 31	train_loss: 3.6016
# Iteration: 10 of 31	train_loss: 3.9381
# Iteration: 12 of 31	train_loss: 3.6659
# Iteration: 14 of 31	train_loss: 3.8652
# Iteration: 16 of 31	train_loss: 3.6328
# Iteration: 18 of 31	train_loss: 3.6518
# Iteration: 20 of 31	train_loss: 3.4627
# Iteration: 22 of 31	train_loss: 3.7508
# Iteration: 24 of 31	train_loss: 3.7021
# Iteration: 26 of 31	train_loss: 3.8442
# Iteration: 28 of 31	train_loss: 4.1659
# Iteration: 30 of 31	train_loss: 3.5466
# Iteration: 31 of 31	train_loss: 3.8105
# Average Score for this Epoch: 3.698990821838379
# -------------------- Epoch 91 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8428
# Iteration: 2 of 31	train_loss: 3.6497
# Iteration: 4 of 31	train_loss: 3.5880
# Iteration: 6 of 31	train_loss: 3.6952
# Iteration: 8 of 31	train_loss: 3.2906
# Iteration: 10 of 31	train_loss: 3.7381
# Iteration: 12 of 31	train_loss: 3.4003
# Iteration: 14 of 31	train_loss: 3.7956
# Iteration: 16 of 31	train_loss: 3.4523
# Iteration: 18 of 31	train_loss: 3.5400
# Iteration: 20 of 31	train_loss: 3.9086
# Iteration: 22 of 31	train_loss: 3.5612
# Iteration: 24 of 31	train_loss: 3.7205
# Iteration: 26 of 31	train_loss: 3.5926
# Iteration: 28 of 31	train_loss: 3.6762
# Iteration: 30 of 31	train_loss: 3.6751
# Iteration: 31 of 31	train_loss: 3.8712
# Average Score for this Epoch: 3.6829233169555664
# --- new best score ---
#
#
# -------------------- Epoch 92 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.8850
# Iteration: 2 of 31	train_loss: 3.6098
# Iteration: 4 of 31	train_loss: 3.7339
# Iteration: 6 of 31	train_loss: 3.7309
# Iteration: 8 of 31	train_loss: 3.7967
# Iteration: 10 of 31	train_loss: 3.3322
# Iteration: 12 of 31	train_loss: 3.6329
# Iteration: 14 of 31	train_loss: 3.6537
# Iteration: 16 of 31	train_loss: 3.8095
# Iteration: 18 of 31	train_loss: 3.9580
# Iteration: 20 of 31	train_loss: 3.6940
# Iteration: 22 of 31	train_loss: 3.7507
# Iteration: 24 of 31	train_loss: 3.5459
# Iteration: 26 of 31	train_loss: 3.6931
# Iteration: 28 of 31	train_loss: 3.2542
# Iteration: 30 of 31	train_loss: 3.3105
# Iteration: 31 of 31	train_loss: 3.9451
# Average Score for this Epoch: 3.65708065032959
# --- new best score ---
#
#
# -------------------- Epoch 93 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.4593
# Iteration: 2 of 31	train_loss: 3.4878
# Iteration: 4 of 31	train_loss: 3.4079
# Iteration: 6 of 31	train_loss: 3.4273
# Iteration: 8 of 31	train_loss: 3.6232
# Iteration: 10 of 31	train_loss: 3.8431
# Iteration: 12 of 31	train_loss: 3.7978
# Iteration: 14 of 31	train_loss: 3.8442
# Iteration: 16 of 31	train_loss: 3.7523
# Iteration: 18 of 31	train_loss: 3.5115
# Iteration: 20 of 31	train_loss: 3.6227
# Iteration: 22 of 31	train_loss: 3.8284
# Iteration: 24 of 31	train_loss: 3.6430
# Iteration: 26 of 31	train_loss: 3.8318
# Iteration: 28 of 31	train_loss: 3.8295
# Iteration: 30 of 31	train_loss: 4.0167
# Iteration: 31 of 31	train_loss: 3.5063
# Average Score for this Epoch: 3.658785820007324
# -------------------- Epoch 94 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.4421
# Iteration: 2 of 31	train_loss: 3.6949
# Iteration: 4 of 31	train_loss: 3.4234
# Iteration: 6 of 31	train_loss: 3.4883
# Iteration: 8 of 31	train_loss: 3.4182
# Iteration: 10 of 31	train_loss: 3.4924
# Iteration: 12 of 31	train_loss: 3.8072
# Iteration: 14 of 31	train_loss: 3.6090
# Iteration: 16 of 31	train_loss: 3.5143
# Iteration: 18 of 31	train_loss: 3.6761
# Iteration: 20 of 31	train_loss: 3.6655
# Iteration: 22 of 31	train_loss: 3.7480
# Iteration: 24 of 31	train_loss: 3.8352
# Iteration: 26 of 31	train_loss: 3.4695
# Iteration: 28 of 31	train_loss: 3.6917
# Iteration: 30 of 31	train_loss: 3.7746
# Iteration: 31 of 31	train_loss: 3.4874
# Average Score for this Epoch: 3.6346704959869385
# --- new best score ---
#
#
# -------------------- Epoch 95 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.5181
# Iteration: 2 of 31	train_loss: 3.1706
# Iteration: 4 of 31	train_loss: 3.4050
# Iteration: 6 of 31	train_loss: 3.2619
# Iteration: 8 of 31	train_loss: 3.7173
# Iteration: 10 of 31	train_loss: 3.6630
# Iteration: 12 of 31	train_loss: 3.6809
# Iteration: 14 of 31	train_loss: 3.5595
# Iteration: 16 of 31	train_loss: 3.5001
# Iteration: 18 of 31	train_loss: 3.4627
# Iteration: 20 of 31	train_loss: 3.4970
# Iteration: 22 of 31	train_loss: 3.3240
# Iteration: 24 of 31	train_loss: 3.7163
# Iteration: 26 of 31	train_loss: 3.5116
# Iteration: 28 of 31	train_loss: 3.3775
# Iteration: 30 of 31	train_loss: 3.9665
# Iteration: 31 of 31	train_loss: 3.4731
# Average Score for this Epoch: 3.616668224334717
# --- new best score ---
#
#
# -------------------- Epoch 96 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.4221
# Iteration: 2 of 31	train_loss: 3.1809
# Iteration: 4 of 31	train_loss: 3.5027
# Iteration: 6 of 31	train_loss: 3.8325
# Iteration: 8 of 31	train_loss: 3.8783
# Iteration: 10 of 31	train_loss: 3.6803
# Iteration: 12 of 31	train_loss: 3.2148
# Iteration: 14 of 31	train_loss: 3.7541
# Iteration: 16 of 31	train_loss: 3.5959
# Iteration: 18 of 31	train_loss: 3.9959
# Iteration: 20 of 31	train_loss: 3.7544
# Iteration: 22 of 31	train_loss: 3.6536
# Iteration: 24 of 31	train_loss: 3.5199
# Iteration: 26 of 31	train_loss: 3.9499
# Iteration: 28 of 31	train_loss: 3.7542
# Iteration: 30 of 31	train_loss: 3.4837
# Iteration: 31 of 31	train_loss: 3.5808
# Average Score for this Epoch: 3.6129698753356934
# --- new best score ---
#
#
# -------------------- Epoch 97 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.9078
# Iteration: 2 of 31	train_loss: 3.6187
# Iteration: 4 of 31	train_loss: 3.8833
# Iteration: 6 of 31	train_loss: 3.5061
# Iteration: 8 of 31	train_loss: 3.4402
# Iteration: 10 of 31	train_loss: 3.7182
# Iteration: 12 of 31	train_loss: 3.6626
# Iteration: 14 of 31	train_loss: 3.9590
# Iteration: 16 of 31	train_loss: 3.6728
# Iteration: 18 of 31	train_loss: 3.6115
# Iteration: 20 of 31	train_loss: 3.2902
# Iteration: 22 of 31	train_loss: 3.6211
# Iteration: 24 of 31	train_loss: 3.6109
# Iteration: 26 of 31	train_loss: 3.8889
# Iteration: 28 of 31	train_loss: 3.7496
# Iteration: 30 of 31	train_loss: 3.5604
# Iteration: 31 of 31	train_loss: 3.9313
# Average Score for this Epoch: 3.6203901767730713
# -------------------- Epoch 98 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.5955
# Iteration: 2 of 31	train_loss: 3.6538
# Iteration: 4 of 31	train_loss: 3.6365
# Iteration: 6 of 31	train_loss: 3.6139
# Iteration: 8 of 31	train_loss: 3.8045
# Iteration: 10 of 31	train_loss: 3.9239
# Iteration: 12 of 31	train_loss: 3.5337
# Iteration: 14 of 31	train_loss: 3.5388
# Iteration: 16 of 31	train_loss: 3.5805
# Iteration: 18 of 31	train_loss: 3.7028
# Iteration: 20 of 31	train_loss: 3.3507
# Iteration: 22 of 31	train_loss: 3.1605
# Iteration: 24 of 31	train_loss: 3.5204
# Iteration: 26 of 31	train_loss: 3.7867
# Iteration: 28 of 31	train_loss: 3.8119
# Iteration: 30 of 31	train_loss: 3.5712
# Iteration: 31 of 31	train_loss: 3.5219
# Average Score for this Epoch: 3.5879745483398438
# --- new best score ---
#
#
# -------------------- Epoch 99 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.7061
# Iteration: 2 of 31	train_loss: 3.5687
# Iteration: 4 of 31	train_loss: 3.5591
# Iteration: 6 of 31	train_loss: 3.5834
# Iteration: 8 of 31	train_loss: 3.6380
# Iteration: 10 of 31	train_loss: 3.6053
# Iteration: 12 of 31	train_loss: 3.6311
# Iteration: 14 of 31	train_loss: 3.8060
# Iteration: 16 of 31	train_loss: 3.7738
# Iteration: 18 of 31	train_loss: 3.3405
# Iteration: 20 of 31	train_loss: 3.5089
# Iteration: 22 of 31	train_loss: 3.7952
# Iteration: 24 of 31	train_loss: 3.8266
# Iteration: 26 of 31	train_loss: 3.9026
# Iteration: 28 of 31	train_loss: 3.5624
# Iteration: 30 of 31	train_loss: 3.4657
# Iteration: 31 of 31	train_loss: 3.7530
# Average Score for this Epoch: 3.5938427448272705
# -------------------- Epoch 100 of 100 --------------------
# Iteration: 0 of 31	train_loss: 3.3294
# Iteration: 2 of 31	train_loss: 3.3240
# Iteration: 4 of 31	train_loss: 3.9635
# Iteration: 6 of 31	train_loss: 3.7664
# Iteration: 8 of 31	train_loss: 3.4274
# Iteration: 10 of 31	train_loss: 3.3684
# Iteration: 12 of 31	train_loss: 3.7106
# Iteration: 14 of 31	train_loss: 3.7136
# Iteration: 16 of 31	train_loss: 3.8126
# Iteration: 18 of 31	train_loss: 3.4798
# Iteration: 20 of 31	train_loss: 3.5311
# Iteration: 22 of 31	train_loss: 3.7179
# Iteration: 24 of 31	train_loss: 3.6786
# Iteration: 26 of 31	train_loss: 3.4162
# Iteration: 28 of 31	train_loss: 3.3794
# Iteration: 30 of 31	train_loss: 3.4930
# Iteration: 31 of 31	train_loss: 3.4126
# Average Score for this Epoch: 3.5831360816955566
# --- new best score ---

# %%
_de_inds, _de_unknowns = nmt_data_utils.convert_to_inds(de_preprocessed_clean, de_word2ind, sos = True,  eos = True)

# %%
# the inference model does not necessaryly need to get input batches. we can just give it. the whole input
# data, but the the batchsize has to be specified as the lenght of the input data.
nmt_model_utils.reset_graph()

nmt = NMT_Model.NMT(en_word2ind,
                    en_ind2word,
                    de_word2ind,
                    de_ind2word,
                    './models/local_one/my_model',
                    'INFER',
                    num_layers_encoder = num_layers_encoder,
                    num_layers_decoder = num_layers_decoder,
                    batch_size = len(en_inds[:50]),
                    keep_probability = 1.0,
                    learning_rate = 0.0,
                    beam_width = 0,
                    rnn_size_encoder = rnn_size_encoder,
                    rnn_size_decoder = rnn_size_decoder)

nmt.build_graph()
preds = nmt.infer(en_inds[:50], restore_path =  './models/local_one/my_model', targets = _de_inds[:50])
# Out:
# Graph built.
# Restore graph from  ./models/local_one/my_model
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./models/local_one/my_model

# %%
# show some of the created translations
# Note: the way bleu score is probably not the perfect way to do it
nmt_model_utils.sample_results(preds, en_ind2word, de_ind2word, en_word2ind, de_word2ind, _de_inds[:50], en_inds[:50])
# Out:
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wouldn ’ t you know it ?
#
# Actual translation:
# und es kam , wie es kommen musste .
#
# Created translation:
# denn kalte , , , es es musste . . ,
#
# Bleu-score: 6.887578243315168e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# since then , the index has climbed above 10,000 .
#
# Actual translation:
# seit damals ist er auf über 10.000 punkte gestiegen .
#
# Created translation:
# die damals ist ist sarajevo noch 10.000 punkte gestiegen .
#
# Bleu-score: 0.31239399369202553
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# they departed pledging to revive europe 's growth .
#
# Actual translation:
# mit der zusicherung , das wachstum in europa wieder zu beleben , gingen sie auseinander .
#
# Created translation:
# aber ultraniedrige zusicherung zusicherung dass , in nicht nicht oligarchen beleben , , , , , ,
#
# Bleu-score: 5.4925306713204074e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# we 've heard that empty promise before .
#
# Actual translation:
# dieses leere versprechen haben wir schon einmal gehört .
#
# Created translation:
# doch leere ist sich es schon einmal .
#
# Bleu-score: 6.805395922591311e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# many europeans are sick of british vetoes .
#
# Actual translation:
# viele europäer sind die britischen vetos leid .
#
# Created translation:
# diese hat hat us-politik britischen vetos leid . . .
#
# Bleu-score: 0.2626909894424158
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# precedents exist for this .
#
# Actual translation:
# hierfür existieren beispiele .
#
# Created translation:
# hierfür existieren beispiele . . .
#
# Bleu-score: 0.5081327481546147
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# nato has been flexible since its inception .
#
# Actual translation:
# die nato ist von anfang an flexibel gewesen .
#
# Created translation:
# die nato ist sich ist die flexibel .
#
# Bleu-score: 4.476766863915479e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# these precedents can be extended .
#
# Actual translation:
# diese beispielsfälle kann man erweitern .
#
# Created translation:
# diese beispielsfälle öffnen alles erweitern .
#
# Bleu-score: 1.0719249972567852e-154
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# i am not talking about a two‑speed europe .
#
# Actual translation:
# ich meine kein europa mit zwei unterschiedlichen geschwindigkeiten .
#
# Created translation:
# ich meine ich nicht schwächer unterschiedlichen unterschiedlichen geschwindigkeiten .
#
# Bleu-score: 5.072841446586652e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but i do n't want to block their way .
#
# Actual translation:
# aber ich möchte ihnen nicht im wege stehen .
#
# Created translation:
# diese ist möchte möchte nicht nicht andauern . .
#
# Bleu-score: 1.384292958842266e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# elected parliaments do not own our liberties .
#
# Actual translation:
# gewählte parlamente besitzen unsere freiheiten nicht .
#
# Created translation:
# gewählte parlamente besitzen unsere freiheiten freiheiten . . .
#
# Bleu-score: 0.4671379777282001
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but the big question remains : how ?
#
# Actual translation:
# aber eine große frage bleibt : wie ?
#
# Created translation:
# aber wie ist ist sich die die ? . .
#
# Bleu-score: 1.3483065280626046e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the need for immediate action is clear .
#
# Actual translation:
# dass sofort gehandelt werden muss , ist eindeutig .
#
# Created translation:
# die sofort gehandelt ist in ist die . .
#
# Bleu-score: 7.241926111174567e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the new year is looking grim .
#
# Actual translation:
# es sieht finster aus für das neue jahr .
#
# Created translation:
# es sieht finster finster das das neue . .
#
# Bleu-score: 5.30941411456236e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# france is flat-lining ( as is britain ) .
#
# Actual translation:
# frankreich stagniert ( und großbritannien auch ) .
#
# Created translation:
# frankreich stagniert ( ( prozent frankreich ) . , die
#
# Bleu-score: 4.640083527732319e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# italy and spain have sunk into deep recession .
#
# Actual translation:
# italien und spanien sind tief in die rezession abgerutscht .
#
# Created translation:
# aber die die ist ist , in zwei abgerutscht .
#
# Bleu-score: 6.8489908526642754e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# greece is in its fifth year of a slump .
#
# Actual translation:
# griechenland erlebt sein fünftes jahr des abschwungs .
#
# Created translation:
# griechenland erlebt erlebt fünftes fünftes des abschwungs . die .
#
# Bleu-score: 4.856474469839072e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a big new push for growth is therefore vital .
#
# Actual translation:
# ein neuer , starker wachstumsanschub ist daher unverzichtbar .
#
# Created translation:
# es ist hierauf starker wachstumsanschub wachstumsanschub unverzichtbar unverzichtbar . . .
#
# Bleu-score: 8.190757052088229e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# boosting exports is also essential .
#
# Actual translation:
# eine ankurbelung des exports ist ebenfalls von zentraler bedeutung .
#
# Created translation:
# die ankurbelung unterbrechung exports kalifornien der . . , , , .
#
# Bleu-score: 1.2882297539194154e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# that brings us to fiscal policy .
#
# Actual translation:
# dies bringt uns zur fiskalpolitik .
#
# Created translation:
# und bringt sollte fiskalpolitik fiskalpolitik . .
#
# Bleu-score: 7.711523862191631e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# indeed , such hopes were misplaced .
#
# Actual translation:
# tatsächlich sind solche hoffnungen verloren gegangen .
#
# Created translation:
# tatsächlich ist solche hoffnungen verloren gegangen .
#
# Bleu-score: 0.6434588841607617
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# in fact , iraqi society is more complex than this .
#
# Actual translation:
# tatsächlich ist die irakische gesellschaft komplexer als dies .
#
# Created translation:
# es ist die irakische gesellschaft komplexer komplexer sein . .
#
# Bleu-score: 0.4111336169005197
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# we are doing our part in terms of burden-sharing .
#
# Actual translation:
# wir leisten unseren teil , was die übernahme der lasten angeht .
#
# Created translation:
# dies ist allerdings , , , der der der lasten angeht , und und
#
# Bleu-score: 3.00466076572634e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# sensible europeans understand that .
#
# Actual translation:
# vernünftige europäer verstehen das .
#
# Created translation:
# vernünftige europäer verstehen verstehen .
#
# Bleu-score: 7.380245217279165e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# to be sure , some of our neighbors are difficult .
#
# Actual translation:
# sicher , einige unserer nachbarn sind schwierig .
#
# Created translation:
# dies ist bei ab nachbarn nachbarn nachbarn .
#
# Bleu-score: 1.2882297539194154e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# progress on disinflation is similarly impressive .
#
# Actual translation:
# der fortschritt hinsichtlich des inflationsrückgangs ist ähnlich beeindruckend .
#
# Created translation:
# die ist russischen die inflationsrückgangs inflationsrückgangs die .
#
# Bleu-score: 1.258141043412406e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# in better shape , but not alone .
#
# Actual translation:
# in besserer verfassung , aber nicht allein .
#
# Created translation:
# es besserer verfassung , nicht nicht allein . . .
#
# Bleu-score: 6.206021746903507e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# when the rich get less rich , the poor get poorer .
#
# Actual translation:
# wenn die reichen weniger reich werden , werden die armen ärmer .
#
# Created translation:
# die die reichen reich reich reich reich werden werden armen ärmer .
#
# Bleu-score: 4.963273987908844e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# it all came about in a number of ways .
#
# Actual translation:
# verschiedene wege führten mich dorthin .
#
# Created translation:
# verschiedene wege führten führten dorthin . . .
#
# Bleu-score: 5.614021910443866e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# then i got distracted for about 40 years .
#
# Actual translation:
# anschließend war ich ungefähr 40 jahre lang anderweitig beschäftigt .
#
# Created translation:
# ich wesentlichen fische jahre investieren längst im anderweitig . . .
#
# Bleu-score: 1.4147351699132998e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# not all are happy about this american notion .
#
# Actual translation:
# nicht alle sind mit dieser amerikanischen vorstellung glücklich .
#
# Created translation:
# nicht kann kann der der der menschheit glücklich .
#
# Bleu-score: 6.7393716283177006e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# this is the beginning of a new authoritarianism .
#
# Actual translation:
# dies ist der anfang eines neuen autoritarismus .
#
# Created translation:
# dies ist ist anfang einfach lieber männliche .
#
# Bleu-score: 7.711523862191631e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a diffuse anxiety is gaining ground .
#
# Actual translation:
# eine diffuse besorgnis greift um sich .
#
# Created translation:
# eine diffuse besorgnis greift greift die .
#
# Bleu-score: 0.4347208719449914
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but this , of course , is untrue .
#
# Actual translation:
# das entspricht natürlich nicht der wahrheit .
#
# Created translation:
# das entspricht das sich die wahrheit .
#
# Bleu-score: 9.85444998995587e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# could the answer be a bit of both ?
#
# Actual translation:
# oder könnte die antwort lauten : ein bisschen von beidem ?
#
# Created translation:
# aber multilateralismus eigenen lauten lauten zweifellos bisschen bisschen ? .
#
# Bleu-score: 1.2199981975731961e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# china is ; you are not . ”
#
# Actual translation:
# china ist es ; ihr nicht. “
#
# Created translation:
# china die die ist ein nicht. “ gegangen .
#
# Bleu-score: 7.241926111174567e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# what do you want back ?
#
# Actual translation:
# was wollt ihr zurück ?
#
# Created translation:
# was wollt umwege zurück ? . .
#
# Bleu-score: 9.85444998995587e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# these principles are clear .
#
# Actual translation:
# diese prinzipien sind klar .
#
# Created translation:
# diese prinzipien sind klar .
#
# Bleu-score: 1.0
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# in the short term , time may be on russia ’ s side .
#
# Actual translation:
# kurzfristig betrachtet , mag die zeit aufseiten russlands sein .
#
# Created translation:
# kurzfristig betrachtet bereich mag mag mag aufseiten aufseiten sein . .
#
# Bleu-score: 8.57273414893938e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# both figures are , again , the lowest in the eu .
#
# Actual translation:
# beide werte sind ebenfalls die niedrigsten in der ganzen eu .
#
# Created translation:
# die werte die ebenfalls niedrigsten niedrigsten niedrigsten der ganzen der .
#
# Bleu-score: 7.49201355438059e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but the agreement has three major flaws .
#
# Actual translation:
# doch die einigung hat drei wichtige fehler .
#
# Created translation:
# dennoch hat ist ist einigung fehler fehler .
#
# Bleu-score: 7.711523862191631e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# what 's the ordinary european to think ?
#
# Actual translation:
# was soll der normale europäer davon halten ?
#
# Created translation:
# was soll die normale europäer , so .
#
# Bleu-score: 9.170599044431425e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but what is the right level ?
#
# Actual translation:
# aber welche ebene ist die richtige ?
#
# Created translation:
# aber verlust haben ist werden richtige ? .
#
# Bleu-score: 7.711523862191631e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# much the same is true in europe .
#
# Actual translation:
# in europa ist es nicht viel anders .
#
# Created translation:
# aber gilt ist gilt nicht nicht . . .
#
# Bleu-score: 1.384292958842266e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# so `` no centralization without representation . ''
#
# Actual translation:
# also `` keine zentralisierung ohne repräsentation '' .
#
# Created translation:
# also ist zentralisierung zentralisierung zentralisierung repräsentation '' .
#
# Bleu-score: 5.072841446586652e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# activities of eu institutions ( percent of total )
#
# Actual translation:
# aufteilung nach tätigkeitsbereichen der europäischen union
#
# Created translation:
# aufteilung unsere tätigkeitsbereichen zur zur ?
#
# Bleu-score: 1.384292958842266e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# europe faces an historic opportunity .
#
# Actual translation:
# europa eröffnet sich eine historische gelegenheit .
#
# Created translation:
# europa eröffnet nicht nicht historische gelegenheit . . .
#
# Bleu-score: 5.072841446586652e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but this scenario failed to materialize .
#
# Actual translation:
# doch hat sich dieses szenario nicht bewahrheitet .
#
# Created translation:
# doch ist ist ist szenario ist bewahrheitet . .
#
# Bleu-score: 7.241926111174567e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# this means two things .
#
# Actual translation:
# daraus ergeben sich zwei dinge .
#
# Created translation:
# es ergeben ergeben zwei abgerutscht . . .
#
# Bleu-score: 1.4256605770826504e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# officially , this has not yet been acknowledged .
#
# Actual translation:
# offiziell wurde dies noch nicht anerkannt .
#
# Created translation:
# offiziell iwf dies nicht nicht anerkannt . . .
#
# Bleu-score: 4.583829695130767e-78
#
#
#
# Total Bleu Score: 0.08079338164047059
# C:\Users\ASUS\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ASUS\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ASUS\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

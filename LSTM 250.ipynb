# %%
from collections import Counter

import nltk
import NMT_Model
import nmt_data_utils
import nmt_model_utils

# %%
with open('news-commentary-v8.de-en.en',
          'r',
          encoding = 'utf-8') as f:
    en = f.readlines()
    
with open('news-commentary-v8.de-en.de',
          'r',
          encoding = 'utf-8') as f:
    de = f.readlines()

# %%
# first 5 sentence pairs. 
for line in zip(en[:5], de[:5]):
    print(line, '\n')
# Out:
# ('SAN FRANCISCO – It has never been easy to have a rational conversation about the value of gold.\n', 'SAN FRANCISCO – Es war noch nie leicht, ein rationales Gespräch über den Wert von Gold zu führen.\n')
#
# ('Lately, with gold prices up more than 300% over the last decade, it is harder than ever.\n', 'In letzter Zeit allerdings ist dies schwieriger denn je, ist doch der Goldpreis im letzten Jahrzehnt um über 300 Prozent angestiegen.\n')
#
# ('Just last December, fellow economists Martin Feldstein and Nouriel Roubini each penned op-eds bravely questioning bullish market sentiment, sensibly pointing out gold’s risks.\n', 'Erst letzten Dezember verfassten meine Kollegen Martin Feldstein und Nouriel Roubini Kommentare, in denen sie mutig die vorherrschende optimistische Marktstimmung hinterfragten und sehr überlegt auf die Risiken des Goldes \xa0hinwiesen.\n')
#
# ('Wouldn’t you know it?\n', 'Und es kam, wie es kommen musste.\n')
#
# ('Since their articles appeared, the price of gold has moved up still further.\n', 'Seit der Veröffentlichung ihrer Artikel ist der Goldpreis noch weiter gestiegen.\n')

# %%
# remove unnecessary new lines. 
de = [line.strip() for line in de]
en = [line.strip() for line in en]

# %%
# we will only use sentences of similar lengths in order to make training easier. 
len_en = [len(sent) for sent in en if 20 < len(sent) < 50]
len_dist = Counter(len_en).most_common()
len_dist
# Out:
# [(49, 599),
#  (48, 599),
#  (46, 583),
#  (47, 547),
#  (43, 514),
#  (44, 512),
#  (45, 511),
#  (41, 509),
#  (40, 503),
#  (42, 490),
#  (39, 477),
#  (38, 443),
#  (37, 438),
#  (36, 421),
#  (34, 412),
#  (33, 365),
#  (32, 358),
#  (31, 353),
#  (35, 346),
#  (30, 326),
#  (28, 324),
#  (27, 273),
#  (25, 260),
#  (29, 254),
#  (26, 250),
#  (24, 233),
#  (23, 232),
#  (22, 214),
#  (21, 208)]

# %%
# 11554 sentences that contain betwenn 20 and 50 words.
len(len_en)
# Out:
# 11554

# %%
_de = []
_en = []
for sent_de, sent_en in zip(de, en):
    if 20 < len(sent_en) < 50:
        _de.append(sent_de)
        _en.append(sent_en)

# %%
# but we will not use all 150 000 sentences, only 5000 for the beginning.
text = _en[:2000]
language='english'
lower=True
words = []
tokenized_text = []

for line in text:
    tokenized = nltk.word_tokenize(line, language=language)
    if lower:
        tokenized = [word.lower() for word in tokenized]
    tokenized_text.append(tokenized)
    for word in tokenized:
        words.append(word)

most_common = Counter(words).most_common()
en_preprocessed = tokenized_text
en_most_common = most_common

text = _de[:2000]
language='german'
lower=True
words = []
tokenized_text = []

for line in text:
    tokenized = nltk.word_tokenize(line, language=language)
    if lower:
        tokenized = [word.lower() for word in tokenized]
    tokenized_text.append(tokenized)
    for word in tokenized:
        words.append(word)

most_common = Counter(words).most_common()
de_preprocessed = tokenized_text
de_most_common = most_common

en_preprocessed
# Out:
# [['wouldn', '’', 't', 'you', 'know', 'it', '?'],
#  ['since',
#   'then',
#   ',',
#   'the',
#   'index',
#   'has',
#   'climbed',
#   'above',
#   '10,000',
#   '.'],
#  ['they',
#   'departed',
#   'pledging',
#   'to',
#   'revive',
#   'europe',
#   "'s",
#   'growth',
#   '.'],
#  ['we', "'ve", 'heard', 'that', 'empty', 'promise', 'before', '.'],
#  ['many', 'europeans', 'are', 'sick', 'of', 'british', 'vetoes', '.'],
#  ['precedents', 'exist', 'for', 'this', '.'],
#  ['nato', 'has', 'been', 'flexible', 'since', 'its', 'inception', '.'],
#  ['these', 'precedents', 'can', 'be', 'extended', '.'],
#  ['i', 'am', 'not', 'talking', 'about', 'a', 'two‑speed', 'europe', '.'],
#  ['but', 'i', 'do', "n't", 'want', 'to', 'block', 'their', 'way', '.'],
#  ['elected', 'parliaments', 'do', 'not', 'own', 'our', 'liberties', '.'],
#  ['but', 'the', 'big', 'question', 'remains', ':', 'how', '?'],
#  ['the', 'need', 'for', 'immediate', 'action', 'is', 'clear', '.'],
#  ['the', 'new', 'year', 'is', 'looking', 'grim', '.'],
#  ['france', 'is', 'flat-lining', '(', 'as', 'is', 'britain', ')', '.'],
#  ['italy', 'and', 'spain', 'have', 'sunk', 'into', 'deep', 'recession', '.'],
#  ['greece', 'is', 'in', 'its', 'fifth', 'year', 'of', 'a', 'slump', '.'],
#  ['a', 'big', 'new', 'push', 'for', 'growth', 'is', 'therefore', 'vital', '.'],
#  ['boosting', 'exports', 'is', 'also', 'essential', '.'],
#  ['that', 'brings', 'us', 'to', 'fiscal', 'policy', '.'],
#  ['indeed', ',', 'such', 'hopes', 'were', 'misplaced', '.'],
#  ['in',
#   'fact',
#   ',',
#   'iraqi',
#   'society',
#   'is',
#   'more',
#   'complex',
#   'than',
#   'this',
#   '.'],
#  ['we',
#   'are',
#   'doing',
#   'our',
#   'part',
#   'in',
#   'terms',
#   'of',
#   'burden-sharing',
#   '.'],
#  ['sensible', 'europeans', 'understand', 'that', '.'],
#  ['to',
#   'be',
#   'sure',
#   ',',
#   'some',
#   'of',
#   'our',
#   'neighbors',
#   'are',
#   'difficult',
#   '.'],
#  ['progress', 'on', 'disinflation', 'is', 'similarly', 'impressive', '.'],
#  ['in', 'better', 'shape', ',', 'but', 'not', 'alone', '.'],
#  ['when',
#   'the',
#   'rich',
#   'get',
#   'less',
#   'rich',
#   ',',
#   'the',
#   'poor',
#   'get',
#   'poorer',
#   '.'],
#  ['it', 'all', 'came', 'about', 'in', 'a', 'number', 'of', 'ways', '.'],
#  ['then', 'i', 'got', 'distracted', 'for', 'about', '40', 'years', '.'],
#  ['not', 'all', 'are', 'happy', 'about', 'this', 'american', 'notion', '.'],
#  ['this', 'is', 'the', 'beginning', 'of', 'a', 'new', 'authoritarianism', '.'],
#  ['a', 'diffuse', 'anxiety', 'is', 'gaining', 'ground', '.'],
#  ['but', 'this', ',', 'of', 'course', ',', 'is', 'untrue', '.'],
#  ['could', 'the', 'answer', 'be', 'a', 'bit', 'of', 'both', '?'],
#  ['china', 'is', ';', 'you', 'are', 'not', '.', '”'],
#  ['what', 'do', 'you', 'want', 'back', '?'],
#  ['these', 'principles', 'are', 'clear', '.'],
#  ['in',
#   'the',
#   'short',
#   'term',
#   ',',
#   'time',
#   'may',
#   'be',
#   'on',
#   'russia',
#   '’',
#   's',
#   'side',
#   '.'],
#  ['both',
#   'figures',
#   'are',
#   ',',
#   'again',
#   ',',
#   'the',
#   'lowest',
#   'in',
#   'the',
#   'eu',
#   '.'],
#  ['but', 'the', 'agreement', 'has', 'three', 'major', 'flaws', '.'],
#  ['what', "'s", 'the', 'ordinary', 'european', 'to', 'think', '?'],
#  ['but', 'what', 'is', 'the', 'right', 'level', '?'],
#  ['much', 'the', 'same', 'is', 'true', 'in', 'europe', '.'],
#  ['so', '``', 'no', 'centralization', 'without', 'representation', '.', "''"],
#  ['activities',
#   'of',
#   'eu',
#   'institutions',
#   '(',
#   'percent',
#   'of',
#   'total',
#   ')'],
#  ['europe', 'faces', 'an', 'historic', 'opportunity', '.'],
#  ['but', 'this', 'scenario', 'failed', 'to', 'materialize', '.'],
#  ['this', 'means', 'two', 'things', '.'],
#  ['officially', ',', 'this', 'has', 'not', 'yet', 'been', 'acknowledged', '.'],
#  ['that', 'makes', 'everyone', 'less', 'safe', '.'],
#  ['now', 'the', 'key', 'is', 'to', 'make', 'this', 'effort', 'work', '.'],
#  ['the', 'lessons', 'of', 'history', 'are', 'clear', '.'],
#  ['he', 'was', 'then', 'told', 'to', 'identify', 'himself', '.'],
#  ['that', ',', 'too', ',', 'would', 'not', 'have', 'been', 'unusual', '.'],
#  ['class', 'and', 'race', 'overlap', 'in', 'the', 'us', '.'],
#  ['crowley',
#   'never',
#   'mentioned',
#   'the',
#   'color',
#   'of',
#   'gates',
#   '’',
#   'skin',
#   '.'],
#  ['it',
#   '’',
#   's',
#   '“',
#   'serious',
#   ',',
#   '”',
#   'the',
#   'smitten',
#   'president',
#   'admitted',
#   '.'],
#  ['(', 'sarkozy', 'is', 'now', 'twice', 'divorced', '.', ')'],
#  ['sarkozy', 'could', 'make', 'that', 'dream', 'come', 'true', '.'],
#  ['we', 'already', 'know', 'this', '.'],
#  ['iran', 'is', 'the', 'most', 'current', 'example', 'of', 'this', '.'],
#  ['honni', 'soit', 'qui', 'mal', 'y', 'pense', '!'],
#  ['the', 'cap', 'must', 'be', 'born', 'again', '.'],
#  ['but', 'a', 'much', 'more', 'profound', 're-think', 'is', 'needed', '.'],
#  ['but', 'that', 'attitude', 'is', 'undermining', 'change', '.'],
#  ['this', 'argument', 'is', 'both', 'disingenuous', 'and', 'dishonest', '.'],
#  ['there', 'is', 'a', 'deeper', 'issue', 'at', 'stake', '.'],
#  ['with', 'donor', 'help', ',', 'they', 'can', '.'],
#  ['the', 'current', 'aid', 'structures', 'are', 'inadequate', '.'],
#  ['the', 'time', 'for', 'business', 'as', 'usual', 'is', 'over', '.'],
#  ['meanwhile',
#   ',',
#   'a',
#   'billion',
#   'people',
#   'go',
#   'hungry',
#   'each',
#   'day',
#   '.'],
#  ['it', 'doesn', '’', 't', 'have', 'to', 'be', 'this', 'way', '.'],
#  ['on', 'the', 'contrary', ',', 'everything', 'becomes', 'brighter', '.'],
#  ['this', 'claim', 'was', 'hugely', 'misguided', '.'],
#  ['perhaps', 'they', 'are', 'right', '.'],
#  ['these', 'are', 'all', 'very', 'important', 'issues', '.'],
#  ['but', 'the', 'mere', 'figures', 'are', 'simply', 'not', 'enough', '.'],
#  ['such', 'a', 'basis', 'is', 'not', 'hard', 'to', 'find', '.'],
#  ['the', 'climate', 'problem', 'does', 'not', 'stop', 'at', 'borders', '.'],
#  ['i',
#   'suspect',
#   'that',
#   'many',
#   'will',
#   'agree',
#   'with',
#   'this',
#   'view',
#   '.'],
#  ['these', 'are', ',', 'of', 'course', ',', 'hypothetical', 'questions', '.'],
#  ['we', 'don', '’', 't', 'yet', 'know', 'what', 'is', 'possible', '.'],
#  ['and',
#   'what',
#   'does',
#   'it',
#   'say',
#   'about',
#   'us',
#   'if',
#   'we',
#   'won',
#   '’',
#   't',
#   '?'],
#  ['yet',
#   'their',
#   'regime',
#   'is',
#   'in',
#   'crisis',
#   ',',
#   'and',
#   'they',
#   'know',
#   'it',
#   '.'],
#  ['military', 'reform', 'has', 'been', 'reversed', '.'],
#  ['the',
#   'country',
#   'is',
#   'unruly',
#   ',',
#   'and',
#   'its',
#   'rulers',
#   'know',
#   'it',
#   '.'],
#  ['they', 'have', 'also', 'become', 'disobedient', '.'],
#  ['cherkesov', '’', 's', 'deputy', 'remains', 'in', 'prison', '.'],
#  ['cherkesov',
#   '’',
#   's',
#   'case',
#   'exemplifies',
#   'putin',
#   '’',
#   's',
#   'nightmare',
#   '.'],
#  ['this', 'is', 'putin', '’', 's', 'plan', '.'],
#  ['it', 'is', 'a', 'bizarre', 'ideology', '.'],
#  ['the', 'answer', 'is', ':', 'very', 'poor', '.'],
#  ['israel',
#   '’',
#   's',
#   'main',
#   'concern',
#   'continues',
#   'to',
#   'be',
#   'security',
#   '.'],
#  ['netanyahu', '’', 's', 'project', 'is', 'not', 'moral', '.'],
#  ['time', 'is', 'running', 'out', 'in', 'kosovo', '.'],
#  ['that', 'would', 'be', 'a', 'disastrous', 'step', '.'],
#  ['serbia', 'is', 'even', 'more', 'strongly', 'opposed', '.'],
#  ['i', 'learned', 'this', 'by', 'accident', '.'],
#  ['there', 'are', 'some', 'major', 'themes', '.'],
#  ['hence', 'their', 'impulse', 'to', 'believe', 'in', 'unseen', 'forces', '.'],
#  ['today',
#   ',',
#   'kuchma',
#   'rules',
#   'as',
#   'an',
#   'all-powerful',
#   'president',
#   '.'],
#  ['sopuissant', 'a', 'caesar', 'must', 'be', 'above', 'reproach', '.'],
#  ['as', 'president', ',', 'kuchma', 'is', 'grotesquely', 'unpopular', '.'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'stimulus',
#   'itself',
#   'is',
#   'contractionary',
#   '.'],
#  ['we',
#   'have',
#   'but',
#   'one',
#   'planet',
#   ',',
#   'and',
#   'should',
#   'treasure',
#   'it',
#   '.'],
#  ['public', 'debt', 'continued', 'to', 'grow', '.'],
#  ['the', 'advanced', 'countries', 'have', 'a', 'choice', '.'],
#  ['so', 'falling', 'trust', 'had', 'real', 'economic', 'consequences', '.'],
#  ['this', 'has', 'been', 'positive', 'for', 'the', 'stock', 'market', '.'],
#  ['others', 'are', 'congenitally', 'distrustful', '.'],
#  ['what', 'will', 'reverse', 'it', '?'],
#  ['economists', 'did', 'not', 'predict', 'that', 'event', ',', 'either', '.'],
#  ['but', 'the', 'book', 'is', 'almost', 'entirely', 'non-theoretical', '.'],
#  ['it', 'merely', 'documents', 'recurrent', 'patterns', '.'],
#  ['there', 'is', 'a', 'no', 'easy', 'way', 'out', '.'],
#  ['it', 'is', 'high', 'time', 'to', 'consider', 'novel', 'approaches', '.'],
#  ['this', 'will', 'take', 'some', 'time', 'to', 'implement', '.'],
#  ['they', 'should', 'be', 'unified', 'throughout', 'the', 'region', '.'],
#  ['participation', 'by', 'romania', 'and', 'moldova', 'is', 'optional', '.'],
#  ['but', 'that', 'process', 'has', 'a', 'long', 'way', 'to', 'go', '.'],
#  ['october', '24', 'is', '350', 'day', '.'],
#  ['the', 'melting', 'of', 'arctic', 'ice', 'is', 'one', 'example', '.'],
#  ['other', 'feedback', 'loops', 'pose', 'a', 'similar', 'danger', '.'],
#  ['there', 'is', 'yet', 'another', 'lesson', 'to', 'be', 'learned', '.'],
#  ['all', 'this', 'is', 'perfectly', 'true', '.'],
#  ['will', 'this', 'spell', 'doom', 'for', 'developing', 'countries', '?'],
#  ['first', 'comes', 'growth', 'driven', 'by', 'foreign', 'borrowing', '.'],
#  ['china', 'exemplified', 'this', 'approach', '.'],
#  ['but', 'it', 'wasn', '’', 't', 'just', 'china', '.'],
#  ['it', 'did', 'so', 'with', 'democracy', 'and', 'freedom', '.'],
#  ['american', 'foreign', 'policy', 'reflects', 'that', 'obsession', '.'],
#  ['yet', 'malaria', 'is', 'preventable', 'and', 'treatable', '.'],
#  ['it', 'has', 'so', 'far', 'failed', 'to', 'act', '.'],
#  ['the', 'list', 'goes', 'on', 'and', 'on', '.'],
#  ['but', 'a', 'euro', 'exit', 'would', 'be', 'a', 'messy', 'affair', '.'],
#  ['this',
#   'policy',
#   'can',
#   'also',
#   'help',
#   'on',
#   'the',
#   'fiscal',
#   'front',
#   '.'],
#  ['the', 'same', 'is', 'true', 'of', 'minimum', 'wages', '.'],
#  ['fiscal', 'devaluations', 'already', 'have', 'some', 'advocates', '.'],
#  ['or',
#   'they',
#   'believe',
#   'that',
#   'their',
#   'light',
#   'is',
#   '“',
#   'funny',
#   '.',
#   '”'],
#  ['who', 'decides', 'when', 'something', 'is', 'luxurious', '?'],
#  ['and', 'where', 'does', 'this', 'end', '?'],
#  ['this',
#   'is',
#   'where',
#   'a',
#   'lot',
#   'of',
#   'policymakers',
#   'get',
#   'it',
#   'wrong',
#   '.'],
#  ['can', 'the', 'situation', 'get', 'worse', '?'],
#  ['yes', ',', 'it', 'can', ':', 'much', 'worse', '.'],
#  ['america', "'s", 'appallingly', 'low', 'savings', 'rate', '.'],
#  ['lax', 'accounting', 'standards', '.'],
#  ['here', "'s", 'a', 'plausible', 'scenario', '.'],
#  ['but', 'america', 'today', 'appears', 'less', 'safe', '.'],
#  ['they',
#   "'re",
#   'free',
#   'to',
#   'choose',
#   'where',
#   'to',
#   'put',
#   'their',
#   'money',
#   '.'],
#  ['i', 'am', 'not', 'predicting', 'that', 'this', 'will', 'happen', '.'],
#  ['how', 'is', 'the', 'wassenaar', 'model', 'relevant', 'to', 'brazil', '?'],
#  ['czechoslovakia', 'split', 'into', 'two', 'separate', 'states', '.'],
#  ['none', 'of', 'this', 'holds', 'true', 'today', '.'],
#  ['could', 'any', 'common', 'european', 'state', 'do', 'worse', '?'],
#  ['so', 'they', 'elected', 'one', 'as', 'president', '.'],
#  ['but',
#   'such',
#   'a',
#   'dynamic',
#   'does',
#   'now',
#   'seem',
#   'to',
#   'be',
#   'in',
#   'motion',
#   '.'],
#  ['but', 'how', 'will', 'sarajevo', 'look', 'in', 'five', 'years', '?'],
#  ['the', 'future', 'promises', 'peace', 'without', 'development', '.'],
#  ['but', 'it', 'is', 'now', 'or', 'never', 'for', 'the', 'balkans', '.'],
#  ['the', 'reason', 'is', 'simple', '.'],
#  ['that', 'is', 'the', 'risk', 'today', '.'],
#  ['the', 'soft', 'patch', 'may', 'be', 'closer', 'to', 'a', 'quagmire', '.'],
#  ['that', 'is', 'certainly', 'true', 'of', 'the', 'united', 'states', '.'],
#  ['the', 'odds', 'on', 'either', 'are', 'exceedingly', 'poor', '.'],
#  ['this', 'is', 'because', 'cyprus', 'remains', 'a', 'divided', 'island', '.'],
#  ['but', 'they', 'are', 'reacting', 'to', 'the', 'current', 'situation', '.'],
#  ['fifteen',
#   'years',
#   'later',
#   ',',
#   'no',
#   'country',
#   'has',
#   'done',
#   'that',
#   '.'],
#  ['are', 'china', 'and', 'india', 'being', 'unreasonable', '?'],
#  ['that', 'catastrophe', 'must', 'be', 'forestalled', '.'],
#  ['reykjavik', 'proved', 'that', 'boldness', 'is', 'rewarded', '.'],
#  ['our', 'world', 'remains', 'too', 'militarized', '.'],
#  ['many', 'denounced', 'sharon', "'s", 'plan', 'as', 'a', 'trick', '.'],
#  ['then', 'there', 'are', 'the', 'strategic', 'hawks', '.'],
#  ['he', 'has', 'brought', 'neither', '.'],
#  ['then', 'we', 'squabble', 'about', 'what', 'to', 'do', '.'],
#  ['the', 'time', 'for', 'such', 'laxity', 'is', 'over', '.'],
#  ['that', 'consensus', 'must', 'include', 'the', 'us', '.'],
#  ['intentions', 'do', "n't", 'deter', 'invasions', '.'],
#  ['prevent', 'local', 'conflict', ';'],
#  ['promote', 'human', 'rights', 'and', 'democracy', ';'],
#  ['the', 'impressive', 'gains', 'don', '’', 't', 'stop', 'there', '.'],
#  ['so', 'what', 'is', 'not', 'to', 'like', '?'],
#  ['how', ',', 'you', 'might', 'ask', ',', 'can', 'i', 'say', 'this', '?'],
#  ['but', 'there', 'are', 'two', 'things', 'different', 'about', 'today', '.'],
#  ['second', ',', 'bond', 'investors', 'are', 'being', 'really', 'stupid', '.'],
#  ['they',
#   'are',
#   'willing',
#   'to',
#   'pay',
#   '6',
#   '%',
#   'per',
#   'year',
#   'for',
#   '“',
#   'safety',
#   '.',
#   '”'],
#  ['thus', ',', 'royal', '’', 's', 'program', 'is', 'her', 'popularity', '.'],
#  ['then', 'there', 'are', 'strategic', 'suspicions', '.'],
#  ['does', 'the', 'european', 'union', 'care', '?'],
#  ['the', 'crucial', 'issue', 'is', 'market', 'access', '.'],
#  ['the', 'european', 'commission', 'understands', 'this', '.'],
#  ['herbivorous', 'fish', 'are', 'key', 'players', 'on', 'coral', 'reefs', '.'],
#  ['two',
#   'things',
#   'can',
#   'be',
#   'done',
#   'to',
#   'protect',
#   'coral',
#   'reefs',
#   '.'],
#  ['roughly', '95', '%', 'of', 'our', 'agriculture', 'is', 'hi-tech', '.'],
#  ['what',
#   'israel',
#   'can',
#   'do',
#   ',',
#   'others',
#   'can',
#   'do',
#   'as',
#   'well',
#   '.'],
#  ['nothing', 'could', 'be', 'more', 'incorrect', '.'],
#  ['then', 'france', 'embraced', 'germany', '.'],
#  ['usually', 'france', 'likes', 'to', 'keep', 'its', 'options', 'open', '.'],
#  ['this', 'has', 'obviously', 'caused', 'frustrations', '.'],
#  ['but',
#   'it',
#   'should',
#   'not',
#   'have',
#   'been',
#   'a',
#   'surprise',
#   'to',
#   'anyone',
#   '.'],
#  ['chirac',
#   'and',
#   'schröder',
#   'do',
#   'not',
#   'seem',
#   'to',
#   'grasp',
#   'this',
#   '.'],
#  ['instructors', 'from', 'abroad', 'can', 'not', 'enter', 'gaza', '.'],
#  ['life', 'in', 'gaza', 'has', 'bled', 'away', 'my', 'optimism', '.'],
#  ['my', 'mother', 'is', 'a', 'housekeeper', '.'],
#  ['i', 'have', 'six', 'brothers', 'and', 'three', 'sisters', '.'],
#  ['that', 'was', 'at', 'the', 'height', 'of', 'the', 'peace', 'process', '.'],
#  ['but',
#   'when',
#   'i',
#   'was',
#   'ten',
#   ',',
#   'the',
#   'secondintifada',
#   'began',
#   '.'],
#  ['sometimes',
#   ',',
#   'i',
#   'am',
#   'sorry',
#   'that',
#   'i',
#   'am',
#   'from',
#   'gaza',
#   '.'],
#  ['we', 'are', 'students', ',', 'not', 'soldiers', '.'],
#  ['we', 'are', 'not', 'fighters', 'in', 'this', 'conflict', '.'],
#  ['why', 'doesn', '’', 't', 'israel', 'let', 'us', 'go', 'study', '?'],
#  ['educated',
#   ',',
#   'pushy',
#   'mothers',
#   'make',
#   'all',
#   'the',
#   'difference',
#   '.'],
#  ['but', 'the', 'boom', 'is', 'not', 'uniform', '.'],
#  ['we', 'know', 'how', 'to', 'do', 'this', '.'],
#  ['in',
#   'the',
#   'middle',
#   'east',
#   ',',
#   'we',
#   'must',
#   'break',
#   'the',
#   'stalemate',
#   '.'],
#  ['palestinians', 'deserve', 'a', 'state', '.'],
#  ['israel', 'needs', 'security', '.'],
#  ['syria', 'is', 'a', 'special', 'concern', '.'],
#  ['the', 'moment', 'to', 'act', 'is', 'now', '.'],
#  ['the', 'violence', 'must', 'stop', '.'],
#  ['let', 'our', 'common', 'agenda', 'begin', '.'],
#  ['batten', 'down', 'the', 'hatches', '.'],
#  ['each', 'of', 'us', 'senses', 'this', 'challenge', 'almost', 'daily', '.'],
#  ['but', 'time', 'is', 'running', 'very', 'short', '.'],
#  ['now', 'the', 'corporate', 'sector', 'has', 'two', 'faces', '.'],
#  ['two', 'wrongs', 'don', '’', 't', 'make', 'a', 'right', '.'],
#  ['more',
#   'than',
#   'the',
#   'usual',
#   '“',
#   'blame',
#   'game',
#   '”',
#   'is',
#   'at',
#   'work',
#   'here',
#   '.'],
#  ['only', 'consumption', 'is', 'lagging', '.'],
#  ['how',
#   'will',
#   'the',
#   'ecb',
#   'react',
#   'to',
#   'better',
#   'economic',
#   'news',
#   '?'],
#  ['this', 'raises', 'an', 'interesting', 'point', '.'],
#  ['let',
#   '’',
#   's',
#   'begin',
#   'with',
#   'why',
#   'the',
#   'euro',
#   'needs',
#   'to',
#   'fall',
#   '.'],
#  ['the', 'first', 'concerns', 'the', 'market', 'response', '.'],
#  ['yet', 'koizumi', 'remains', 'defiant', '.'],
#  ['bilateral', 'relations', 'were', 'frozen', '.'],
#  ['admittedly', ',', 'sometimes', 'time', 'is', 'a', 'luxury', '.'],
#  ['figures', 'for', 'the', 'ictr', 'are', 'only', 'slightly', 'better', '.'],
#  ['but', 'such', 'agreement', 'is', 'extraordinary', '.'],
#  ['alas', ',', 'the', 'revolution', 'soon', 'bogged', 'down', '.'],
#  ['they', 'will', 'most', 'likely', 'succeed', '.'],
#  ['the', 'diet', '’', 's', 'role', 'was', 'merely', 'pro', 'forma', '.'],
#  ['so', 'the', 'lesson', 'from', 'the', 'recession', 'is', 'clear', '.'],
#  ['opportunism',
#   'has',
#   'had',
#   'its',
#   'share',
#   'in',
#   'this',
#   ',',
#   'of',
#   'course',
#   '.'],
#  ['moreover', ',', 'kundera', '’', 's', 'case', 'is', 'hardly', 'unique', '.'],
#  ['this', 'is', 'not', 'only', 'dangerous', ',', 'but', 'incoherent', '.'],
#  ['finally', ',', 'the', 'idea', 'is', 'impracticable', '.'],
#  ['this', 'is', 'the', 'thrust', 'of', 'mccain', '’', 's', 'message', '.'],
#  ['this', 'is', 'crazy', 'and', 'unhistorical', '.'],
#  ['to', 'see', 'why', ',', 'consider', 'nigeria', '.'],
#  ['it', 'was', 'also', 'a', 'matter', 'of', 'national', 'pride', '.'],
#  ['but', 'that', 'did', 'not', 'happen', '.'],
#  ['only', 'the', 'ecb', 'can', 'provide', 'this', 'insurance', '.'],
#  ['it', 'now', 'needs', 'to', 'be', 'implemented', '.'],
#  ['spanish', 'borrowing', 'costs', 'are', 'also', 'rising', '.'],
#  ['greece', 'is', 'clearly', 'insolvent', '.'],
#  ['this', 'can', 'happen', 'in', 'a', 'number', 'of', 'ways', '.'],
#  ['then', ',', 'there', 'is', 'the', 'issue', 'of', 'trust', '.'],
#  ['are', 'we', 'going', 'to', 'be', 'in', 'a', 'war', '?'],
#  ['on',
#   'a',
#   'third',
#   'issue',
#   ',',
#   'the',
#   'results',
#   'so',
#   'far',
#   'are',
#   'mixed',
#   '.'],
#  ['over-diagnosis', 'of', 'bipolar', 'disorder', 'has', 'costs', '.'],
#  ['we',
#   'have',
#   'seen',
#   'evidence',
#   'of',
#   'this',
#   'in',
#   'our',
#   'practice',
#   '.'],
#  ['the', 'idea', 'is', 'compelling', '.'],
#  ['but', 'the', 'ipo', 'soon', 'sunk', 'miserably', '.'],
#  ['could', 'the', 'opposite', 'happen', '?'],
#  ['actual', 'imf', 'equilibrium', 'rate'],
#  ['dollar/euro', '(', '$', '/_', ')', '0.88', '1.26'],
#  ['yen/euro', '(', '-/_', ')', '93.1', '113.3'],
#  ['they', 'keep', 'the', 'world', 'growing', '!'],
#  ['yes', ',', 'the', 'euro', 'can', 'tend', 'toward', 'dollar', 'parity', '.'],
#  ['it', 'has', 'no', 'chance', 'to', 'shine', '.'],
#  ['now', 'they', 'are', 'a', 'global', 'obsession', '.'],
#  ['noodles', 'are', 'beating', 'spaghetti', '.'],
#  ['some', 'of', 'this', 'is', 'unsurprising', '.'],
#  ['that', 'is', 'far', 'harder', 'to', 'judge', '.'],
#  ['this', 'is', 'risky', 'speculation', '.'],
#  ['white', 'balloons', 'were', 'launched', 'everywhere', '.'],
#  ['it', 'is', 'perhaps', 'a', 'beginning', '.'],
#  ['first', ',', 'heavy', 'tv', 'viewing', 'brings', 'little', 'pleasure', '.'],
#  ['the',
#   'same',
#   ',',
#   'of',
#   'course',
#   ',',
#   'has',
#   'happened',
#   'to',
#   'politics',
#   '.'],
#  ['even',
#   'war',
#   'can',
#   'be',
#   'rolled',
#   'out',
#   'as',
#   'a',
#   'new',
#   'product',
#   '.'],
#  ['at',
#   'the',
#   'very',
#   'least',
#   ',',
#   'we',
#   'can',
#   'minimize',
#   'those',
#   'dangers',
#   '.'],
#  ['of', 'course', ',', 'the', 'alternative', 'is', 'no', 'safer', '.'],
#  ['everyone',
#   'agrees',
#   'that',
#   'iran',
#   'has',
#   'the',
#   'right',
#   'to',
#   'do',
#   'so',
#   '.'],
#  ['these', 'are', 'violent', 'times', '.'],
#  ['ruthless', 'leaders', 'mobilize', 'disoriented', 'followers', '.'],
#  ['it', 'has', 'to', 'do', 'with', 'israel', '.'],
#  ['it', 'is', 'linked', 'to', 'israel', '.'],
#  ['this', 'might', 'be', 'done', 'in', 'several', 'ways', '.'],
#  ['but', 'it', 'is', 'not', 'monolithic', '.'],
#  ['such', 'policies', 'might', 'include', ':'],
#  ['its', 'interventionist', 'measures', 'won', '’', 't', 'work', '.'],
#  ['there',
#   'is',
#   'no',
#   'time',
#   'to',
#   'lose',
#   'in',
#   'trying',
#   'something',
#   'new',
#   '.'],
#  ['food', 'riots', 'are', 'mounting', '.'],
#  ['the', 'idea', 'is', 'basic', 'and', 'well', 'known', '.'],
#  ['other', 'low-income', 'countries', 'should', 'follow', 'suit', '.'],
#  ['at', 'bottom', ',', 'the', 'problem', 'is', 'one', 'of', 'legitimacy', '.'],
#  ['good', 'feelings', 'abound', '.'],
#  ['russia',
#   'will',
#   'hold',
#   'a',
#   'presidential',
#   'election',
#   'in',
#   '2012',
#   '.'],
#  ['the', 'president', '’', 's', 'statement', 'was', 'unexpected', '.'],
#  ['society', 'will', 'support', 'him', '.'],
#  ['the', 'standard', 'of', 'living', 'was', 'low', '.'],
#  ['this', 'is', 'one', 'unclaimed', 'opportunity', '.'],
#  ['the', 'us', 'has', 'made', 'profound', 'missteps', 'recently', '.'],
#  ['why', 'are', 'these', 'new', 'bodies', 'needed', '?'],
#  ['far', 'more', 'needs', 'to', 'be', 'done', '.'],
#  ['it', 'is', 'cheap', 'because', 'it', 'is', 'plentiful', '.'],
#  ['it', 'is', 'time', 'to', 'embrace', 'them', '.'],
#  ['after', 'all', ',', 'today', '’', 's', 'models', 'work', '.'],
#  ['consider', 'the', 'brain', ',', 'for', 'example', '.'],
#  ['independent', 'thinking', 'is', 'an', 'underestimated', 'factor', '.'],
#  ['or', 'if', 'you', 'wish', ',', 'discovered', '.'],
#  ['the', 'main', 'problems', 'are', 'easily', 'identified', '.'],
#  ['these', 'issues', 'will', 'not', 'be', 'resolved', 'overnight', '.'],
#  ['leu', 'can', 'not', 'be', 'used', 'to', 'make', 'weapons', '.'],
#  ['but', 'this', 'can', 'only', 'be', 'a', 'first', 'step', '.'],
#  ['but',
#   'the',
#   'us',
#   'should',
#   'not',
#   'succumb',
#   'to',
#   'this',
#   'temptation',
#   '.'],
#  ['in',
#   'fact',
#   ',',
#   'democracy',
#   'is',
#   'in',
#   'deep',
#   'trouble',
#   'in',
#   'america',
#   '.'],
#  ['obama', 'has', 'the', 'right', 'vision', '.'],
#  ['in', '2005', ',', 'we', 'can', 'begin', 'to', 'change', 'direction', '.'],
#  ['what', 'we', 'learned', 'is', 'easily', 'summarized', '.'],
#  ['therein', 'lies', 'the', 'path', 'to', 'sustained', 'peace', '.'],
#  ['or', 'will', 'it', 'be', '“', 'excellent', 'in', 'parts', '”', '?'],
#  ['the', 'probable', 'answer', 'is', ':', 'both', '.'],
#  ['the', 'situation', 'in', 'libya', 'today', 'is', 'not', 'identical', '.'],
#  ['but', 'qaddafi', 'is', 'shrewd', '.'],
#  ['we', 'can', 'not', 'wait', 'for', 'that', 'to', 'happen', '.'],
#  ['china', 'and', 'russia', 'have', 'expressed', 'reservations', '.'],
#  ['on', 'that', 'front', ',', 'there', 'are', 'promising', 'signs', '.'],
#  ['the', 'arab', 'league', 'has', 'endorsed', 'a', 'similar', 'proposal', '.'],
#  ['fresh', 'water', 'is', 'one', 'such', 'area', '.'],
#  ['water', 'flows', 'on', 'the', 'surface', 'and', 'underground', '.'],
#  ['moreover', ',', 'demand', 'for', 'water', 'changes', 'over', 'time', '.'],
#  ['these', 'are', 'eminently', 'negotiable', 'issues', '.'],
#  ['everything', 'else', 'can', 'be', 'worked', 'out', '.'],
#  ['water', 'is', 'the', 'essence', 'of', 'life', '.'],
#  ['cooperating',
#   'to',
#   'secure',
#   'it',
#   'is',
#   'the',
#   'only',
#   'way',
#   'forward',
#   '.'],
#  ['last',
#   'year',
#   ',',
#   'there',
#   'were',
#   'two',
#   'sides',
#   'to',
#   'the',
#   'debate',
#   '.'],
#  ['if',
#   'so',
#   ',',
#   'a',
#   'correction',
#   'can',
#   'not',
#   'be',
#   'too',
#   'far',
#   'behind',
#   '.'],
#  ['this', 'idea', 'has', 'logic', 'behind', 'it', '.'],
#  ['yet', 'no', 'live', 'apes', 'were', 'used', '.'],
#  ['but', 'he', 'also', 'understood', 'the', 'ethical', 'issue', '.'],
#  ['that', '’', 's', 'exploitative', '.', '”'],
#  ['this', 'divergence', 'is', 'mirrored', 'in', 'public', 'finances', '.'],
#  ['adjustments', 'will', 'need', 'to', 'be', 'made', '.'],
#  ['but', 'even', 'there', ',', 'risks', 'lurk', '.'],
#  ['so', 'security', 'vigilance', 'is', 'essential', '.'],
#  ['so',
#   'where',
#   'are',
#   'the',
#   'calls',
#   'for',
#   'woodward',
#   '’',
#   's',
#   'arrest',
#   '?'],
#  ['the', 'associated', 'press', 'refuses', 'to', 'comment', 'on', 'him', '.'],
#  ['but', 'that', 'mission', 'now', 'seems', 'lost', 'in', 'america', '.'],
#  ['in', '2003', ',', 'it', 'was', 'sars', '.'],
#  ['there',
#   'are',
#   'more',
#   'bacteria',
#   'than',
#   'any',
#   'other',
#   'life',
#   'form',
#   '.'],
#  ['prions', 'are', 'a', 'relatively', 'new', 'discovery', '.'],
#  ['in', 'practical', 'terms', ',', 'how', 'should', 'it', 'be', 'built', '?'],
#  ['this', 'is', 'not', 'as', 'difficult', 'as', 'it', 'sounds', '.'],
#  ['the', 'key', 'is', 'to', 'harness', 'existing', 'infrastructure', '.'],
#  ['can', 'a', 'public', 'figure', 'have', 'a', 'private', 'life', '?'],
#  ['growth', ',', 'indeed', ',', 'is', 'accelerating', '.'],
#  ['this', 'year', 'it', 'will', 'be', 'nearly', 'eliminated', '.'],
#  ['the', 'last', 'real', 'worry', 'was', 'the', 'foreign', 'balance', '.'],
#  ['we', 'have', 'been', 'here', 'before', '.'],
#  ['developed', 'countries', 'did', 'not', 'learn', '.'],
#  ['that', 'has', 'not', 'happened', '.'],
#  ['but', 'there', 'is', 'a', 'wider', 'lesson', '.'],
#  ['and', 'yet', 'that', 'could', 'very', 'well', 'happen', '.'],
#  ['this', 'can', 'be', 'achieved', '.'],
#  ['the', 'same', 'should', 'apply', 'to', 'turkey', '.'],
#  ['why', 'not', 'in', 'iraqi', 'kurdistan', '?'],
#  ['today', ',', 'both', 'factors', 'have', 'changed', '.'],
#  ['the', 'perception', 'of', 'military', 'parity', 'has', 'altered', '.'],
#  ['this', 'is', 'turkey', '’', 's', 'moment', 'of', 'truth', '.'],
#  ['but', 'the', 'situation', 'is', 'not', 'irretrievable', '.'],
#  ['yet', 'they', 'have', 'not', 'saved', 'us', '.'],
#  ['is', 'there', 'a', 'different', 'way', '?'],
#  ['do',
#   'we',
#   'want',
#   'to',
#   'save',
#   'ourselves',
#   'and',
#   'our',
#   'children',
#   '?'],
#  ['why', 'didn', '’', 't', 'we', 'say', 'so', '?'],
#  ['the', 'world', 'is', 'poised', 'to', 'act', '.'],
#  ['the', 'extremist', 'positions', 'are', 'clear', '.'],
#  ['no', 'land-for-peace', 'deal', 'will', 'satisfy', 'either', 'side', '.'],
#  ['the', 'moderates', 'are', 'understandably', 'wary', '.'],
#  ['but', 'this', 'largely', 'ignored', 'the', 'role', 'of', 'extremists', '.'],
#  ['that', 'dynamic', 'is', 'still', 'at', 'work', '.'],
#  ['the',
#   'roadmap',
#   'is',
#   '--',
#   'so',
#   'far',
#   '--',
#   'silent',
#   'on',
#   'this',
#   'issue',
#   '.'],
#  ['but', 'moderates', 'raised', 'red', 'flags', ',', 'too', '.'],
#  ['the', 'kanjorski', 'amendment', 'is', 'a', 'very', 'big', 'stick', '.'],
#  ['but',
#   'the',
#   'army',
#   'as',
#   'a',
#   'whole',
#   'is',
#   'not',
#   'anti-democratic',
#   '.'],
#  ['paris', '–', 'russia', 'is', 'not', 'egypt', '.'],
#  ['and', 'not', 'all', 'russians', 'are', 'in', 'the', 'streets', '.'],
#  ['that', 'applies', 'to', 'russia', ',', 'too', '.'],
#  ['but', 'this', 'comparison', 'has', 'limits', '.'],
#  ['it', 'is', 'past', 'time', 'to', 'move', 'forward', '.'],
#  ['others',
#   'returned',
#   'home',
#   'and',
#   'were',
#   'welcomed',
#   'as',
#   'heroes',
#   '.'],
#  ['we', 'saudis', 'have', 'failed', 'to', 'do', 'the', 'same', '.'],
#  ['educated', 'hijazis', 'ask', 'only', 'for', 'modest', 'reforms', '.'],
#  ['yet', 'even', 'moderation', 'is', 'dismissed', 'by', 'the', 'al-saud', '.'],
#  ['inclusion', 'is', 'the', 'less', 'dangerous', 'path', '.'],
#  ['those', 'risks', 'will', 'not', 'go', 'away', '.'],
#  ['the', 'big', 'one', 'will', 'one', 'day', 'strike', 'california', '.'],
#  ['the', 'concept', 'is', 'simple', '.'],
#  ['(', 'cancer-preventing', 'tomatoes', ',', 'take', 'notice', '.', ')'],
#  ['but', 'none', 'of', 'this', 'can', 'be', 'relied', 'upon', '.'],
#  ['so', ',', 'what', 'needs', 'to', 'be', 'done', '?'],
#  ['first', ',', 'eurozone', 'banks', 'have', 'to', 'be', 'recapitalized', '.'],
#  ['but', 'we', 'are', 'where', 'we', 'are', '.'],
#  ['this', 'is', 'a', 'recipe', 'for', 'trouble', '.'],
#  ['the', 'world', 'has', 'a', 'stake', 'in', 'their', 'resolution', '.'],
#  ['unresolved', ',', 'the', 'crisis', 'will', 'spare', 'no', 'one', '.'],
#  ['there',
#   'have',
#   'been',
#   'few',
#   'convictions',
#   'for',
#   'these',
#   'crimes',
#   '.'],
#  ['so', 'other', 'policies', 'are', 'needed', 'to', 'restore', 'growth', '.'],
#  ['it', 'seems', 'the', 'story', 'never', 'ends', '.'],
#  ['they', 'are', 'also', 'facing', 'huge', 'uncertainties', '.'],
#  ['that', 'is', 'largely', 'the', 'job', 'of', 'government', '.'],
#  ['the',
#   'us',
#   'is',
#   'not',
#   'the',
#   'only',
#   'economy',
#   'in',
#   'this',
#   'equation',
#   '.'],
#  ['this', 'will', 'have', 'to', 'change', '.'],
#  ['this', 'time', 'we', 'will', 'need', 'global', 'cooperation', '.'],
#  ['consider', 'also', 'the', 'credit', 'markets', '.'],
#  ['the', 'challenges', 'facing', 'both', 'are', 'monumental', '.'],
#  ['that', 'pattern', 'is', 'much', 'less', 'prevalent', 'in', 'europe', '.'],
#  ['initially',
#   ',',
#   'the',
#   'new',
#   'arrangement',
#   'worked',
#   'very',
#   'well',
#   '.'],
#  ['the', 'country', 'thus', 'had', 'problems', 'exporting', '.'],
#  ['it', 'developed', 'external', 'deficits', 'and', 'growth', 'slowed', '.'],
#  ['now',
#   ',',
#   'it',
#   'is',
#   'moving',
#   'into',
#   'pakistan',
#   'and',
#   'west',
#   'asia',
#   '.'],
#  ['this', 'explains', 'high', 'economic', 'growth', 'rates', '.'],
#  ['what', 'can', 'even', 'more', 'isolation', 'achieve', '?'],
#  ['i', 'was', 'in', 'pakistan', 'as', 'a', 'state', 'guest', '.'],
#  ['this', 'has', 'spread', 'a', 'sense', 'of', 'unfairness', '.'],
#  ['look', 'at', 'our', 'television', 'programs', '.'],
#  ['that', 'pattern', 'reflected', 'cold', 'war', 'imperatives', '.'],
#  ['dissenting', 'views', 'found', 'little', 'traction', '.'],
#  ['vote-buying', 'became', 'increasingly', 'insufficient', '.'],
#  ['by', '2001', ',', 'the', 'cold', 'war', 'was', 'long', 'over', '.'],
#  ['thailand', '’', 's', 'demographics', 'also', 'changed', '.'],
#  ['we', 'live', 'in', 'an', 'era', 'of', 'low', 'predictability', '.'],
#  ['the', 'world', 'appears', 'in', 'constant', 'flux', '.'],
#  ['the', 'challenges', 'are', 'immense', '.'],
#  ['but', 'there', 'are', 'ways', 'to', 'waste', 'less', '.'],
#  ['transparency', 'in', 'procurement', 'works', 'wonders', '.'],
#  ['so', ',', 'too', ',', 'does', 'private', 'sector', 'involvement', '.'],
#  ['that', 'is', 'in', 'the', 'common', 'interest', '.'],
#  ['here', 'is', 'a', 'list', 'of', 'things', 'to', 'watch', 'for', '.'],
#  ['will', 'the', 'us', 'response', 'be', '“', 'bold', '”', 'enough', '?'],
#  ['will', 'europe', 'get', 'its', 'act', 'together', '?'],
#  ['this', 'could', 'have', 'been', 'europe', '’', 's', 'moment', '.'],
#  ['will', 'china', 'hold', 'together', '?'],
#  ['will', 'there', 'be', 'enough', 'global', 'economic', 'cooperation', '?'],
#  ['the',
#   'imf',
#   'has',
#   'not',
#   'been',
#   'immune',
#   'to',
#   'this',
#   'treatment',
#   '.'],
#  ['ultimately', ',', 'development', 'is', 'about', 'people', '.'],
#  ['reality', 'is', 'more', 'complex', '.'],
#  ['nostalgia', 'is', 'not', 'what', 'it', 'used', 'to', 'be', '.'],
#  ['and', 'now', 'we', 'are', 'back', 'to', 'reality', '.'],
#  ['this', 'is', 'a', 'strikingly', 'bad', 'idea', '.'],
#  ['fundamental', 'political', 'reform', 'is', 'needed', '.'],
#  ['true', ',', 'arab', 'leaders', 'differ', 'over', 'tactics', '.'],
#  ['but',
#   ',',
#   'the',
#   'irish',
#   'story',
#   'has',
#   'not',
#   'had',
#   'a',
#   'happy',
#   'ending',
#   '.'],
#  ['i', 'asked', 'them', 'to', 'set', 'priorities', 'for', 'the', 'world', '.'],
#  ['all', 'important', 'problems', '.'],
#  ['each', 'should', 'be', 'tackled', '.'],
#  ['the', 'ambassadors', 'showed', 'courage', '.'],
#  ['communicable', 'diseases'],
#  ['scaled-up', 'basic', 'health', 'services'],
#  ['community-managed', 'water', 'supply', 'and', 'sanitation'],
#  ['malnutrition', 'and', 'hunger'],
#  ['improving', 'infant', 'and', 'child', 'nutrition'],
#  ['malnutrition', 'and', 'hunger'],
#  ['communicable', 'diseases'],
#  ['communicable', 'diseases'],
#  ['malnutrition', 'and', 'hunger'],
#  ['reducing', 'micro', 'nutrient', 'deficiencies'],
#  ['subsidies', 'and', 'trade', 'barriers'],
#  ['optimistic', 'doha', ':', '50', '%', 'liberalization'],
#  ['improve', 'quality', '/', 'systemic', 'reforms'],
#  ['small-scale', 'water', 'technology', 'for', 'livelihoods'],
#  ['expand', 'demand', 'for', 'schooling'],
#  ['malnutrition', 'and', 'hunger'],
#  ['migration', 'for', 'development'],
#  ['re-using', 'waste', 'water', 'for', 'agriculture'],
#  ['guest', 'worker', 'policies'],
#  ['sustainable', 'food', 'and', 'fish', 'production', 'in', 'wetlands'],
#  ['grassroots', 'monitoring', 'and', 'service', 'delivery'],
#  ['active', 'immigration', 'policies'],
#  ['subsidies', 'and', 'trade', 'barriers'],
#  ['pessimistic', 'doha', ':', '25', '%', 'liberalization'],
#  ['aid', 'as', 'conflict', 'prevention'],
#  ['reform', 'of', 'revenue', 'collection'],
#  ['financial', 'instability'],
#  ['financial', 'instability'],
#  ['re-regulate', 'domestic', 'financial', 'markets'],
#  ['shortening', 'conflicts', ':', 'natural', 'resource', 'tracking'],
#  ['financial', 'instability'],
#  ['reimpose', 'capital', 'controls'],
#  ['financial', 'instability'],
#  ['adopt', 'a', 'common', 'currency'],
#  ['subsidies', 'and', 'trade', 'barriers'],
#  ['full', 'reform', ':', '100', '%', 'liberalization'],
#  ['value-at-risk', 'carbon', 'tax'],
#  ['a',
#   'carbon',
#   'tax',
#   'starting',
#   'at',
#   '$',
#   '2',
#   'and',
#   'ending',
#   'at',
#   '$',
#   '20'],
#  ['you',
#   'need',
#   'to',
#   'login',
#   'in',
#   'order',
#   'to',
#   'leave',
#   'a',
#   'comment',
#   '.'],
#  ['enter', 'and', 'post', 'your', 'comment', '.'],
#  ['2', ')', 'paragraph', 'commentplease', 'log', 'in', 'first', '.'],
#  ['then',
#   'click',
#   'to',
#   'the',
#   'left',
#   'of',
#   'the',
#   'desired',
#   'paragraph',
#   '.'],
#  ['enter', 'and', 'post', 'your', 'comment', '.'],
#  ['your', 'name', 'is', 'required', '.'],
#  ['your', 'email', 'is', 'required', '.'],
#  ['your', 'friend', "'s", 'name', 'is', 'required', '.'],
#  ['your', 'friend', "'s", 'email', 'is', 'required', '.'],
#  ['a', 'message', 'is', 'required', '.'],
#  ['the', 'email', 'was', 'sent', 'successfully', '.'],
#  ['but', 'google', '’', 's', 'plan', 'had', 'a', 'catch', '.'],
#  ['they', 'do', 'not', 'derive', 'from', 'a', 'social', 'contract', '.'],
#  ['indeed',
#   ',',
#   'they',
#   'are',
#   'part',
#   'of',
#   'what',
#   'makes',
#   'us',
#   'human',
#   '.'],
#  ['each', 'of', 'us', 'may', 'enjoy', 'rights', '.'],
#  ['europe', ',', 'by', 'contrast', ',', 'is', 'clearly', 'lagging', '.'],
#  ['should', 'europeans', 'be', 'worried', '?'],
#  ['this', 'process', 'is', 'starting', 'in', 'europe', 'only', 'now', '.'],
#  ['obviously', ',', 'such', 'a', 'comparison', 'has', 'its', 'limits', '.'],
#  ['today', ',', 'we', 'also', 'share', 'a', 'common', 'enemy', '.'],
#  ['they', 'will', 'not', 'negotiate', 'a', 'separate', 'peace', '.'],
#  ['who', 'decides', 'what', 'is', 'free', 'and', 'fair', '?'],
#  ['i', '’', 've', 'learned', 'my', 'lesson', 'about', 'musharraf', '.'],
#  ['the', 'same', 'is', 'true', 'of', 'democracy', '.'],
#  ['perhaps', ',', 'but', 'this', 'is', 'probably', 'a', 'red', 'herring', '.'],
#  ['these', 'anxieties', 'have', 'too', 'often', 'been', 'ignored', '.'],
#  ['the',
#   'muslim',
#   'threat',
#   'is',
#   ',',
#   'of',
#   'course',
#   ',',
#   'not',
#   'a',
#   'fantasy',
#   '.'],
#  ['nothing', 'good', 'ever', 'came', 'from', 'that', '.'],
#  ['the', 'warrant', 'was', 'no', 'leap', 'forward', '.'],
#  ['in',
#   'this',
#   'case',
#   ',',
#   'justice',
#   'comes',
#   'with',
#   'poisoned',
#   'arrows',
#   '.'],
#  ['a',
#   'law',
#   'that',
#   'can',
#   'not',
#   'be',
#   'enforced',
#   'deters',
#   'no',
#   'one',
#   '.'],
#  ['in', 'fact', ',', 'it', 'weakens', 'respect', 'for', 'law', '.'],
#  ['indeed',
#   ',',
#   'it',
#   'is',
#   'likely',
#   'to',
#   'prolong',
#   'wicked',
#   'regimes',
#   '.'],
#  ['international', 'law', 'is', 'the', 'conscience', 'of', 'mankind', '.'],
#  ['i',
#   'call',
#   'this',
#   'strategy',
#   'the',
#   '“',
#   'watershed',
#   'doctrine',
#   '.',
#   '”'],
#  ['we', 'find', 'watersheds', 'throughout', 'american', 'history', '.'],
#  ['but', 'arms-control', 'skeptics', 'take', 'issue', 'with', 'this', '.'],
#  ['it', 'all', 'depends', 'on', 'the', 'path', 'chosen', '.'],
#  ['new', 'york', '–', 'the', 'world', 'is', 'at', 'a', 'crossroads', '.'],
#  ['the', 'world', 'should', 'not', 'accept', 'the', 'status', 'quo', '.'],
#  ['market',
#   'logic',
#   ',',
#   'it',
#   'is',
#   'argued',
#   ',',
#   'dictates',
#   'this',
#   'result',
#   '.'],
#  ['but',
#   'this',
#   'premise',
#   'is',
#   'wrong',
#   ',',
#   'for',
#   'three',
#   'reasons',
#   '.'],
#  ['in', 'the', 'end', ',', 'that', 'will', 'be', 'a', 'good', 'thing', '.'],
#  ['it', 'has', 'fostered', 'regional-scale', 'infrastructure', '.'],
#  ['we',
#   'are',
#   ',',
#   'in',
#   'short',
#   ',',
#   'moving',
#   'to',
#   'a',
#   'multi-polar',
#   'world',
#   '.'],
#  ['so', 'you', 'thought', 'this', 'year', 'was', 'bad', '!'],
#  ['2009', 'began', 'with', 'the', 'flattening', 'of', 'gaza', '.'],
#  ['greed', 'was', 'just', 'taking', 'a', 'temporary', 'break', '.'],
#  ['he', '’', 'll', 'certainly', 'have', 'his', 'work', 'cut', 'out', '.'],
#  ['let', '’', 's', 'be', 'clear', 'about', 'what', 'is', 'happening', '.'],
#  ['weaker', 'economies', 'will', 'also', 'feel', 'the', 'pinch', '.'],
#  ['anything',
#   'short',
#   'of',
#   'that',
#   'would',
#   'be',
#   'very',
#   'bad',
#   'news',
#   '.'],
#  ['what', 'explains', 'this', 'odd', 'behavior', '?'],
#  ['not', 'blind', 'faith', 'in', 'technology', '.'],
#  ['nobody', 'can', 'be', 'sure', 'that', 'it', 'will', 'work', 'either', '.'],
#  ['such', 'efforts', 'are', 'getting', 'discretely', 'underway', '.'],
#  ['russia',
#   '’',
#   's',
#   'early',
#   '``',
#   'nyet',
#   "''",
#   'may',
#   'not',
#   'be',
#   'the',
#   'last',
#   'word',
#   '.'],
#  ['but', 'what', 'about', 'china', '?'],
#  ['it', 'is', 'also', 'bad', 'news', 'for', 'america', 'and', 'china', '.'],
#  ['american', 'populism', 'will', 'meet', 'chinese', 'pride', '.'],
#  ['just', '27', '%', 'chose', 'america', '.'],
#  ['a', 'full-scale', 'trade', 'war', 'is', 'unlikely', '.'],
#  ['but', 'these', 'spasms', 'will', 'not', 'revive', 'the', 'corpse', '.'],
#  ['this', 'is', 'somewhat', 'reassuring', '.'],
#  ['why', 'is', 'the', 'adb', 'constricting', 'its', 'agenda', '?'],
#  ['as',
#   'food',
#   'prices',
#   'rise',
#   ',',
#   'so',
#   'is',
#   'hunger',
#   'and',
#   'poverty',
#   '.'],
#  ['all',
#   'of',
#   'these',
#   'are',
#   'good',
#   ',',
#   'but',
#   'they',
#   'are',
#   'insufficient',
#   '.'],
#  ['his', 'was', 'the', 'aristocracy', 'of', 'the', 'spirit', '.'],
#  ['that', 'neglect', 'is', 'a', 'human', 'tragedy', '.'],
#  ['consider', 'a', 'couple', 'of', 'notorious', 'examples', '.'],
#  ['these', 'measures', 'are', 'achievable', 'by', '2010', '.'],
#  ['as', "goldstone's", 'report', 'makes', 'clear', ':'],
#  ['but', 'what', 'else', 'is', 'aid', 'if', 'it', 'is', 'not', 'revenue', '?'],
#  ['the',
#   'balance',
#   'sheet',
#   'is',
#   'improved',
#   'by',
#   '$',
#   '500',
#   'million',
#   '.'],
#  ['but', 'in', 'most', 'cases', ',', 'this', 'is', 'not', 'possible', '.'],
#  ['we', 'see', 'five', 'keys', 'to', 'recovery', ':'],
#  ['this', 'is', ',', 'in', 'part', ',', 'inevitable', '.'],
#  ['that', 'has', 'now', 'changed', '.'],
#  ['and', 'this', 'is', 'just', 'the', 'baseline', 'scenario', '.'],
#  ['these', 'need', 'to', 'adapt', ',', 'too', '.'],
#  ['what', 'of', 'the', 'large', 'advanced', 'countries', '?'],
#  ['the', 'political', 'narrative', 'runs', 'in', 'parallel', '.'],
#  ['it', 'is', 'also', 'often', 'ignored', '.'],
#  ['much', 'less', 'work', 'has', 'been', 'devoted', 'to', 'adaptation', '.'],
#  ['farmers', 'will', 'choose', 'plants', 'that', 'thrive', 'in', 'heat', '.'],
#  ['poor', 'countries', 'will', 'be', 'hit', 'harder', ',', 'however', '.'],
#  ['the', 'sovereign-debt', 'crisis', 'is', 'well', 'known', '.'],
#  ['greece', 'essentially', 'defaulted', 'on', 'some', 'obligations', '.'],
#  ['the', 'immediate', 'causes', 'are', 'well', 'known', '.'],
#  ['the', 'subtext', 'is', 'clear', ':', 'be', 'like', 'us', 'now', '.'],
#  ['modesty', 'is', 'a', 'virtue', 'in', 'private', 'life', '.'],
#  ['in',
#   'most',
#   'cases',
#   ',',
#   'neither',
#   'can',
#   'be',
#   'remedied',
#   'overnight',
#   '.'],
#  ['but',
#   'they',
#   'remain',
#   'in',
#   'existence',
#   'three',
#   'decades',
#   'later',
#   '.'],
#  ['in',
#   'fact',
#   ',',
#   'they',
#   'are',
#   'so',
#   'right',
#   'that',
#   'they',
#   'are',
#   'wrong',
#   '.'],
#  ['that',
#   '’',
#   's',
#   'not',
#   'a',
#   'lot',
#   'of',
#   'bang',
#   'for',
#   'the',
#   'buck',
#   '.'],
#  ['we', 'can', 'do', 'the', 'same', 'for', 'clean', 'energy', '.'],
#  ['the', 'younger', 'the', 'girl', ',', 'the', 'higher', 'the', 'price', '.'],
#  ['yet', 'women', 'are', 'precious', 'in', 'their', 'own', 'way', '.'],
#  ['illegal', 'logging', 'crews', 'number', '200', 'or', 'more', '.'],
#  ['they', 'have', 'chain', 'saws', 'and', 'trucks', '.'],
#  ['unloved', 'little', 'girls', 'fare', 'the', 'worst', '.'],
#  ['but',
#   'note',
#   'that',
#   'it',
#   'occurred',
#   'near',
#   'a',
#   'health',
#   'facility',
#   '.'],
#  ['opium', 'is', 'choking', 'afghan', 'society', '.'],
#  ['within', 'afghanistan', ',', 'drug', 'addiction', 'is', 'rising', '.'],
#  ['farmers', 'are', 'a', 'different', 'story', '.'],
#  ['that', 'situation', 'needs', 'to', 'be', 'reversed', '.'],
#  ['we', 'can', 'not', 'afford', 'to', 'fail', 'in', 'afghanistan', '.'],
#  ['these', 'may', 'seem', 'to', 'be', 'distinct', 'issues', '.'],
#  ['in', 'fact', ',', 'they', 'are', 'linked', '.'],
#  ['hunger', 'is', 'omnipresent', '.'],
#  ['nor', 'should', 'they', 'have', 'to', '.'],
#  ['rich', 'countries', 'need', 'to', 'lead', 'the', 'way', '.'],
#  ['no', 'amount', 'of', 'money', 'will', 'undo', 'the', 'damage', 'done', '.'],
#  ['it', 'was', 'that', 'word', '``', 'development', "''", 'again', '.'],
#  ['do',
#   'we',
#   'really',
#   '``',
#   'develop',
#   "''",
#   'leaders',
#   'or',
#   'countries',
#   '?'],
#  ['but', 'perhaps', 'he', 'knows', 'better', '.'],
#  ['was', 'kofi', 'annan', '``', 'developed', '?', "''"],
#  ['countries', 'like', 'ghana', 'do', 'not', 'lack', 'enterprise', '.'],
#  ['markets', 'and', 'personal', 'initiative', 'are', 'pervasive', '.'],
#  ['globalization', 'must', 'not', 'be', 'allowed', 'to', 'blind', 'us', '.'],
#  ['rarely', 'have', 'i', 'been', 'so', 'profoundly', 'moved', '.'],
#  ['uganda', 'was', 'the', 'epicenter', 'of', 'the', 'aids', 'epidemic', '.'],
#  ['yet', 'uganda', 'is', 'also', 'a', 'success', 'story', '.'],
#  ['meanwhile', ',', 'money', 'for', 'treatment', 'is', 'drying', 'up', '.'],
#  ['worldwide', ',', 'the', 'number', 'is', 'about', '10', 'million', '.'],
#  ['those', 'who', 'rallied', 'to', 'the', 'fight', 'are', 'alarmed', '.'],
#  ['surely', 'we', 'can', 'do', 'better', '.'],
#  ['the', 'war', 'was', 'over', '.', 'but', 'not', 'for', 'me', '.'],
#  ['i', 'became', 'an', 'expert', 'in', 'tank', 'warfare', '.'],
#  ['i', 'have', 'no', 'regrets', ',', 'i', 'offer', 'no', 'apologies', '.'],
#  ['injustice', 'provokes', 'children', 'to', 'pick', 'up', 'guns', '.'],
#  ['of', 'course', ',', 'no', 'child', 'should', 'go', 'to', 'war', '.'],
#  ['i', 'survived', 'and', 'learned', '.'],
#  ['i', 'learned', 'the', 'limits', 'of', 'the', 'gun', '.'],
#  ['yet', 'most', 'died', 'in', 'combat', 'or', 'of', 'aids', '.'],
#  ['domestic', 'capital', 'markets', 'were', 'non-existent', '.'],
#  ['litigation', 'can', 'be', 'costly', 'and', 'hazardous', '.'],
#  ['meles', 'was', 'certainly', 'both', '.'],
#  ['africa', 'has', 'about', '50', 'billion', 'tons', '.'],
#  ['britain', 'nationalizes', 'its', 'banks', '.'],
#  ['but',
#   'haven',
#   '’',
#   't',
#   'we',
#   'heard',
#   'this',
#   'all',
#   'before',
#   'in',
#   'africa',
#   '?'],
#  ['that', 'allegiance', 'is', 'misplaced', '.'],
#  ['what', 'it', 'does', 'not', 'require', 'is', 'a', 'currency', 'union', '.'],
#  ['but', 'there', 'is', 'a', 'remedy', 'at', 'hand', '.'],
#  ['this', 'policy', 'poses', 'two', 'practical', 'problems', '.'],
#  ['so', 'why', 'are', "n't", 'africans', 'celebrating', '?'],
#  ['but',
#   'graft',
#   'and',
#   'theft',
#   'are',
#   'not',
#   'the',
#   'only',
#   'problems',
#   '.'],
#  ['the', 'call', 'went', 'unheeded', '.'],
#  ['why', 'does', 'africa', 'remain', 'poor', '?'],
#  ['without',
#   'her',
#   'help',
#   ',',
#   'i',
#   'might',
#   'not',
#   'have',
#   'farmed',
#   'at',
#   'all',
#   '.'],
#  ['even',
#   'with',
#   'mother',
#   '’',
#   's',
#   'help',
#   ',',
#   'i',
#   'have',
#   'worries',
#   '.'],
#  ['one', 'key', 'tool', 'is', 'the', 'mobile', 'phone', '.'],
#  ['certain',
#   'crops',
#   'can',
#   'be',
#   'grown',
#   'in',
#   'their',
#   'own',
#   'homes',
#   '.'],
#  ['but',
#   'the',
#   'facts',
#   'on',
#   'the',
#   'ground',
#   'do',
#   'not',
#   'bear',
#   'this',
#   'out',
#   '.'],
#  ['nor', 'is', 'the', 'icc', 'a', 'foreign', 'body', '.'],
#  ['arafat', 'never', 'really', 'agreed', 'to', 'share', 'power', '.'],
#  ['that', 'is', 'the', 'problem', '.', "''"],
#  ['but', 'at', 'some', 'point', ',', 'arafat', 'will', 'depart', '.'],
#  ['this',
#   'problem',
#   'will',
#   'not',
#   'go',
#   'away',
#   'when',
#   'arafat',
#   'does',
#   '.'],
#  ['human', 'migration', 'is', 'as', 'old', 'as', 'history', '.'],
#  ['what', 'then', 'is', 'the', 'alternative', 'to', 'assimilation', '?'],
#  ['but', 'it', 'can', 'not', 'be', 'had', 'for', 'nothing', '.'],
#  ['there', 'are', 'alternative', 'strategies', '.'],
#  ['the', 'eib', 'should', 'expand', 'its', 'lending', '.'],
#  ['and', 'the', 'crisis', 'itself', 'almost', 'surely', 'will', 'spread', '.'],
#  ['but', 'that', 'is', 'what', 'europe', 'is', 'doing', '.'],
#  ['fortunately', ',', 'there', 'is', 'an', 'alternative', '.'],
#  ['ultimately', ',', 'chernobyl', 'changed', 'the', 'world', '.'],
#  ['international', 'support', 'for', 'our', 'efforts', 'is', 'crucial', '.'],
#  ['we', 'are', 'a', 'european', 'nation', '.'],
#  ['every', 'case', 'has', 'its', 'own', 'defining', 'features', '.'],
#  ['they', 'had', 'good', 'reasons', 'to', 'complain', '.'],
#  ['a',
#   'second',
#   'general',
#   'issue',
#   'has',
#   'to',
#   'do',
#   'with',
#   'priorities',
#   '.'],
#  ['the', 'second', 'imperative', 'is', 'the', 'rule', 'of', 'law', '.'],
#  ['this', 'is', 'notably', 'the', 'case', 'in', 'economic', 'terms', '.'],
#  ['no', 'single', 'instrument', 'will', 'work', 'everywhere', '.'],
#  ['seoul', '–', 'korea', 'is', 'a', 'unique', 'country', '.'],
#  ['call', 'itfast-forward', 'modernization', '.'],
#  ['indeed', ',', 'the', 'revolution', 'is', 'already', 'upon', 'us', '.'],
#  ['take', 'the', 'example', 'of', 'computers', '.'],
#  ['this', 'conflict', 'exists', 'globally', '.'],
#  ['so',
#   'long',
#   'as',
#   'these',
#   'ideas',
#   'clash',
#   ',',
#   'violence',
#   'will',
#   'lurk',
#   '.'],
#  ['the', 'implications', 'are', 'clear', '.'],
#  ['efforts', 'to', 'do', 'so', 'usually', 'ended', 'disastrously', '.'],
#  ['not', 'only', 'political', 'forces', 'need', 'to', 'be', 'checked', '.'],
#  ['this', 'was', 'the', 'golden', 'age', 'of', 'finance', '.'],
#  ['is', 'this', 'a', 'short-term', 'phenomenon', '?'],
#  ['will', 'financial', '“', 'deepening', '”', 'continue', '?'],
#  ['financial-sector', 'returns', 'are', 'likely', 'to', 'be', 'lower', '.'],
#  ['that', 'will', 'not', 'be', 'easy', '.'],
#  ['let', '’', 's', 'start', 'with', 'the', 'united', 'states', '.'],
#  ['but', 'these', 'complaints', 'miss', 'the', 'point', '.'],
#  ['still', ',', 'a', 'central', 'paradox', 'plagues', 'the', 'mdgs', '.'],
#  ['this', 'kind', 'of', 'reorientation', 'will', 'not', 'be', 'easy', '.'],
#  ['the', 'trends', 'are', 'similar', 'elsewhere', 'in', 'europe', '.'],
#  ['the', 'priorities', 'are', 'clear', '.'],
#  ['but', 'examples', 'of', 'smart', 'migration', 'practices', 'abound', '.'],
#  ['land-mines', 'defile', 'the', 'countryside', '.'],
#  ['afghanistan', 'is', 'no', 'place', 'for', 'quick', 'fixes', '.'],
#  ['rebuilding', 'the', 'country', 'can', 'not', 'be', 'done', 'cheaply', '.'],
#  ['but', 'stripped', 'they', 'must', 'be', '.'],
#  ['reasonableness', 'does', 'not', 'always', 'yield', 'results', '.'],
#  ['there', 'are', 'bright', 'spots', ',', 'of', 'course', '.'],
#  ['none',
#   'of',
#   'this',
#   'detracts',
#   'from',
#   'the',
#   'resilience',
#   'factor',
#   '.'],
#  ['and', 'now', 'it', 'risks', 'missing', 'another', 'important', 'clue', '.'],
#  ['the', 'novel', 'is', 'blinding', ',', 'by', 'claudio', 'magris', '.'],
#  ['unfortunately', ',', 'that', 'is', 'no', 'surprise', '.'],
#  ['new',
#   'york',
#   '–',
#   'the',
#   'critics',
#   'of',
#   'foreign',
#   'aid',
#   'are',
#   'wrong',
#   '.'],
# ...
#  ['the', 'story', 'goes', 'back', 'to', 'the', 'recession', 'of', '2001', '.'],
#  ['that', 'is', 'certainly', 'true', 'of', 'greenspan', '.'],
#  ['it', 'is', 'also', 'filled', 'with', 'propaganda', '.'],
#  ['for', '40', 'years', ',', 'compassion', 'in', 'politics', 'receded', '.'],
#  ['bill',
#   'clinton',
#   'continued',
#   'those',
#   'cuts',
#   'in',
#   'the',
#   '1990',
#   '’',
#   's',
#   '.'],
#  ['the', 'world', 'should', 'beware', '.'],
#  ['this', 'reinforces', 'the', 'stalemate', '.'],
#  ['obama', 'has', 'dramatically', 'increased', 'spending', '.'],
#  ['in', 'fact', ',', 'it', 'had', 'deep', 'roots', '.'],
#  ['the', 'household', 'sector', 'is', 'especially', 'important', '.'],
#  ['that', 'means', 'forgoing', 'some', 'government', 'services', '.'],
#  ['•', 'additional', 'deficit', 'spending', ';'],
#  ['but', 'will', 'congress', 'act', 'quickly', '?'],
#  ['don', '’', 't', 'hold', 'your', 'breath', '.'],
#  ['it', 'has', 'not', 'always', 'been', 'this', 'way', '.'],
#  ['it', 'backs', 'the', 'ethiopian', 'army', 'in', 'somalia', '.'],
#  ['it', 'occupies', 'iraq', 'and', 'afghanistan', '.'],
#  ['it', 'threatens', 'to', 'bomb', 'iran', '.'],
#  ['naturally', ',', 'many', 'join', 'radical', 'causes', '.'],
#  ['we', 'all', 'breathe', 'the', 'same', 'air', '.'],
#  ['but', 'what', 'are', 'they', 'really', 'buying', '?'],
#  ['and', 'that', 'is', 'not', 'something', 'you', 'want', 'to', 'buy', '.'],
#  ['after',
#   'all',
#   ',',
#   'the',
#   'united',
#   'states',
#   'had',
#   'been',
#   'attacked',
#   '.'],
#  ['that', 'message', 'is', 'bad', 'news', 'for', 'american', 'diplomacy', '.'],
#  ['countries', 'take', 'others', '’', 'advice', 'for', 'many', 'reasons', '.'],
#  ['but', 'what', 'if', 'there', 'is', 'no', 'money', 'to', 'offer', '?'],
#  ['but',
#   'there',
#   'was',
#   'no',
#   'response',
#   'from',
#   'the',
#   'us',
#   'government',
#   '.'],
#  ['she', 'has', 'never', 'recanted', '.'],
#  ['it', 'is', 'still', 'not', 'too', 'late', '.'],
#  ['it', 'need', 'only', 'seize', 'the', 'g-zero', 'moment', '.'],
#  ['sometimes', 'reason', 'does', 'prevail', '.'],
#  ['we',
#   'scratch',
#   'our',
#   'heads',
#   'about',
#   'america',
#   '’',
#   's',
#   'gun',
#   'laws',
#   '.'],
#  ['it', 'is', 'hugely', 'expensive', '.'],
#  ['the', 'poor', 'go', 'unprotected', '.'],
#  ['too', 'many', 'of', 'the', 'sick', 'are', 'untreated', '.'],
#  ['communism', 'in', 'toronto', 'and', 'london', '?'],
#  ['but', 'no', 'bubble', 'can', 'expand', 'forever', '.'],
#  ['there', 'is', 'a', 'macro-story', 'and', 'a', 'micro-story', 'here', '.'],
#  ['the', 'macro-story', 'is', 'simple', ',', 'but', 'dramatic', '.'],
#  ['the', 'micro-story', 'is', 'more', 'dramatic', '.'],
#  ['in',
#   'the',
#   'face',
#   'of',
#   'such',
#   'uncertainty',
#   ',',
#   'markets',
#   'froze',
#   '.'],
#  ['for', 'where', 'should', 'they', 'park', 'their', 'money', '?'],
#  ['this', 'raises', 'serious', 'ethical', 'questions', '.'],
#  ['accountability', 'is', 'also', 'being', 'flouted', '.'],
#  ['others', 'should', 'feel', 'encouraged', 'to', 'follow', 'suit', '.'],
#  ['another', 'six', 'months', 'should', 'not', 'be', 'lost', '.'],
#  ['here',
#   ',',
#   'too',
#   ',',
#   'another',
#   'six',
#   'months',
#   'should',
#   'not',
#   'be',
#   'lost',
#   '.'],
#  ['another', 'six', 'months', 'have', 'been', 'lost', '.'],
#  ['but', 'the', 'us', 'government', 'won', '’', 't', 'address', 'them', '.'],
#  ['that', 'america', 'may', 'be', 'gone', 'for', 'good', '.'],
#  ['the', 'opening', 'was', 'less', 'than', 'it', 'seemed', '.'],
#  ['for',
#   'cambodia',
#   ',',
#   'the',
#   'figure',
#   'would',
#   'be',
#   'about',
#   '62',
#   '%',
#   '.'],
#  ['it', 'was', 'imperative', 'that', 'such', 'unity', 'be', 'destroyed', '.'],
#  ['the', 'cause', 'is', 'no', 'secret', '.'],
#  ['none', 'of', 'this', 'can', 'occur', 'in', 'a', 'vacuum', '.'],
#  ['yet',
#   'the',
#   'us',
#   'found',
#   'a',
#   'way',
#   'to',
#   'finesse',
#   'this',
#   'problem',
#   '.'],
#  ['there', 'are', 'obvious', 'reasons', 'for', 'this', '.'],
#  ['but', 'don', '’', 't', 'count', 'on', 'it', '.'],
#  ['let',
#   'us',
#   'hope',
#   'that',
#   'it',
#   'will',
#   'be',
#   'short',
#   'and',
#   'shallow',
#   '.'],
#  ['this',
#   'view',
#   'seems',
#   'intuitively',
#   'correct',
#   ',',
#   'but',
#   'is',
#   'it',
#   '?'],
#  ['the', 'gargantuan', 'us', 'trade', 'deficit', '?'],
#  ['at', 'some', 'point', ',', 'the', 'party', 'is', 'going', 'to', 'end', '.'],
#  ['can', 'the', 'end', 'come', 'abruptly', 'in', '2006', '?'],
#  ['in',
#   'the',
#   'united',
#   'states',
#   ',',
#   'this',
#   'is',
#   'truer',
#   'than',
#   'ever',
#   '.'],
#  ['it', 'must', 'be', 'cut', ',', 'but', 'how', '?'],
#  ['the', 'result', 'is', 'a', 'dangerous', 'paradox', '.'],
#  ['it', 'makes', 'sense', 'to', 'tax', 'them', 'more', '.'],
#  ['this',
#   'month',
#   ',',
#   'they',
#   'succeeded',
#   ',',
#   'at',
#   'least',
#   'for',
#   'now',
#   '.'],
#  ['in',
#   'the',
#   'end',
#   ',',
#   'i',
#   'don',
#   '’',
#   't',
#   'think',
#   'they',
#   'will',
#   'succeed',
#   '.'],
#  ['but',
#   'make',
#   'no',
#   'mistake',
#   ':',
#   'both',
#   'parties',
#   'are',
#   'implicated',
#   '.'],
#  ['that', 'sum', 'will', 'not', 'come', 'from', 'the', 'poor', '.'],
#  ['obama',
#   'swept',
#   'to',
#   'power',
#   'on',
#   'the',
#   'promise',
#   'of',
#   'change',
#   '.'],
#  ['so', 'far', 'there', 'has', 'been', 'none', '.'],
#  ['this', ',', 'too', ',', 'will', 'take', 'time', '.'],
#  ['yet', 'the', 'time', 'for', 'change', 'will', 'come', '.'],
#  ['i', 'believe', 'that', 'they', 'will', 'be', 'proved', 'wrong', '.'],
#  ['in', 'the', 'end', ',', 'our', 'hopes', 'were', 'frustrated', '.'],
#  ['very', 'little', 'was', 'added', 'to', 'current', 'spending', '.'],
#  ['this', 'is', 'especially', 'true', 'of', 'bachmann', '.'],
#  ['they', 'use', 'emotive', 'rhetoric', '.'],
#  ['they', 'create', 'an', '“', 'us', 'versus', 'them', '”', 'scenario', '.'],
#  ['this', 'reasoning', 'resonates', 'with', 'the', 'us', 'public', '.'],
#  ['indeed',
#   ',',
#   'america',
#   '’',
#   's',
#   'major',
#   'threat',
#   'is',
#   'from',
#   'within',
#   '.'],
#  ['exports', 'top', 'the', 'list', 'of', 'possibilities', '.'],
#  ['the', 'same', 'is', 'true', 'of', 'services', '.'],
#  ['the', 'withdrawal', 'plan', 'is', 'causing', 'countless', 'worries', '.'],
#  ['militarily', ',', 'this', 'argument', 'does', 'make', 'sense', '.'],
#  ['the', 'net', 'saving', 'rate', 'fell', 'to', 'near', 'zero', '.'],
#  ['mortgages', 'became', 'more', 'widely', 'available', '.'],
#  ['the', 'stock', 'market', 'dropped', 'sharply', '.'],
#  ['this', 'is', 'easy', 'to', 'demonstrate', '.'],
#  ['so',
#   'the',
#   'equation',
#   'is',
#   'simple',
#   ':',
#   '5.5',
#   '%',
#   '-1.5',
#   '%',
#   '-3.5',
#   '%',
#   '=',
#   '0.5',
#   '%',
#   '.'],
#  ['but', 'why', 'does', 'this', 'seem', 'so', 'surprising', '?'],
#  ['it', 'is', 'a', 'community', 'of', 'human', 'beings', '.'],
#  ['memories', 'of', 'the', 'great', 'depression', 'are', 'dying', 'out', '.'],
#  ['now', 'the', 'west', 'is', 'paying', 'the', 'price', '.'],
#  ['i', 'see', 'a', 'very', 'different', 'picture', '.'],
#  ['i', 'really', 'do', 'not', 'know', '.'],
#  ['i', 'think', 'this', 'judgment', 'is', 'wrong', '.'],
#  ['there', 'is', 'no', 'market', 'discipline', '.'],
#  ['we', 'can', 'not', 'afford', 'to', 'let', 'that', 'happen', '.'],
#  ['frighteningly', ',', 'the', 'russians', 'were', 'likely', 'correct', '.'],
#  ['madrid', '–', 'the', 'pacific', 'or', 'the', 'middle', 'east', '?'],
#  ['but', 'how', 'can', 'this', 'be', 'achieved', '?'],
#  ['us', 'public', 'opinion', 'seems', 'to', 'confirm', 'this', '.'],
#  ['consider', 'the', 'middle', 'east', '.'],
#  ['japan',
#   'and',
#   'canada',
#   'have',
#   'said',
#   'they',
#   'plan',
#   'to',
#   'do',
#   'so',
#   '.'],
#  ['of',
#   'course',
#   ',',
#   'the',
#   'us',
#   'lobbies',
#   'would',
#   'have',
#   'none',
#   'of',
#   'it',
#   '.'],
#  ['but', 'it', 'is', 'too', 'early', 'to', 'celebrate', '.'],
#  ['the',
#   'united',
#   'states',
#   'is',
#   'now',
#   'caught',
#   'in',
#   'such',
#   'a',
#   'bind',
#   '.'],
#  ['obama', 'emphasized', 'these', 'themes', 'for', 'good', 'reason', '.'],
#  ['the', 'truth', 'of', 'us', 'politics', 'today', 'is', 'simple', '.'],
#  ['both', 'parties', 'therefore', 'cater', 'to', 'their', 'wishes', '.'],
#  ['first',
#   ',',
#   'it',
#   'has',
#   'contributed',
#   'to',
#   'rising',
#   'oil',
#   'prices',
#   '.'],
#  ['the', 'war', 'changed', 'that', 'equation', '.'],
#  ['instead',
#   ',',
#   'much',
#   'of',
#   'it',
#   'will',
#   'find',
#   'its',
#   'way',
#   'abroad',
#   '.'],
#  ['when',
#   'america',
#   'went',
#   'to',
#   'war',
#   ',',
#   'there',
#   'was',
#   'a',
#   'deficit',
#   '.'],
#  ['the', 'numbers', 'are', 'hard', 'to', 'believe', '.'],
#  ['there', 'is', 'also', 'the', 'promise', 'of', 'new', 'institutions', '.'],
#  ['america', 'should', 'take', 'note', '.'],
#  ['clearly', ',', 'the', 'nuclear', 'door', 'is', 'being', 'reopened', '.'],
#  ['that', 'seems', 'to', 'be', 'happening', '.'],
#  ['none', 'of', 'them', 'has', 'ever', 'been', 'put', 'on', 'trial', '.'],
#  ['they',
#   'were',
#   'left',
#   'there',
#   'for',
#   '18',
#   'or',
#   '24',
#   'hours',
#   ',',
#   'or',
#   'more',
#   '.'],
#  ['but', 'the', 'cia', 'has', 'made', 'mistakes', 'before', '.'],
#  ['the', 'basic', 'situation', 'has', 'been', 'clear', 'for', 'years', '.'],
#  ['rainfall', 'patterns', 'are', 'changing', '.'],
#  ['deserts', 'and', 'dry', 'regions', 'are', 'becoming', 'drier', '.'],
#  ['but', 'the', 'effort', 'needs', 'to', 'start', 'now', '.'],
#  ['she', 'even', 'had', 'an', 'oil', 'tanker', 'named', 'after', 'her', '.'],
#  ['what', 'comes', 'after', 'iraq', '?'],
#  ['the', 'danger', 'of', 'their', 'approach', 'is', 'now', 'obvious', '.'],
#  ['these', 'are', 'not', 'problems', 'you', 'can', 'leave', 'overseas', '.'],
#  ['they', 'follow', 'you', 'home', '.'],
#  ['chaudhuri', 'had', 'a', 'point', '.'],
#  ['like', 'chaudhuri', ',', 'kagan', 'is', 'an', 'engaging', 'writer', '.'],
#  ['his', 'arguments', 'sound', 'reasonable', '.'],
#  ['this', 'is', 'the', 'conceit', 'of', 'all', 'great', 'powers', '.'],
#  ['how', 'can', 'things', 'have', 'come', 'to', 'this', 'america', '?'],
#  ['but', 'the', 'term', 'is', 'confusing', '.'],
#  ['many', 'considered', 'it', 'a', 'global', 'hegemon', '.'],
#  ['now',
#   'many',
#   'have',
#   'gone',
#   'back',
#   'to',
#   'believing',
#   'in',
#   'decline',
#   '.'],
#  ['how',
#   'can',
#   'we',
#   'know',
#   'if',
#   'these',
#   'predictions',
#   'are',
#   'correct',
#   '?'],
#  ['what', 'resources', 'will', 'produce', 'power', '?'],
#  ['power', 'always', 'depends', 'on', 'context', '.'],
#  ['in',
#   'this',
#   'sense',
#   ',',
#   'power',
#   'becomes',
#   'a',
#   'positive',
#   'sum',
#   'game',
#   '.'],
#  ['ultimately',
#   ',',
#   'america',
#   '’',
#   's',
#   'vital',
#   'interests',
#   'prevailed',
#   '.'],
#  ['is', 'such', 'an', 'amnesty', 'a', 'good', 'idea', '?'],
#  ['these', 'are', 'weighty', 'questions', '.'],
#  ['an', 'incomplete', 'list', 'of', 'his', 'crimes', 'includes', ':'],
#  ['he', 'could', 'not', 'move', 'freely', '.'],
#  ['amnesty', 'for', 'saddam', 'hussein', 'is', 'simply', 'intolerable', '.'],
#  ['unfortunately', ',', 'reform', 'was', 'derailed', 'in', '2005', '.'],
#  ['this', 'is', 'a', 'historic', 'fallacy', '.'],
#  ['tolerance', 'and', 'religious', 'freedom', 'must', 'be', 'mutual', '.'],
#  ['no', 'core', 'problem', 'was', 'really', 'tackled', '.'],
#  ['was', 'it', 'capitulating', 'to', 'american', 'hegemony', '?'],
#  ['but', 'what', 'is', 'the', 'reality', 'here', '?'],
#  ['sofear', 'of', 'a', 'panic', 'cancreate', 'a', 'panic', '.'],
#  ['but', 'did', 'the', 'reforms', 'go', 'far', 'enough', '?'],
#  ['these', 'banks', 'areilliquid', 'but', 'notinsolvent', '.'],
#  ['the', 'central', 'bank', 'can', 'help', 'with', 'familiar', 'tools', '.'],
#  ['or', 'perhaps', 'it', 'is', 'not', 'so', 'new', 'after', 'all', '.'],
#  ['they', ',', 'too', ',', 'thirst', 'for', 'freedom', '.'],
#  ['but',
#   'this',
#   'would',
#   'lead',
#   'to',
#   'an',
#   'even',
#   'greater',
#   'tragedy',
#   '.'],
#  ['in', 'fact', ',', 'the', 'exact', 'opposite', 'is', 'true', '.'],
#  ['they', 'need', 'it', 'to', 'talk', 'to', 'their', 'adversaries', '.'],
#  ['the', 'us', 'might', 'also', 'learn', 'from', 'other', 'examples', '.'],
#  ['we', 'have', 'great', 'differences', 'today', '.'],
#  ['djindjic', 'remained', 'pragmatic', ',', 'never', 'doctrinaire', '.'],
#  ['only',
#   'prosperity',
#   'and',
#   'a',
#   '``',
#   'european',
#   'serbia',
#   "''",
#   'mattered',
#   '.'],
#  ['did', 'these', 'short', 'cuts', 'help', 'incite', 'his', 'death', '?'],
#  ['once', 'again', ',', 'serbs', 'face', 'such', 'a', 'moment', '.'],
#  ['but',
#   'it',
#   'is',
#   'the',
#   'eu',
#   'that',
#   'is',
#   'proving',
#   'most',
#   'complicit',
#   '.'],
#  ['but', 'europe', 'can', 'fight', 'back', '.'],
#  ['that', 'risk', 'materialized', 'with', 'the', 'iraq', 'war', '.'],
#  ['this',
#   'is',
#   'the',
#   'stuff',
#   'of',
#   'dictatorship',
#   ',',
#   'not',
#   'democracy',
#   '.'],
#  ['they',
#   'can',
#   'do',
#   'so',
#   'very',
#   'easily',
#   ':',
#   'by',
#   'following',
#   'the',
#   'law',
#   '.'],
#  ['how', 'wrong', 'frum', 'now', 'seems', '.'],
#  ['the', 'british', 'government', 'did', 'say', 'that', '.', "''"],
#  ['but', 'bush', 'did', 'nothing', 'of', 'the', 'sort', '.'],
#  ['but', 'the', 'crisis', 'has', 'invigorated', 'the', 'imf', '.'],
#  ['how',
#   'will',
#   'it',
#   'choose',
#   'to',
#   'deploy',
#   'its',
#   'newfound',
#   'power',
#   '?'],
#  ['this', 'is', 'an', 'important', 'moment', 'for', 'the', 'imf', '.'],
#  ['gore',
#   'also',
#   'frets',
#   'about',
#   'the',
#   'future',
#   'of',
#   'polar',
#   'bears',
#   '.'],
#  ['gore', 'has', 'helped', 'the', 'world', 'to', 'worry', '.'],
#  ['three', 'million', 'lives', 'will', 'be', 'lost', 'to', 'hiv/aids', '.'],
#  ['gore', 'has', 'a', 'very', 'different', 'approach', '.'],
#  ['few', 'expect', 'that', 'to', 'happen', '.'],
#  ['should', 'anything', 'be', 'done', 'about', 'this', '?'],
#  ['they', 'argue', 'that', 'only', 'poverty', 'reduction', 'matters', '.'],
#  ['now', ',', 'all', 'can', 'see', 'these', 'income', 'differences', '.'],
#  ['the',
#   'us',
#   'is',
#   'now',
#   'ground',
#   'zero',
#   'for',
#   'global',
#   'inflation',
#   '.'],
#  ['so', 'what', 'happens', 'next', '?'],
#  ['terrorism', 'is', 'an', 'existential', 'threat', '.'],
#  ['the', 'operation', "'s", 'success', 'was', 'no', 'accident', '.'],
#  ['still', ',', 'i', 'am', 'not', 'complacent', '.'],
#  ['but',
#   'esdp',
#   'is',
#   'not',
#   'at',
#   'the',
#   'core',
#   'of',
#   'our',
#   'efforts',
#   '.'],
#  ['regional', 'conflicts', 'cause', 'anger', 'and', 'resentment', '.'],
#  ['the', 'eu', 'will', 'be', 'tough', 'on', 'terrorism', '.'],
#  ['these', 'are', 'not', 'two', 'fights', ',', 'but', 'one', '.'],
#  ['such', 'complacency', 'is', 'premature', '.'],
#  ['but',
#   'that',
#   'putsch',
#   ',',
#   'thankfully',
#   ',',
#   'ended',
#   'as',
#   'a',
#   'farce',
#   '.'],
#  ['this', 'is', 'not', 'a', 'novel', 'phenomenon', '.'],
#  ['political', 'maps', 'are', 'never', 'carved', 'in', 'stone', '.'],
#  ['stanford',
#   '–',
#   'well',
#   ',',
#   'america',
#   'is',
#   'involved',
#   'at',
#   'last',
#   '.'],
#  ['there', 'is', 'little', 'time', 'to', 'waste', '.'],
#  ['and',
#   'yet',
#   'renewed',
#   'war',
#   'in',
#   'sudan',
#   'is',
#   'not',
#   'inevitable',
#   '.'],
#  ['keep', 'the', 'pressure', 'on', 'them', '.'],
#  ['support', 'the', 'peace', 'process', '.'],
#  ['your', 'voice', 'can', 'prevent', 'a', 'war', '.'],
#  ['there', 'are', 'hard', 'choices', 'to', 'be', 'made', '.'],
#  ['but', 'other', 'things', 'were', 'not', 'equal', '.'],
#  ['but', 'conglomeratization', 'takes', 'time', '.'],
#  ['the', 'bush', 'administration', 'cut', 'taxes', '.'],
#  ['again', ',', 'these', 'were', 'not', 'outright', 'policy', 'mistakes', '.'],
#  ['but', ',', 'either', 'way', ',', 'there', 'will', 'be', 'downsizing', '.'],
#  ['us', 'households', 'will', 'have', 'to', 'start', 'saving', 'again', '.'],
#  ['we', 'are', 'not', 'going', 'to', 'change', 'human', 'nature', '.'],
#  ['we', 'can', 'not', 'make', 'investors', 'less', 'greedy', '.'],
#  ['this', 'trend', 'is', 'not', 'hard', 'to', 'understand', '.'],
#  ['a', 'few', 'key', 'indicators', 'appear', 'to', 'support', 'this', '.'],
#  ['but', 'history', 'never', 'truly', 'repeats', 'itself', '.'],
#  ['this', 'is', 'when', 'feelings', 'of', 'fear', 'arise', '.'],
#  ['this', 'was', 'always', 'bad', 'history', '.'],
#  ['what', 'about', 'inflation', 'targeting', '?'],
#  ...]

# %%
len(en_preprocessed), len(de_preprocessed)
# Out:
# (2000, 2000)

# %%
# for some of the sentences there is not german or english counterpart, i.e. only an empy array []
# therefore we will remove those sentence pairs.
en_preprocessed_clean, de_preprocessed_clean = [], []

for sent_en, sent_de in zip(en_preprocessed, de_preprocessed):
    if sent_en != [] and sent_de != []:
        en_preprocessed_clean.append(sent_en)
        de_preprocessed_clean.append(sent_de)
    else:
        continue

# %%
len(en_preprocessed_clean), len(de_preprocessed_clean)
# Out:
# (1992, 1992)

# %%
for e, d in zip(en_preprocessed_clean, de_preprocessed_clean[:5]):
    print('English:\n', e)
    print('German:\n', d, '\n'*3)
# Out:
# English:
#  ['wouldn', '’', 't', 'you', 'know', 'it', '?']
# German:
#  ['und', 'es', 'kam', ',', 'wie', 'es', 'kommen', 'musste', '.']
#
#
#
# English:
#  ['since', 'then', ',', 'the', 'index', 'has', 'climbed', 'above', '10,000', '.']
# German:
#  ['seit', 'damals', 'ist', 'er', 'auf', 'über', '10.000', 'punkte', 'gestiegen', '.']
#
#
#
# English:
#  ['they', 'departed', 'pledging', 'to', 'revive', 'europe', "'s", 'growth', '.']
# German:
#  ['mit', 'der', 'zusicherung', ',', 'das', 'wachstum', 'in', 'europa', 'wieder', 'zu', 'beleben', ',', 'gingen', 'sie', 'auseinander', '.']
#
#
#
# English:
#  ['we', "'ve", 'heard', 'that', 'empty', 'promise', 'before', '.']
# German:
#  ['dieses', 'leere', 'versprechen', 'haben', 'wir', 'schon', 'einmal', 'gehört', '.']
#
#
#
# English:
#  ['many', 'europeans', 'are', 'sick', 'of', 'british', 'vetoes', '.']
# German:
#  ['viele', 'europäer', 'sind', 'die', 'britischen', 'vetos', 'leid', '.']

# %%
en_most_common[:15], len(en_most_common), len(de_most_common)
# Out:
# ([('.', 1747),
#   ('the', 648),
#   ('is', 559),
#   (',', 437),
#   ('to', 297),
#   ('this', 258),
#   ('a', 239),
#   ('but', 234),
#   ('of', 213),
#   ('not', 197),
#   ('in', 193),
#   ('are', 192),
#   ('?', 184),
#   ('it', 182),
#   ('be', 161)],
#  3174,
#  7078)

# %%
# now we can create oyr lookup dicts for english and german, i.e. our vocab. 
# we will also include special tokens, later on used in the model. 
specials = ["<unk>", "<s>", "</s>", '<pad>']

en_word2ind, en_ind2word, en_vocab_size = nmt_data_utils.create_vocab(en_most_common, specials)
de_word2ind, de_ind2word, de_vocab_size = nmt_data_utils.create_vocab(de_most_common, specials)

# %%
# in order to feed the sentences to the network, we have to convert them to ints, corresponding to their indices
# in the lookup dicts. 
# we reverse the source language sentences, i.e. the english sentences as this alleviates learning for the seq2seq 
# model. Apart from this we also include EndOfSentence and StartOfSentence tags, which are needed as well. 
en_inds, en_unknowns = nmt_data_utils.convert_to_inds(en_preprocessed_clean, en_word2ind, reverse = True, eos = True)
de_inds, de_unknowns = nmt_data_utils.convert_to_inds(de_preprocessed_clean, de_word2ind, sos = True, eos = True)

# %%
[nmt_data_utils.convert_to_words(sentence, en_ind2word) for sentence in  en_inds[:2]]
# Out:
# [['?', 'it', 'know', 'you', 't', '’', 'wouldn', '</s>'],
#  ['.',
#   '10,000',
#   'above',
#   'climbed',
#   'has',
#   'index',
#   'the',
#   ',',
#   'then',
#   'since',
#   '</s>']]

# %%
[nmt_data_utils.convert_to_words(sentence, de_ind2word) for sentence in  de_inds[:2]]
# Out:
# [['<s>',
#   'und',
#   'es',
#   'kam',
#   ',',
#   'wie',
#   'es',
#   'kommen',
#   'musste',
#   '.',
#   '</s>'],
#  ['<s>',
#   'seit',
#   'damals',
#   'ist',
#   'er',
#   'auf',
#   'über',
#   '10.000',
#   'punkte',
#   'gestiegen',
#   '.',
#   '</s>']]

# %%
# hyperparams. 
# those are probably not perfect, but work fine for now. 
num_layers_encoder = 4
num_layers_decoder = 4
rnn_size_encoder = 128
rnn_size_decoder = 128
embedding_dim = 300

batch_size = 64
epochs = 250
clip = 5
keep_probability = 0.8
learning_rate = 0.01
learning_rate_decay_steps = 1000
learning_rate_decay = 0.9

# %%
# create the graph and train the model. 
nmt_model_utils.reset_graph()

nmt = NMT_Model.NMT(en_word2ind,
                    en_ind2word,
                    de_word2ind,
                    de_ind2word,
                    './models/local_one/my_model',
                    'TRAIN',
                    embedding_dim = embedding_dim,
                    num_layers_encoder = num_layers_encoder,
                    num_layers_decoder = num_layers_decoder,
                    batch_size = batch_size,
                    clip = clip,
                    keep_probability = keep_probability,
                    learning_rate = learning_rate,
                    epochs = epochs,
                    rnn_size_encoder = rnn_size_encoder,
                    rnn_size_decoder = rnn_size_decoder, 
                    learning_rate_decay_steps = learning_rate_decay_steps,
                    learning_rate_decay = learning_rate_decay)

nmt.build_graph()
nmt.train(en_inds, de_inds)
# Out:
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\ASUS\Documents\NMT_Model.py:106: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\ASUS\Documents\NMT_Model.py:181: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn.py:443: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn.py:626: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\ASUS\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\ASUS\Documents\NMT_Model.py:331: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# Graph built.
# -------------------- Epoch 0 of 250 --------------------
# Iteration: 0 of 31	train_loss: 8.8653
# Iteration: 2 of 31	train_loss: 8.4461
# Iteration: 4 of 31	train_loss: 7.1284
# Iteration: 6 of 31	train_loss: 6.8229
# Iteration: 8 of 31	train_loss: 7.1070
# Iteration: 10 of 31	train_loss: 7.0631
# Iteration: 12 of 31	train_loss: 7.0428
# Iteration: 14 of 31	train_loss: 6.8448
# Iteration: 16 of 31	train_loss: 6.9675
# Iteration: 18 of 31	train_loss: 7.0251
# Iteration: 20 of 31	train_loss: 6.8486
# Iteration: 22 of 31	train_loss: 7.0440
# Iteration: 24 of 31	train_loss: 6.9041
# Iteration: 26 of 31	train_loss: 6.9234
# Iteration: 28 of 31	train_loss: 6.9437
# Iteration: 30 of 31	train_loss: 6.7897
# Iteration: 31 of 31	train_loss: 7.0300
# Average Score for this Epoch: 7.16456937789917
# --- new best score ---
#
#
# -------------------- Epoch 1 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.9864
# Iteration: 2 of 31	train_loss: 6.4301
# Iteration: 4 of 31	train_loss: 6.3939
# Iteration: 6 of 31	train_loss: 6.2870
# Iteration: 8 of 31	train_loss: 6.4196
# Iteration: 10 of 31	train_loss: 6.4514
# Iteration: 12 of 31	train_loss: 6.4500
# Iteration: 14 of 31	train_loss: 6.6033
# Iteration: 16 of 31	train_loss: 6.6076
# Iteration: 18 of 31	train_loss: 6.5130
# Iteration: 20 of 31	train_loss: 6.6022
# Iteration: 22 of 31	train_loss: 6.5715
# Iteration: 24 of 31	train_loss: 6.4258
# Iteration: 26 of 31	train_loss: 6.6598
# Iteration: 28 of 31	train_loss: 6.2955
# Iteration: 30 of 31	train_loss: 6.5044
# Iteration: 31 of 31	train_loss: 6.2167
# Average Score for this Epoch: 6.471875190734863
# --- new best score ---
#
#
# -------------------- Epoch 2 of 250 --------------------
# Iteration: 0 of 31	train_loss: 6.1771
# Iteration: 2 of 31	train_loss: 6.1848
# Iteration: 4 of 31	train_loss: 6.2598
# Iteration: 6 of 31	train_loss: 6.1710
# Iteration: 8 of 31	train_loss: 6.6020
# Iteration: 10 of 31	train_loss: 6.2845
# Iteration: 12 of 31	train_loss: 6.3691
# Iteration: 14 of 31	train_loss: 6.3239
# Iteration: 16 of 31	train_loss: 6.3705
# Iteration: 18 of 31	train_loss: 6.3885
# Iteration: 20 of 31	train_loss: 6.4418
# Iteration: 22 of 31	train_loss: 6.3976
# Iteration: 24 of 31	train_loss: 6.4528
# Iteration: 26 of 31	train_loss: 6.4338
# Iteration: 28 of 31	train_loss: 6.4077
# Iteration: 30 of 31	train_loss: 6.4261
# Iteration: 31 of 31	train_loss: 6.4591
# Average Score for this Epoch: 6.371787071228027
# --- new best score ---
#
#
# -------------------- Epoch 3 of 250 --------------------
# Iteration: 0 of 31	train_loss: 6.0583
# Iteration: 2 of 31	train_loss: 6.1671
# Iteration: 4 of 31	train_loss: 6.0341
# Iteration: 6 of 31	train_loss: 6.2368
# Iteration: 8 of 31	train_loss: 6.1914
# Iteration: 10 of 31	train_loss: 6.2224
# Iteration: 12 of 31	train_loss: 6.2360
# Iteration: 14 of 31	train_loss: 6.3129
# Iteration: 16 of 31	train_loss: 6.2231
# Iteration: 18 of 31	train_loss: 6.2942
# Iteration: 20 of 31	train_loss: 6.3328
# Iteration: 22 of 31	train_loss: 6.2561
# Iteration: 24 of 31	train_loss: 6.4587
# Iteration: 26 of 31	train_loss: 6.5088
# Iteration: 28 of 31	train_loss: 6.0048
# Iteration: 30 of 31	train_loss: 6.5563
# Iteration: 31 of 31	train_loss: 6.3992
# Average Score for this Epoch: 6.237303733825684
# --- new best score ---
#
#
# -------------------- Epoch 4 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.7799
# Iteration: 2 of 31	train_loss: 6.1459
# Iteration: 4 of 31	train_loss: 6.1498
# Iteration: 6 of 31	train_loss: 6.1820
# Iteration: 8 of 31	train_loss: 6.1387
# Iteration: 10 of 31	train_loss: 6.2242
# Iteration: 12 of 31	train_loss: 6.2108
# Iteration: 14 of 31	train_loss: 6.1549
# Iteration: 16 of 31	train_loss: 6.2148
# Iteration: 18 of 31	train_loss: 5.8870
# Iteration: 20 of 31	train_loss: 6.2416
# Iteration: 22 of 31	train_loss: 6.2619
# Iteration: 24 of 31	train_loss: 6.0187
# Iteration: 26 of 31	train_loss: 6.1486
# Iteration: 28 of 31	train_loss: 6.2554
# Iteration: 30 of 31	train_loss: 6.1763
# Iteration: 31 of 31	train_loss: 6.1780
# Average Score for this Epoch: 6.124814033508301
# --- new best score ---
#
#
# -------------------- Epoch 5 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.8340
# Iteration: 2 of 31	train_loss: 5.8905
# Iteration: 4 of 31	train_loss: 5.9341
# Iteration: 6 of 31	train_loss: 5.9587
# Iteration: 8 of 31	train_loss: 5.9880
# Iteration: 10 of 31	train_loss: 6.0007
# Iteration: 12 of 31	train_loss: 5.7358
# Iteration: 14 of 31	train_loss: 5.9490
# Iteration: 16 of 31	train_loss: 6.1034
# Iteration: 18 of 31	train_loss: 6.0442
# Iteration: 20 of 31	train_loss: 5.8447
# Iteration: 22 of 31	train_loss: 6.1102
# Iteration: 24 of 31	train_loss: 6.1557
# Iteration: 26 of 31	train_loss: 6.2447
# Iteration: 28 of 31	train_loss: 6.2651
# Iteration: 30 of 31	train_loss: 6.1753
# Iteration: 31 of 31	train_loss: 5.9876
# Average Score for this Epoch: 6.002371311187744
# --- new best score ---
#
#
# -------------------- Epoch 6 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.8881
# Iteration: 2 of 31	train_loss: 5.7750
# Iteration: 4 of 31	train_loss: 5.6430
# Iteration: 6 of 31	train_loss: 5.6737
# Iteration: 8 of 31	train_loss: 5.8945
# Iteration: 10 of 31	train_loss: 5.8454
# Iteration: 12 of 31	train_loss: 5.8339
# Iteration: 14 of 31	train_loss: 5.8946
# Iteration: 16 of 31	train_loss: 5.9878
# Iteration: 18 of 31	train_loss: 5.9894
# Iteration: 20 of 31	train_loss: 6.0928
# Iteration: 22 of 31	train_loss: 5.9663
# Iteration: 24 of 31	train_loss: 5.8399
# Iteration: 26 of 31	train_loss: 5.9558
# Iteration: 28 of 31	train_loss: 5.8084
# Iteration: 30 of 31	train_loss: 5.9056
# Iteration: 31 of 31	train_loss: 5.9432
# Average Score for this Epoch: 5.900243759155273
# --- new best score ---
#
#
# -------------------- Epoch 7 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.4658
# Iteration: 2 of 31	train_loss: 5.8455
# Iteration: 4 of 31	train_loss: 5.6955
# Iteration: 6 of 31	train_loss: 5.7803
# Iteration: 8 of 31	train_loss: 5.8051
# Iteration: 10 of 31	train_loss: 5.7219
# Iteration: 12 of 31	train_loss: 6.0272
# Iteration: 14 of 31	train_loss: 5.8561
# Iteration: 16 of 31	train_loss: 5.9408
# Iteration: 18 of 31	train_loss: 5.7624
# Iteration: 20 of 31	train_loss: 6.0337
# Iteration: 22 of 31	train_loss: 6.1276
# Iteration: 24 of 31	train_loss: 5.9860
# Iteration: 26 of 31	train_loss: 5.9008
# Iteration: 28 of 31	train_loss: 5.8000
# Iteration: 30 of 31	train_loss: 5.5604
# Iteration: 31 of 31	train_loss: 5.5847
# Average Score for this Epoch: 5.818266868591309
# --- new best score ---
#
#
# -------------------- Epoch 8 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.6353
# Iteration: 2 of 31	train_loss: 5.5086
# Iteration: 4 of 31	train_loss: 5.6072
# Iteration: 6 of 31	train_loss: 5.6228
# Iteration: 8 of 31	train_loss: 5.5265
# Iteration: 10 of 31	train_loss: 5.6853
# Iteration: 12 of 31	train_loss: 5.8621
# Iteration: 14 of 31	train_loss: 5.8603
# Iteration: 16 of 31	train_loss: 5.7057
# Iteration: 18 of 31	train_loss: 5.5943
# Iteration: 20 of 31	train_loss: 5.8328
# Iteration: 22 of 31	train_loss: 5.9037
# Iteration: 24 of 31	train_loss: 5.8491
# Iteration: 26 of 31	train_loss: 5.9907
# Iteration: 28 of 31	train_loss: 6.1083
# Iteration: 30 of 31	train_loss: 5.9827
# Iteration: 31 of 31	train_loss: 5.5343
# Average Score for this Epoch: 5.759139060974121
# --- new best score ---
#
#
# -------------------- Epoch 9 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.4392
# Iteration: 2 of 31	train_loss: 5.5195
# Iteration: 4 of 31	train_loss: 5.4284
# Iteration: 6 of 31	train_loss: 5.5627
# Iteration: 8 of 31	train_loss: 5.6148
# Iteration: 10 of 31	train_loss: 5.9119
# Iteration: 12 of 31	train_loss: 5.7496
# Iteration: 14 of 31	train_loss: 5.7901
# Iteration: 16 of 31	train_loss: 5.9483
# Iteration: 18 of 31	train_loss: 5.4560
# Iteration: 20 of 31	train_loss: 5.8624
# Iteration: 22 of 31	train_loss: 5.7686
# Iteration: 24 of 31	train_loss: 6.0556
# Iteration: 26 of 31	train_loss: 5.7577
# Iteration: 28 of 31	train_loss: 5.6522
# Iteration: 30 of 31	train_loss: 5.9358
# Iteration: 31 of 31	train_loss: 5.5219
# Average Score for this Epoch: 5.701986312866211
# --- new best score ---
#
#
# -------------------- Epoch 10 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.2628
# Iteration: 2 of 31	train_loss: 5.6176
# Iteration: 4 of 31	train_loss: 5.6134
# Iteration: 6 of 31	train_loss: 5.6213
# Iteration: 8 of 31	train_loss: 5.4878
# Iteration: 10 of 31	train_loss: 5.5772
# Iteration: 12 of 31	train_loss: 5.6764
# Iteration: 14 of 31	train_loss: 5.5060
# Iteration: 16 of 31	train_loss: 5.7097
# Iteration: 18 of 31	train_loss: 5.4537
# Iteration: 20 of 31	train_loss: 5.7548
# Iteration: 22 of 31	train_loss: 5.8826
# Iteration: 24 of 31	train_loss: 5.8214
# Iteration: 26 of 31	train_loss: 5.8948
# Iteration: 28 of 31	train_loss: 5.7231
# Iteration: 30 of 31	train_loss: 5.8649
# Iteration: 31 of 31	train_loss: 5.2329
# Average Score for this Epoch: 5.643461227416992
# --- new best score ---
#
#
# -------------------- Epoch 11 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.5761
# Iteration: 2 of 31	train_loss: 5.6953
# Iteration: 4 of 31	train_loss: 5.5541
# Iteration: 6 of 31	train_loss: 5.5101
# Iteration: 8 of 31	train_loss: 5.6018
# Iteration: 10 of 31	train_loss: 5.6753
# Iteration: 12 of 31	train_loss: 5.6292
# Iteration: 14 of 31	train_loss: 5.3640
# Iteration: 16 of 31	train_loss: 5.6035
# Iteration: 18 of 31	train_loss: 5.5061
# Iteration: 20 of 31	train_loss: 5.6517
# Iteration: 22 of 31	train_loss: 5.7945
# Iteration: 24 of 31	train_loss: 5.6970
# Iteration: 26 of 31	train_loss: 5.6391
# Iteration: 28 of 31	train_loss: 5.8263
# Iteration: 30 of 31	train_loss: 5.9408
# Iteration: 31 of 31	train_loss: 5.6467
# Average Score for this Epoch: 5.61332893371582
# --- new best score ---
#
#
# -------------------- Epoch 12 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.5173
# Iteration: 2 of 31	train_loss: 5.4995
# Iteration: 4 of 31	train_loss: 5.6880
# Iteration: 6 of 31	train_loss: 5.4790
# Iteration: 8 of 31	train_loss: 5.4006
# Iteration: 10 of 31	train_loss: 5.6218
# Iteration: 12 of 31	train_loss: 5.6218
# Iteration: 14 of 31	train_loss: 5.5808
# Iteration: 16 of 31	train_loss: 5.6688
# Iteration: 18 of 31	train_loss: 5.4412
# Iteration: 20 of 31	train_loss: 5.3833
# Iteration: 22 of 31	train_loss: 5.6706
# Iteration: 24 of 31	train_loss: 5.7451
# Iteration: 26 of 31	train_loss: 5.7301
# Iteration: 28 of 31	train_loss: 5.6611
# Iteration: 30 of 31	train_loss: 5.7483
# Iteration: 31 of 31	train_loss: 5.5160
# Average Score for this Epoch: 5.572394371032715
# --- new best score ---
#
#
# -------------------- Epoch 13 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.4084
# Iteration: 2 of 31	train_loss: 5.3509
# Iteration: 4 of 31	train_loss: 5.4675
# Iteration: 6 of 31	train_loss: 5.3585
# Iteration: 8 of 31	train_loss: 5.6014
# Iteration: 10 of 31	train_loss: 5.6563
# Iteration: 12 of 31	train_loss: 5.6273
# Iteration: 14 of 31	train_loss: 5.3082
# Iteration: 16 of 31	train_loss: 5.5542
# Iteration: 18 of 31	train_loss: 5.5742
# Iteration: 20 of 31	train_loss: 5.2953
# Iteration: 22 of 31	train_loss: 5.6593
# Iteration: 24 of 31	train_loss: 5.5601
# Iteration: 26 of 31	train_loss: 5.3274
# Iteration: 28 of 31	train_loss: 5.8405
# Iteration: 30 of 31	train_loss: 5.6771
# Iteration: 31 of 31	train_loss: 5.4867
# Average Score for this Epoch: 5.522590637207031
# --- new best score ---
#
#
# -------------------- Epoch 14 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.3030
# Iteration: 2 of 31	train_loss: 5.6446
# Iteration: 4 of 31	train_loss: 5.4936
# Iteration: 6 of 31	train_loss: 5.3987
# Iteration: 8 of 31	train_loss: 5.5475
# Iteration: 10 of 31	train_loss: 5.4489
# Iteration: 12 of 31	train_loss: 5.7326
# Iteration: 14 of 31	train_loss: 5.5814
# Iteration: 16 of 31	train_loss: 5.8188
# Iteration: 18 of 31	train_loss: 5.3968
# Iteration: 20 of 31	train_loss: 5.1787
# Iteration: 22 of 31	train_loss: 5.2292
# Iteration: 24 of 31	train_loss: 5.4097
# Iteration: 26 of 31	train_loss: 5.7269
# Iteration: 28 of 31	train_loss: 5.5548
# Iteration: 30 of 31	train_loss: 5.7070
# Iteration: 31 of 31	train_loss: 5.3326
# Average Score for this Epoch: 5.4683356285095215
# --- new best score ---
#
#
# -------------------- Epoch 15 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.4338
# Iteration: 2 of 31	train_loss: 5.3288
# Iteration: 4 of 31	train_loss: 5.3420
# Iteration: 6 of 31	train_loss: 5.3239
# Iteration: 8 of 31	train_loss: 5.2785
# Iteration: 10 of 31	train_loss: 5.5359
# Iteration: 12 of 31	train_loss: 5.4949
# Iteration: 14 of 31	train_loss: 5.3560
# Iteration: 16 of 31	train_loss: 5.5958
# Iteration: 18 of 31	train_loss: 5.6019
# Iteration: 20 of 31	train_loss: 5.3599
# Iteration: 22 of 31	train_loss: 5.0509
# Iteration: 24 of 31	train_loss: 5.1173
# Iteration: 26 of 31	train_loss: 5.4343
# Iteration: 28 of 31	train_loss: 5.5234
# Iteration: 30 of 31	train_loss: 5.5371
# Iteration: 31 of 31	train_loss: 5.4615
# Average Score for this Epoch: 5.429488658905029
# --- new best score ---
#
#
# -------------------- Epoch 16 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.1919
# Iteration: 2 of 31	train_loss: 5.3522
# Iteration: 4 of 31	train_loss: 5.1838
# Iteration: 6 of 31	train_loss: 5.3557
# Iteration: 8 of 31	train_loss: 5.2852
# Iteration: 10 of 31	train_loss: 5.1145
# Iteration: 12 of 31	train_loss: 5.5214
# Iteration: 14 of 31	train_loss: 5.1528
# Iteration: 16 of 31	train_loss: 5.3847
# Iteration: 18 of 31	train_loss: 5.2987
# Iteration: 20 of 31	train_loss: 5.6050
# Iteration: 22 of 31	train_loss: 5.3653
# Iteration: 24 of 31	train_loss: 5.4804
# Iteration: 26 of 31	train_loss: 5.3943
# Iteration: 28 of 31	train_loss: 5.5515
# Iteration: 30 of 31	train_loss: 5.4446
# Iteration: 31 of 31	train_loss: 5.2881
# Average Score for this Epoch: 5.3856353759765625
# --- new best score ---
#
#
# -------------------- Epoch 17 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.2067
# Iteration: 2 of 31	train_loss: 5.2025
# Iteration: 4 of 31	train_loss: 5.2892
# Iteration: 6 of 31	train_loss: 5.2789
# Iteration: 8 of 31	train_loss: 5.6161
# Iteration: 10 of 31	train_loss: 5.2557
# Iteration: 12 of 31	train_loss: 5.2128
# Iteration: 14 of 31	train_loss: 5.1739
# Iteration: 16 of 31	train_loss: 5.0100
# Iteration: 18 of 31	train_loss: 5.4073
# Iteration: 20 of 31	train_loss: 5.5723
# Iteration: 22 of 31	train_loss: 5.4103
# Iteration: 24 of 31	train_loss: 5.1821
# Iteration: 26 of 31	train_loss: 5.7135
# Iteration: 28 of 31	train_loss: 5.4353
# Iteration: 30 of 31	train_loss: 5.2927
# Iteration: 31 of 31	train_loss: 5.2502
# Average Score for this Epoch: 5.330804824829102
# --- new best score ---
#
#
# -------------------- Epoch 18 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.9200
# Iteration: 2 of 31	train_loss: 5.3333
# Iteration: 4 of 31	train_loss: 5.1435
# Iteration: 6 of 31	train_loss: 5.1457
# Iteration: 8 of 31	train_loss: 5.2991
# Iteration: 10 of 31	train_loss: 5.2648
# Iteration: 12 of 31	train_loss: 5.3982
# Iteration: 14 of 31	train_loss: 5.3610
# Iteration: 16 of 31	train_loss: 5.4843
# Iteration: 18 of 31	train_loss: 5.1919
# Iteration: 20 of 31	train_loss: 5.3650
# Iteration: 22 of 31	train_loss: 5.2214
# Iteration: 24 of 31	train_loss: 5.4227
# Iteration: 26 of 31	train_loss: 5.5349
# Iteration: 28 of 31	train_loss: 5.5520
# Iteration: 30 of 31	train_loss: 5.4980
# Iteration: 31 of 31	train_loss: 4.8598
# Average Score for this Epoch: 5.28370475769043
# --- new best score ---
#
#
# -------------------- Epoch 19 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.1689
# Iteration: 2 of 31	train_loss: 5.0238
# Iteration: 4 of 31	train_loss: 5.4180
# Iteration: 6 of 31	train_loss: 4.7793
# Iteration: 8 of 31	train_loss: 5.2546
# Iteration: 10 of 31	train_loss: 5.0754
# Iteration: 12 of 31	train_loss: 5.1107
# Iteration: 14 of 31	train_loss: 5.4223
# Iteration: 16 of 31	train_loss: 5.1739
# Iteration: 18 of 31	train_loss: 5.3297
# Iteration: 20 of 31	train_loss: 5.2344
# Iteration: 22 of 31	train_loss: 5.2202
# Iteration: 24 of 31	train_loss: 5.3456
# Iteration: 26 of 31	train_loss: 5.2147
# Iteration: 28 of 31	train_loss: 5.5405
# Iteration: 30 of 31	train_loss: 5.2097
# Iteration: 31 of 31	train_loss: 4.9174
# Average Score for this Epoch: 5.241091251373291
# --- new best score ---
#
#
# -------------------- Epoch 20 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.0630
# Iteration: 2 of 31	train_loss: 5.1414
# Iteration: 4 of 31	train_loss: 5.2822
# Iteration: 6 of 31	train_loss: 5.0294
# Iteration: 8 of 31	train_loss: 4.9730
# Iteration: 10 of 31	train_loss: 5.1113
# Iteration: 12 of 31	train_loss: 5.2323
# Iteration: 14 of 31	train_loss: 5.0305
# Iteration: 16 of 31	train_loss: 5.2197
# Iteration: 18 of 31	train_loss: 5.0944
# Iteration: 20 of 31	train_loss: 5.2561
# Iteration: 22 of 31	train_loss: 5.3324
# Iteration: 24 of 31	train_loss: 5.4251
# Iteration: 26 of 31	train_loss: 5.1377
# Iteration: 28 of 31	train_loss: 4.9586
# Iteration: 30 of 31	train_loss: 5.4682
# Iteration: 31 of 31	train_loss: 5.1929
# Average Score for this Epoch: 5.208771705627441
# --- new best score ---
#
#
# -------------------- Epoch 21 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.0223
# Iteration: 2 of 31	train_loss: 4.8658
# Iteration: 4 of 31	train_loss: 5.0683
# Iteration: 6 of 31	train_loss: 4.9338
# Iteration: 8 of 31	train_loss: 5.0641
# Iteration: 10 of 31	train_loss: 5.2471
# Iteration: 12 of 31	train_loss: 5.1154
# Iteration: 14 of 31	train_loss: 5.2811
# Iteration: 16 of 31	train_loss: 5.1928
# Iteration: 18 of 31	train_loss: 5.3831
# Iteration: 20 of 31	train_loss: 5.1057
# Iteration: 22 of 31	train_loss: 5.3660
# Iteration: 24 of 31	train_loss: 5.3224
# Iteration: 26 of 31	train_loss: 5.2649
# Iteration: 28 of 31	train_loss: 5.1439
# Iteration: 30 of 31	train_loss: 5.2884
# Iteration: 31 of 31	train_loss: 5.0573
# Average Score for this Epoch: 5.16768741607666
# --- new best score ---
#
#
# -------------------- Epoch 22 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.0951
# Iteration: 2 of 31	train_loss: 4.8371
# Iteration: 4 of 31	train_loss: 4.8930
# Iteration: 6 of 31	train_loss: 5.1253
# Iteration: 8 of 31	train_loss: 5.2294
# Iteration: 10 of 31	train_loss: 5.0959
# Iteration: 12 of 31	train_loss: 5.3474
# Iteration: 14 of 31	train_loss: 5.1938
# Iteration: 16 of 31	train_loss: 5.0450
# Iteration: 18 of 31	train_loss: 5.1600
# Iteration: 20 of 31	train_loss: 5.2476
# Iteration: 22 of 31	train_loss: 5.1113
# Iteration: 24 of 31	train_loss: 5.1927
# Iteration: 26 of 31	train_loss: 4.9748
# Iteration: 28 of 31	train_loss: 5.3941
# Iteration: 30 of 31	train_loss: 5.3578
# Iteration: 31 of 31	train_loss: 5.0595
# Average Score for this Epoch: 5.123143672943115
# --- new best score ---
#
#
# -------------------- Epoch 23 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.1185
# Iteration: 2 of 31	train_loss: 5.0144
# Iteration: 4 of 31	train_loss: 5.1111
# Iteration: 6 of 31	train_loss: 4.8105
# Iteration: 8 of 31	train_loss: 4.8970
# Iteration: 10 of 31	train_loss: 5.0900
# Iteration: 12 of 31	train_loss: 5.2590
# Iteration: 14 of 31	train_loss: 5.2208
# Iteration: 16 of 31	train_loss: 5.2923
# Iteration: 18 of 31	train_loss: 5.1825
# Iteration: 20 of 31	train_loss: 4.8899
# Iteration: 22 of 31	train_loss: 5.2848
# Iteration: 24 of 31	train_loss: 5.0928
# Iteration: 26 of 31	train_loss: 5.3111
# Iteration: 28 of 31	train_loss: 5.4187
# Iteration: 30 of 31	train_loss: 5.1702
# Iteration: 31 of 31	train_loss: 4.9515
# Average Score for this Epoch: 5.090999603271484
# --- new best score ---
#
#
# -------------------- Epoch 24 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6104
# Iteration: 2 of 31	train_loss: 4.8952
# Iteration: 4 of 31	train_loss: 4.9578
# Iteration: 6 of 31	train_loss: 5.2416
# Iteration: 8 of 31	train_loss: 4.7706
# Iteration: 10 of 31	train_loss: 5.1701
# Iteration: 12 of 31	train_loss: 4.7614
# Iteration: 14 of 31	train_loss: 5.1067
# Iteration: 16 of 31	train_loss: 5.0196
# Iteration: 18 of 31	train_loss: 4.8374
# Iteration: 20 of 31	train_loss: 5.1451
# Iteration: 22 of 31	train_loss: 5.1680
# Iteration: 24 of 31	train_loss: 5.0302
# Iteration: 26 of 31	train_loss: 5.1122
# Iteration: 28 of 31	train_loss: 4.9080
# Iteration: 30 of 31	train_loss: 5.2003
# Iteration: 31 of 31	train_loss: 4.8396
# Average Score for this Epoch: 5.03464412689209
# --- new best score ---
#
#
# -------------------- Epoch 25 of 250 --------------------
# Iteration: 0 of 31	train_loss: 5.0271
# Iteration: 2 of 31	train_loss: 4.8739
# Iteration: 4 of 31	train_loss: 5.0188
# Iteration: 6 of 31	train_loss: 5.1052
# Iteration: 8 of 31	train_loss: 4.7454
# Iteration: 10 of 31	train_loss: 4.7873
# Iteration: 12 of 31	train_loss: 4.7305
# Iteration: 14 of 31	train_loss: 5.1742
# Iteration: 16 of 31	train_loss: 5.0805
# Iteration: 18 of 31	train_loss: 4.8180
# Iteration: 20 of 31	train_loss: 4.8073
# Iteration: 22 of 31	train_loss: 5.2791
# Iteration: 24 of 31	train_loss: 5.1339
# Iteration: 26 of 31	train_loss: 5.1590
# Iteration: 28 of 31	train_loss: 5.0319
# Iteration: 30 of 31	train_loss: 5.3851
# Iteration: 31 of 31	train_loss: 4.9191
# Average Score for this Epoch: 5.007616996765137
# --- new best score ---
#
#
# -------------------- Epoch 26 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.9479
# Iteration: 2 of 31	train_loss: 4.8937
# Iteration: 4 of 31	train_loss: 4.7924
# Iteration: 6 of 31	train_loss: 4.9976
# Iteration: 8 of 31	train_loss: 5.2782
# Iteration: 10 of 31	train_loss: 5.0207
# Iteration: 12 of 31	train_loss: 4.9120
# Iteration: 14 of 31	train_loss: 4.7433
# Iteration: 16 of 31	train_loss: 4.8670
# Iteration: 18 of 31	train_loss: 5.2516
# Iteration: 20 of 31	train_loss: 4.7911
# Iteration: 22 of 31	train_loss: 4.9549
# Iteration: 24 of 31	train_loss: 5.1431
# Iteration: 26 of 31	train_loss: 4.9698
# Iteration: 28 of 31	train_loss: 5.1114
# Iteration: 30 of 31	train_loss: 4.9590
# Iteration: 31 of 31	train_loss: 4.8929
# Average Score for this Epoch: 4.964115142822266
# --- new best score ---
#
#
# -------------------- Epoch 27 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.8758
# Iteration: 2 of 31	train_loss: 4.8898
# Iteration: 4 of 31	train_loss: 4.7707
# Iteration: 6 of 31	train_loss: 4.9574
# Iteration: 8 of 31	train_loss: 5.0106
# Iteration: 10 of 31	train_loss: 4.9358
# Iteration: 12 of 31	train_loss: 4.5854
# Iteration: 14 of 31	train_loss: 5.0193
# Iteration: 16 of 31	train_loss: 5.0939
# Iteration: 18 of 31	train_loss: 5.1300
# Iteration: 20 of 31	train_loss: 4.9506
# Iteration: 22 of 31	train_loss: 5.1299
# Iteration: 24 of 31	train_loss: 5.0346
# Iteration: 26 of 31	train_loss: 5.0629
# Iteration: 28 of 31	train_loss: 4.9802
# Iteration: 30 of 31	train_loss: 4.9650
# Iteration: 31 of 31	train_loss: 4.8059
# Average Score for this Epoch: 4.938074111938477
# --- new best score ---
#
#
# -------------------- Epoch 28 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.7921
# Iteration: 2 of 31	train_loss: 4.9335
# Iteration: 4 of 31	train_loss: 4.6617
# Iteration: 6 of 31	train_loss: 5.0531
# Iteration: 8 of 31	train_loss: 4.6624
# Iteration: 10 of 31	train_loss: 4.8061
# Iteration: 12 of 31	train_loss: 4.7670
# Iteration: 14 of 31	train_loss: 4.9676
# Iteration: 16 of 31	train_loss: 4.7825
# Iteration: 18 of 31	train_loss: 5.1335
# Iteration: 20 of 31	train_loss: 5.0256
# Iteration: 22 of 31	train_loss: 4.9514
# Iteration: 24 of 31	train_loss: 4.9415
# Iteration: 26 of 31	train_loss: 5.1721
# Iteration: 28 of 31	train_loss: 4.8910
# Iteration: 30 of 31	train_loss: 4.8337
# Iteration: 31 of 31	train_loss: 4.7440
# Average Score for this Epoch: 4.899945259094238
# --- new best score ---
#
#
# -------------------- Epoch 29 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.8572
# Iteration: 2 of 31	train_loss: 4.7470
# Iteration: 4 of 31	train_loss: 4.9253
# Iteration: 6 of 31	train_loss: 4.9061
# Iteration: 8 of 31	train_loss: 4.9184
# Iteration: 10 of 31	train_loss: 4.9205
# Iteration: 12 of 31	train_loss: 4.8792
# Iteration: 14 of 31	train_loss: 5.0140
# Iteration: 16 of 31	train_loss: 4.7753
# Iteration: 18 of 31	train_loss: 4.6092
# Iteration: 20 of 31	train_loss: 4.7817
# Iteration: 22 of 31	train_loss: 4.7974
# Iteration: 24 of 31	train_loss: 4.9811
# Iteration: 26 of 31	train_loss: 5.0189
# Iteration: 28 of 31	train_loss: 4.7821
# Iteration: 30 of 31	train_loss: 4.8692
# Iteration: 31 of 31	train_loss: 4.8136
# Average Score for this Epoch: 4.8732590675354
# --- new best score ---
#
#
# -------------------- Epoch 30 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.8580
# Iteration: 2 of 31	train_loss: 4.9306
# Iteration: 4 of 31	train_loss: 5.1495
# Iteration: 6 of 31	train_loss: 4.6028
# Iteration: 8 of 31	train_loss: 4.5293
# Iteration: 10 of 31	train_loss: 4.5749
# Iteration: 12 of 31	train_loss: 4.8317
# Iteration: 14 of 31	train_loss: 4.7745
# Iteration: 16 of 31	train_loss: 4.7410
# Iteration: 18 of 31	train_loss: 4.9656
# Iteration: 20 of 31	train_loss: 4.9918
# Iteration: 22 of 31	train_loss: 4.8434
# Iteration: 24 of 31	train_loss: 4.8054
# Iteration: 26 of 31	train_loss: 4.9646
# Iteration: 28 of 31	train_loss: 4.9346
# Iteration: 30 of 31	train_loss: 5.0390
# Iteration: 31 of 31	train_loss: 4.8547
# Average Score for this Epoch: 4.841440677642822
# --- new best score ---
#
#
# -------------------- Epoch 31 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6472
# Iteration: 2 of 31	train_loss: 4.6611
# Iteration: 4 of 31	train_loss: 5.0350
# Iteration: 6 of 31	train_loss: 5.0047
# Iteration: 8 of 31	train_loss: 4.5586
# Iteration: 10 of 31	train_loss: 5.0508
# Iteration: 12 of 31	train_loss: 4.6792
# Iteration: 14 of 31	train_loss: 4.8491
# Iteration: 16 of 31	train_loss: 4.8368
# Iteration: 18 of 31	train_loss: 4.7176
# Iteration: 20 of 31	train_loss: 4.9002
# Iteration: 22 of 31	train_loss: 4.5661
# Iteration: 24 of 31	train_loss: 4.8995
# Iteration: 26 of 31	train_loss: 4.8174
# Iteration: 28 of 31	train_loss: 4.9116
# Iteration: 30 of 31	train_loss: 5.0317
# Iteration: 31 of 31	train_loss: 4.5396
# Average Score for this Epoch: 4.8057942390441895
# --- new best score ---
#
#
# -------------------- Epoch 32 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6588
# Iteration: 2 of 31	train_loss: 4.4430
# Iteration: 4 of 31	train_loss: 4.5155
# Iteration: 6 of 31	train_loss: 4.7217
# Iteration: 8 of 31	train_loss: 4.9798
# Iteration: 10 of 31	train_loss: 4.7165
# Iteration: 12 of 31	train_loss: 4.6753
# Iteration: 14 of 31	train_loss: 4.6695
# Iteration: 16 of 31	train_loss: 5.1771
# Iteration: 18 of 31	train_loss: 4.6437
# Iteration: 20 of 31	train_loss: 5.0496
# Iteration: 22 of 31	train_loss: 4.7358
# Iteration: 24 of 31	train_loss: 4.7117
# Iteration: 26 of 31	train_loss: 4.6582
# Iteration: 28 of 31	train_loss: 5.1139
# Iteration: 30 of 31	train_loss: 4.7442
# Iteration: 31 of 31	train_loss: 4.7118
# Average Score for this Epoch: 4.765460014343262
# --- new best score ---
#
#
# -------------------- Epoch 33 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6130
# Iteration: 2 of 31	train_loss: 4.7315
# Iteration: 4 of 31	train_loss: 4.4582
# Iteration: 6 of 31	train_loss: 4.4597
# Iteration: 8 of 31	train_loss: 4.9068
# Iteration: 10 of 31	train_loss: 4.7395
# Iteration: 12 of 31	train_loss: 4.4783
# Iteration: 14 of 31	train_loss: 4.6184
# Iteration: 16 of 31	train_loss: 4.8665
# Iteration: 18 of 31	train_loss: 4.8591
# Iteration: 20 of 31	train_loss: 4.8608
# Iteration: 22 of 31	train_loss: 4.7782
# Iteration: 24 of 31	train_loss: 4.9060
# Iteration: 26 of 31	train_loss: 4.7483
# Iteration: 28 of 31	train_loss: 4.6579
# Iteration: 30 of 31	train_loss: 4.6840
# Iteration: 31 of 31	train_loss: 4.6571
# Average Score for this Epoch: 4.7430009841918945
# --- new best score ---
#
#
# -------------------- Epoch 34 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.8048
# Iteration: 2 of 31	train_loss: 4.7509
# Iteration: 4 of 31	train_loss: 4.6375
# Iteration: 6 of 31	train_loss: 4.6400
# Iteration: 8 of 31	train_loss: 4.7785
# Iteration: 10 of 31	train_loss: 4.3636
# Iteration: 12 of 31	train_loss: 5.0408
# Iteration: 14 of 31	train_loss: 4.6001
# Iteration: 16 of 31	train_loss: 4.6768
# Iteration: 18 of 31	train_loss: 4.6680
# Iteration: 20 of 31	train_loss: 4.8483
# Iteration: 22 of 31	train_loss: 4.9564
# Iteration: 24 of 31	train_loss: 4.5516
# Iteration: 26 of 31	train_loss: 4.9302
# Iteration: 28 of 31	train_loss: 4.8341
# Iteration: 30 of 31	train_loss: 4.7542
# Iteration: 31 of 31	train_loss: 4.7254
# Average Score for this Epoch: 4.712015628814697
# --- new best score ---
#
#
# -------------------- Epoch 35 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2136
# Iteration: 2 of 31	train_loss: 4.6597
# Iteration: 4 of 31	train_loss: 4.6134
# Iteration: 6 of 31	train_loss: 4.6432
# Iteration: 8 of 31	train_loss: 4.3824
# Iteration: 10 of 31	train_loss: 4.5709
# Iteration: 12 of 31	train_loss: 4.8520
# Iteration: 14 of 31	train_loss: 4.8607
# Iteration: 16 of 31	train_loss: 4.8841
# Iteration: 18 of 31	train_loss: 4.7849
# Iteration: 20 of 31	train_loss: 4.9928
# Iteration: 22 of 31	train_loss: 4.8446
# Iteration: 24 of 31	train_loss: 4.7591
# Iteration: 26 of 31	train_loss: 4.8242
# Iteration: 28 of 31	train_loss: 4.7761
# Iteration: 30 of 31	train_loss: 4.8516
# Iteration: 31 of 31	train_loss: 4.2856
# Average Score for this Epoch: 4.673915863037109
# --- new best score ---
#
#
# -------------------- Epoch 36 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.7135
# Iteration: 2 of 31	train_loss: 4.8529
# Iteration: 4 of 31	train_loss: 4.7712
# Iteration: 6 of 31	train_loss: 4.5215
# Iteration: 8 of 31	train_loss: 4.6097
# Iteration: 10 of 31	train_loss: 4.6999
# Iteration: 12 of 31	train_loss: 4.6341
# Iteration: 14 of 31	train_loss: 4.6995
# Iteration: 16 of 31	train_loss: 4.4380
# Iteration: 18 of 31	train_loss: 4.8119
# Iteration: 20 of 31	train_loss: 4.6332
# Iteration: 22 of 31	train_loss: 4.4863
# Iteration: 24 of 31	train_loss: 4.5593
# Iteration: 26 of 31	train_loss: 4.8413
# Iteration: 28 of 31	train_loss: 4.8176
# Iteration: 30 of 31	train_loss: 4.7996
# Iteration: 31 of 31	train_loss: 4.6584
# Average Score for this Epoch: 4.659703731536865
# --- new best score ---
#
#
# -------------------- Epoch 37 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6766
# Iteration: 2 of 31	train_loss: 4.3324
# Iteration: 4 of 31	train_loss: 4.7043
# Iteration: 6 of 31	train_loss: 4.4748
# Iteration: 8 of 31	train_loss: 4.6988
# Iteration: 10 of 31	train_loss: 4.6845
# Iteration: 12 of 31	train_loss: 4.3676
# Iteration: 14 of 31	train_loss: 4.6311
# Iteration: 16 of 31	train_loss: 4.7240
# Iteration: 18 of 31	train_loss: 4.4199
# Iteration: 20 of 31	train_loss: 4.3416
# Iteration: 22 of 31	train_loss: 4.6913
# Iteration: 24 of 31	train_loss: 4.6121
# Iteration: 26 of 31	train_loss: 4.6129
# Iteration: 28 of 31	train_loss: 4.6471
# Iteration: 30 of 31	train_loss: 4.8942
# Iteration: 31 of 31	train_loss: 4.5026
# Average Score for this Epoch: 4.635412216186523
# --- new best score ---
#
#
# -------------------- Epoch 38 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.4684
# Iteration: 2 of 31	train_loss: 4.5153
# Iteration: 4 of 31	train_loss: 4.5669
# Iteration: 6 of 31	train_loss: 4.5070
# Iteration: 8 of 31	train_loss: 4.6289
# Iteration: 10 of 31	train_loss: 5.0236
# Iteration: 12 of 31	train_loss: 4.4597
# Iteration: 14 of 31	train_loss: 4.6657
# Iteration: 16 of 31	train_loss: 4.8226
# Iteration: 18 of 31	train_loss: 4.7710
# Iteration: 20 of 31	train_loss: 4.3405
# Iteration: 22 of 31	train_loss: 4.2803
# Iteration: 24 of 31	train_loss: 4.5922
# Iteration: 26 of 31	train_loss: 4.7974
# Iteration: 28 of 31	train_loss: 4.2308
# Iteration: 30 of 31	train_loss: 4.5362
# Iteration: 31 of 31	train_loss: 4.5087
# Average Score for this Epoch: 4.60654878616333
# --- new best score ---
#
#
# -------------------- Epoch 39 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.3661
# Iteration: 2 of 31	train_loss: 4.6990
# Iteration: 4 of 31	train_loss: 4.5634
# Iteration: 6 of 31	train_loss: 4.5986
# Iteration: 8 of 31	train_loss: 4.6488
# Iteration: 10 of 31	train_loss: 4.3265
# Iteration: 12 of 31	train_loss: 4.6769
# Iteration: 14 of 31	train_loss: 4.5632
# Iteration: 16 of 31	train_loss: 4.7554
# Iteration: 18 of 31	train_loss: 4.5293
# Iteration: 20 of 31	train_loss: 4.5224
# Iteration: 22 of 31	train_loss: 4.5265
# Iteration: 24 of 31	train_loss: 4.5843
# Iteration: 26 of 31	train_loss: 4.3471
# Iteration: 28 of 31	train_loss: 4.2292
# Iteration: 30 of 31	train_loss: 4.5246
# Iteration: 31 of 31	train_loss: 4.2744
# Average Score for this Epoch: 4.569852828979492
# --- new best score ---
#
#
# -------------------- Epoch 40 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2018
# Iteration: 2 of 31	train_loss: 4.7405
# Iteration: 4 of 31	train_loss: 4.5312
# Iteration: 6 of 31	train_loss: 4.5457
# Iteration: 8 of 31	train_loss: 4.2907
# Iteration: 10 of 31	train_loss: 4.4912
# Iteration: 12 of 31	train_loss: 4.5917
# Iteration: 14 of 31	train_loss: 4.5812
# Iteration: 16 of 31	train_loss: 4.6096
# Iteration: 18 of 31	train_loss: 4.2547
# Iteration: 20 of 31	train_loss: 4.6907
# Iteration: 22 of 31	train_loss: 4.3306
# Iteration: 24 of 31	train_loss: 4.7094
# Iteration: 26 of 31	train_loss: 4.8548
# Iteration: 28 of 31	train_loss: 4.7570
# Iteration: 30 of 31	train_loss: 4.8311
# Iteration: 31 of 31	train_loss: 4.1215
# Average Score for this Epoch: 4.545139789581299
# --- new best score ---
#
#
# -------------------- Epoch 41 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2490
# Iteration: 2 of 31	train_loss: 4.6467
# Iteration: 4 of 31	train_loss: 4.2461
# Iteration: 6 of 31	train_loss: 4.4586
# Iteration: 8 of 31	train_loss: 4.5586
# Iteration: 10 of 31	train_loss: 4.2238
# Iteration: 12 of 31	train_loss: 4.6042
# Iteration: 14 of 31	train_loss: 4.5899
# Iteration: 16 of 31	train_loss: 4.3298
# Iteration: 18 of 31	train_loss: 4.0365
# Iteration: 20 of 31	train_loss: 4.6780
# Iteration: 22 of 31	train_loss: 4.7334
# Iteration: 24 of 31	train_loss: 4.7115
# Iteration: 26 of 31	train_loss: 4.5821
# Iteration: 28 of 31	train_loss: 4.6383
# Iteration: 30 of 31	train_loss: 4.7693
# Iteration: 31 of 31	train_loss: 4.0907
# Average Score for this Epoch: 4.525165557861328
# --- new best score ---
#
#
# -------------------- Epoch 42 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6659
# Iteration: 2 of 31	train_loss: 4.6500
# Iteration: 4 of 31	train_loss: 4.4950
# Iteration: 6 of 31	train_loss: 4.1392
# Iteration: 8 of 31	train_loss: 4.3399
# Iteration: 10 of 31	train_loss: 4.6844
# Iteration: 12 of 31	train_loss: 4.5891
# Iteration: 14 of 31	train_loss: 4.5448
# Iteration: 16 of 31	train_loss: 4.5886
# Iteration: 18 of 31	train_loss: 4.2720
# Iteration: 20 of 31	train_loss: 4.6653
# Iteration: 22 of 31	train_loss: 4.2509
# Iteration: 24 of 31	train_loss: 4.5088
# Iteration: 26 of 31	train_loss: 4.2927
# Iteration: 28 of 31	train_loss: 4.5892
# Iteration: 30 of 31	train_loss: 4.4242
# Iteration: 31 of 31	train_loss: 4.6691
# Average Score for this Epoch: 4.513241291046143
# --- new best score ---
#
#
# -------------------- Epoch 43 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6192
# Iteration: 2 of 31	train_loss: 4.1452
# Iteration: 4 of 31	train_loss: 4.4952
# Iteration: 6 of 31	train_loss: 4.2356
# Iteration: 8 of 31	train_loss: 4.5560
# Iteration: 10 of 31	train_loss: 4.4786
# Iteration: 12 of 31	train_loss: 4.4663
# Iteration: 14 of 31	train_loss: 4.6293
# Iteration: 16 of 31	train_loss: 4.4273
# Iteration: 18 of 31	train_loss: 4.6944
# Iteration: 20 of 31	train_loss: 4.5348
# Iteration: 22 of 31	train_loss: 4.6422
# Iteration: 24 of 31	train_loss: 4.7539
# Iteration: 26 of 31	train_loss: 4.7604
# Iteration: 28 of 31	train_loss: 4.5173
# Iteration: 30 of 31	train_loss: 4.4553
# Iteration: 31 of 31	train_loss: 4.7249
# Average Score for this Epoch: 4.497463703155518
# --- new best score ---
#
#
# -------------------- Epoch 44 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2254
# Iteration: 2 of 31	train_loss: 4.0227
# Iteration: 4 of 31	train_loss: 4.7196
# Iteration: 6 of 31	train_loss: 4.6849
# Iteration: 8 of 31	train_loss: 4.1808
# Iteration: 10 of 31	train_loss: 4.1594
# Iteration: 12 of 31	train_loss: 4.8001
# Iteration: 14 of 31	train_loss: 4.2663
# Iteration: 16 of 31	train_loss: 4.5385
# Iteration: 18 of 31	train_loss: 4.5770
# Iteration: 20 of 31	train_loss: 4.6617
# Iteration: 22 of 31	train_loss: 4.7001
# Iteration: 24 of 31	train_loss: 4.6627
# Iteration: 26 of 31	train_loss: 4.7910
# Iteration: 28 of 31	train_loss: 4.0528
# Iteration: 30 of 31	train_loss: 4.4475
# Iteration: 31 of 31	train_loss: 4.2714
# Average Score for this Epoch: 4.463850021362305
# --- new best score ---
#
#
# -------------------- Epoch 45 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2489
# Iteration: 2 of 31	train_loss: 4.4303
# Iteration: 4 of 31	train_loss: 4.5685
# Iteration: 6 of 31	train_loss: 4.2428
# Iteration: 8 of 31	train_loss: 4.5090
# Iteration: 10 of 31	train_loss: 4.6235
# Iteration: 12 of 31	train_loss: 4.3332
# Iteration: 14 of 31	train_loss: 4.0416
# Iteration: 16 of 31	train_loss: 4.4269
# Iteration: 18 of 31	train_loss: 4.3857
# Iteration: 20 of 31	train_loss: 4.5171
# Iteration: 22 of 31	train_loss: 4.5072
# Iteration: 24 of 31	train_loss: 4.6053
# Iteration: 26 of 31	train_loss: 4.2547
# Iteration: 28 of 31	train_loss: 4.2109
# Iteration: 30 of 31	train_loss: 4.5353
# Iteration: 31 of 31	train_loss: 4.1911
# Average Score for this Epoch: 4.448870658874512
# --- new best score ---
#
#
# -------------------- Epoch 46 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.6777
# Iteration: 2 of 31	train_loss: 4.1848
# Iteration: 4 of 31	train_loss: 4.1535
# Iteration: 6 of 31	train_loss: 4.2712
# Iteration: 8 of 31	train_loss: 4.3670
# Iteration: 10 of 31	train_loss: 4.4355
# Iteration: 12 of 31	train_loss: 4.3684
# Iteration: 14 of 31	train_loss: 4.2418
# Iteration: 16 of 31	train_loss: 4.5256
# Iteration: 18 of 31	train_loss: 4.6429
# Iteration: 20 of 31	train_loss: 4.2942
# Iteration: 22 of 31	train_loss: 4.3096
# Iteration: 24 of 31	train_loss: 4.4877
# Iteration: 26 of 31	train_loss: 4.4491
# Iteration: 28 of 31	train_loss: 4.6037
# Iteration: 30 of 31	train_loss: 4.4276
# Iteration: 31 of 31	train_loss: 4.7033
# Average Score for this Epoch: 4.442682266235352
# --- new best score ---
#
#
# -------------------- Epoch 47 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2515
# Iteration: 2 of 31	train_loss: 4.2571
# Iteration: 4 of 31	train_loss: 4.3014
# Iteration: 6 of 31	train_loss: 4.3974
# Iteration: 8 of 31	train_loss: 4.4332
# Iteration: 10 of 31	train_loss: 4.6201
# Iteration: 12 of 31	train_loss: 4.4829
# Iteration: 14 of 31	train_loss: 4.4455
# Iteration: 16 of 31	train_loss: 4.5515
# Iteration: 18 of 31	train_loss: 4.0000
# Iteration: 20 of 31	train_loss: 4.5208
# Iteration: 22 of 31	train_loss: 4.7336
# Iteration: 24 of 31	train_loss: 4.3104
# Iteration: 26 of 31	train_loss: 3.8380
# Iteration: 28 of 31	train_loss: 4.2618
# Iteration: 30 of 31	train_loss: 4.8302
# Iteration: 31 of 31	train_loss: 4.1374
# Average Score for this Epoch: 4.397872447967529
# --- new best score ---
#
#
# -------------------- Epoch 48 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.3066
# Iteration: 2 of 31	train_loss: 4.5282
# Iteration: 4 of 31	train_loss: 4.0810
# Iteration: 6 of 31	train_loss: 4.6810
# Iteration: 8 of 31	train_loss: 4.1461
# Iteration: 10 of 31	train_loss: 4.2903
# Iteration: 12 of 31	train_loss: 4.4564
# Iteration: 14 of 31	train_loss: 4.4795
# Iteration: 16 of 31	train_loss: 4.2493
# Iteration: 18 of 31	train_loss: 4.5271
# Iteration: 20 of 31	train_loss: 4.4615
# Iteration: 22 of 31	train_loss: 3.9348
# Iteration: 24 of 31	train_loss: 4.7410
# Iteration: 26 of 31	train_loss: 4.6844
# Iteration: 28 of 31	train_loss: 4.3752
# Iteration: 30 of 31	train_loss: 4.7191
# Iteration: 31 of 31	train_loss: 4.2255
# Average Score for this Epoch: 4.3755879402160645
# --- new best score ---
#
#
# -------------------- Epoch 49 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.3773
# Iteration: 2 of 31	train_loss: 4.4623
# Iteration: 4 of 31	train_loss: 4.3776
# Iteration: 6 of 31	train_loss: 4.5161
# Iteration: 8 of 31	train_loss: 4.3613
# Iteration: 10 of 31	train_loss: 4.3825
# Iteration: 12 of 31	train_loss: 4.3119
# Iteration: 14 of 31	train_loss: 4.5413
# Iteration: 16 of 31	train_loss: 4.3134
# Iteration: 18 of 31	train_loss: 4.4603
# Iteration: 20 of 31	train_loss: 4.3006
# Iteration: 22 of 31	train_loss: 4.4825
# Iteration: 24 of 31	train_loss: 4.3493
# Iteration: 26 of 31	train_loss: 4.5456
# Iteration: 28 of 31	train_loss: 4.6673
# Iteration: 30 of 31	train_loss: 4.6436
# Iteration: 31 of 31	train_loss: 4.4943
# Average Score for this Epoch: 4.377231121063232
# -------------------- Epoch 50 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.3277
# Iteration: 2 of 31	train_loss: 3.9797
# Iteration: 4 of 31	train_loss: 4.4339
# Iteration: 6 of 31	train_loss: 4.2392
# Iteration: 8 of 31	train_loss: 4.0656
# Iteration: 10 of 31	train_loss: 4.1884
# Iteration: 12 of 31	train_loss: 4.3249
# Iteration: 14 of 31	train_loss: 4.2844
# Iteration: 16 of 31	train_loss: 4.4623
# Iteration: 18 of 31	train_loss: 4.4383
# Iteration: 20 of 31	train_loss: 4.6590
# Iteration: 22 of 31	train_loss: 4.4414
# Iteration: 24 of 31	train_loss: 4.7491
# Iteration: 26 of 31	train_loss: 4.4655
# Iteration: 28 of 31	train_loss: 4.2836
# Iteration: 30 of 31	train_loss: 4.5488
# Iteration: 31 of 31	train_loss: 4.4020
# Average Score for this Epoch: 4.351719856262207
# --- new best score ---
#
#
# -------------------- Epoch 51 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.4306
# Iteration: 2 of 31	train_loss: 4.1797
# Iteration: 4 of 31	train_loss: 4.2577
# Iteration: 6 of 31	train_loss: 4.3289
# Iteration: 8 of 31	train_loss: 4.5023
# Iteration: 10 of 31	train_loss: 4.2713
# Iteration: 12 of 31	train_loss: 4.3009
# Iteration: 14 of 31	train_loss: 4.4996
# Iteration: 16 of 31	train_loss: 4.0054
# Iteration: 18 of 31	train_loss: 4.3405
# Iteration: 20 of 31	train_loss: 4.3645
# Iteration: 22 of 31	train_loss: 4.2426
# Iteration: 24 of 31	train_loss: 4.3514
# Iteration: 26 of 31	train_loss: 4.4519
# Iteration: 28 of 31	train_loss: 4.3384
# Iteration: 30 of 31	train_loss: 4.8009
# Iteration: 31 of 31	train_loss: 4.4609
# Average Score for this Epoch: 4.3340535163879395
# --- new best score ---
#
#
# -------------------- Epoch 52 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.3467
# Iteration: 2 of 31	train_loss: 4.2363
# Iteration: 4 of 31	train_loss: 4.3653
# Iteration: 6 of 31	train_loss: 4.0694
# Iteration: 8 of 31	train_loss: 4.5197
# Iteration: 10 of 31	train_loss: 4.7302
# Iteration: 12 of 31	train_loss: 4.5307
# Iteration: 14 of 31	train_loss: 4.0377
# Iteration: 16 of 31	train_loss: 4.5384
# Iteration: 18 of 31	train_loss: 4.2180
# Iteration: 20 of 31	train_loss: 4.4332
# Iteration: 22 of 31	train_loss: 4.6884
# Iteration: 24 of 31	train_loss: 4.3582
# Iteration: 26 of 31	train_loss: 4.1125
# Iteration: 28 of 31	train_loss: 4.2996
# Iteration: 30 of 31	train_loss: 4.4675
# Iteration: 31 of 31	train_loss: 4.4505
# Average Score for this Epoch: 4.321864128112793
# --- new best score ---
#
#
# -------------------- Epoch 53 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.2414
# Iteration: 2 of 31	train_loss: 4.2820
# Iteration: 4 of 31	train_loss: 4.3824
# Iteration: 6 of 31	train_loss: 3.9189
# Iteration: 8 of 31	train_loss: 4.2893
# Iteration: 10 of 31	train_loss: 4.2508
# Iteration: 12 of 31	train_loss: 4.3047
# Iteration: 14 of 31	train_loss: 4.3654
# Iteration: 16 of 31	train_loss: 3.9717
# Iteration: 18 of 31	train_loss: 4.5290
# Iteration: 20 of 31	train_loss: 4.1304
# Iteration: 22 of 31	train_loss: 4.7954
# Iteration: 24 of 31	train_loss: 4.6145
# Iteration: 26 of 31	train_loss: 4.2104
# Iteration: 28 of 31	train_loss: 4.7922
# Iteration: 30 of 31	train_loss: 4.2212
# Iteration: 31 of 31	train_loss: 4.2864
# Average Score for this Epoch: 4.297072410583496
# --- new best score ---
#
#
# -------------------- Epoch 54 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.3277
# Iteration: 2 of 31	train_loss: 4.1309
# Iteration: 4 of 31	train_loss: 4.2380
# Iteration: 6 of 31	train_loss: 4.0340
# Iteration: 8 of 31	train_loss: 4.2259
# Iteration: 10 of 31	train_loss: 4.0216
# Iteration: 12 of 31	train_loss: 4.2116
# Iteration: 14 of 31	train_loss: 4.6482
# Iteration: 16 of 31	train_loss: 4.2969
# Iteration: 18 of 31	train_loss: 4.0610
# Iteration: 20 of 31	train_loss: 4.4845
# Iteration: 22 of 31	train_loss: 4.3604
# Iteration: 24 of 31	train_loss: 4.5834
# Iteration: 26 of 31	train_loss: 4.1498
# Iteration: 28 of 31	train_loss: 4.3129
# Iteration: 30 of 31	train_loss: 4.4995
# Iteration: 31 of 31	train_loss: 4.2549
# Average Score for this Epoch: 4.280073165893555
# --- new best score ---
#
#
# -------------------- Epoch 55 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.4796
# Iteration: 2 of 31	train_loss: 4.1469
# Iteration: 4 of 31	train_loss: 4.1996
# Iteration: 6 of 31	train_loss: 4.2467
# Iteration: 8 of 31	train_loss: 4.1616
# Iteration: 10 of 31	train_loss: 4.0742
# Iteration: 12 of 31	train_loss: 4.2925
# Iteration: 14 of 31	train_loss: 4.3697
# Iteration: 16 of 31	train_loss: 4.3750
# Iteration: 18 of 31	train_loss: 4.4045
# Iteration: 20 of 31	train_loss: 3.9750
# Iteration: 22 of 31	train_loss: 4.3685
# Iteration: 24 of 31	train_loss: 4.3584
# Iteration: 26 of 31	train_loss: 4.2831
# Iteration: 28 of 31	train_loss: 4.4024
# Iteration: 30 of 31	train_loss: 4.5772
# Iteration: 31 of 31	train_loss: 4.3817
# Average Score for this Epoch: 4.275757789611816
# --- new best score ---
#
#
# -------------------- Epoch 56 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.1500
# Iteration: 2 of 31	train_loss: 4.4510
# Iteration: 4 of 31	train_loss: 4.2838
# Iteration: 6 of 31	train_loss: 4.2848
# Iteration: 8 of 31	train_loss: 4.4227
# Iteration: 10 of 31	train_loss: 4.2181
# Iteration: 12 of 31	train_loss: 3.9022
# Iteration: 14 of 31	train_loss: 4.4850
# Iteration: 16 of 31	train_loss: 4.3330
# Iteration: 18 of 31	train_loss: 4.5204
# Iteration: 20 of 31	train_loss: 4.0343
# Iteration: 22 of 31	train_loss: 4.4808
# Iteration: 24 of 31	train_loss: 4.1371
# Iteration: 26 of 31	train_loss: 3.6796
# Iteration: 28 of 31	train_loss: 4.3828
# Iteration: 30 of 31	train_loss: 4.3654
# Iteration: 31 of 31	train_loss: 4.0933
# Average Score for this Epoch: 4.234991073608398
# --- new best score ---
#
#
# -------------------- Epoch 57 of 250 --------------------
# Iteration: 0 of 31	train_loss: 4.0318
# Iteration: 2 of 31	train_loss: 4.4771
# Iteration: 4 of 31	train_loss: 4.2257
# Iteration: 6 of 31	train_loss: 4.0821
# Iteration: 8 of 31	train_loss: 4.1954
# Iteration: 10 of 31	train_loss: 4.1238
# Iteration: 12 of 31	train_loss: 4.3037
# Iteration: 14 of 31	train_loss: 4.3084
# Iteration: 16 of 31	train_loss: 4.1253
# Iteration: 18 of 31	train_loss: 4.3134
# Iteration: 20 of 31	train_loss: 4.1362
# Iteration: 22 of 31	train_loss: 4.7997
# Iteration: 24 of 31	train_loss: 3.9593
# Iteration: 26 of 31	train_loss: 4.4386
# ...
# Iteration: 14 of 31	train_loss: 2.9032
# Iteration: 16 of 31	train_loss: 2.3090
# Iteration: 18 of 31	train_loss: 2.6143
# Iteration: 20 of 31	train_loss: 3.1404
# Iteration: 22 of 31	train_loss: 3.1222
# Iteration: 24 of 31	train_loss: 2.9038
# Iteration: 26 of 31	train_loss: 2.9083
# Iteration: 28 of 31	train_loss: 2.3768
# Iteration: 30 of 31	train_loss: 3.0623
# Iteration: 31 of 31	train_loss: 3.1443
# Average Score for this Epoch: 2.7691264152526855
# -------------------- Epoch 228 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7911
# Iteration: 2 of 31	train_loss: 2.4763
# Iteration: 4 of 31	train_loss: 2.9774
# Iteration: 6 of 31	train_loss: 2.6044
# Iteration: 8 of 31	train_loss: 3.3792
# Iteration: 10 of 31	train_loss: 2.8654
# Iteration: 12 of 31	train_loss: 2.9782
# Iteration: 14 of 31	train_loss: 2.5521
# Iteration: 16 of 31	train_loss: 2.5755
# Iteration: 18 of 31	train_loss: 2.7904
# Iteration: 20 of 31	train_loss: 2.9733
# Iteration: 22 of 31	train_loss: 2.6554
# Iteration: 24 of 31	train_loss: 2.5024
# Iteration: 26 of 31	train_loss: 3.0096
# Iteration: 28 of 31	train_loss: 3.1495
# Iteration: 30 of 31	train_loss: 2.7585
# Iteration: 31 of 31	train_loss: 2.7677
# Average Score for this Epoch: 2.804993152618408
# -------------------- Epoch 229 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7959
# Iteration: 2 of 31	train_loss: 2.8021
# Iteration: 4 of 31	train_loss: 2.6951
# Iteration: 6 of 31	train_loss: 2.8819
# Iteration: 8 of 31	train_loss: 2.8939
# Iteration: 10 of 31	train_loss: 2.2309
# Iteration: 12 of 31	train_loss: 2.5225
# Iteration: 14 of 31	train_loss: 2.7976
# Iteration: 16 of 31	train_loss: 2.9824
# Iteration: 18 of 31	train_loss: 3.0545
# Iteration: 20 of 31	train_loss: 3.0186
# Iteration: 22 of 31	train_loss: 2.8530
# Iteration: 24 of 31	train_loss: 2.6472
# Iteration: 26 of 31	train_loss: 2.3036
# Iteration: 28 of 31	train_loss: 2.9367
# Iteration: 30 of 31	train_loss: 2.8563
# Iteration: 31 of 31	train_loss: 2.7427
# Average Score for this Epoch: 2.7767558097839355
# -------------------- Epoch 230 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7309
# Iteration: 2 of 31	train_loss: 2.4133
# Iteration: 4 of 31	train_loss: 3.1141
# Iteration: 6 of 31	train_loss: 2.6179
# Iteration: 8 of 31	train_loss: 2.7775
# Iteration: 10 of 31	train_loss: 2.6267
# Iteration: 12 of 31	train_loss: 2.9403
# Iteration: 14 of 31	train_loss: 2.7089
# Iteration: 16 of 31	train_loss: 2.8251
# Iteration: 18 of 31	train_loss: 2.6929
# Iteration: 20 of 31	train_loss: 2.9124
# Iteration: 22 of 31	train_loss: 2.5062
# Iteration: 24 of 31	train_loss: 2.6706
# Iteration: 26 of 31	train_loss: 2.8003
# Iteration: 28 of 31	train_loss: 2.8104
# Iteration: 30 of 31	train_loss: 2.7103
# Iteration: 31 of 31	train_loss: 2.7596
# Average Score for this Epoch: 2.749394655227661
# --- new best score ---
#
#
# -------------------- Epoch 231 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.6733
# Iteration: 2 of 31	train_loss: 2.6976
# Iteration: 4 of 31	train_loss: 2.6907
# Iteration: 6 of 31	train_loss: 2.7995
# Iteration: 8 of 31	train_loss: 2.4915
# Iteration: 10 of 31	train_loss: 2.7152
# Iteration: 12 of 31	train_loss: 2.7249
# Iteration: 14 of 31	train_loss: 2.6452
# Iteration: 16 of 31	train_loss: 2.8637
# Iteration: 18 of 31	train_loss: 2.6030
# Iteration: 20 of 31	train_loss: 2.6665
# Iteration: 22 of 31	train_loss: 2.7911
# Iteration: 24 of 31	train_loss: 2.9467
# Iteration: 26 of 31	train_loss: 2.9548
# Iteration: 28 of 31	train_loss: 2.3713
# Iteration: 30 of 31	train_loss: 2.7406
# Iteration: 31 of 31	train_loss: 2.6192
# Average Score for this Epoch: 2.740388870239258
# --- new best score ---
#
#
# -------------------- Epoch 232 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.9409
# Iteration: 2 of 31	train_loss: 2.6167
# Iteration: 4 of 31	train_loss: 2.7304
# Iteration: 6 of 31	train_loss: 2.8993
# Iteration: 8 of 31	train_loss: 2.7078
# Iteration: 10 of 31	train_loss: 2.8953
# Iteration: 12 of 31	train_loss: 2.8420
# Iteration: 14 of 31	train_loss: 2.5373
# Iteration: 16 of 31	train_loss: 2.4019
# Iteration: 18 of 31	train_loss: 3.1174
# Iteration: 20 of 31	train_loss: 2.5881
# Iteration: 22 of 31	train_loss: 2.7840
# Iteration: 24 of 31	train_loss: 2.8365
# Iteration: 26 of 31	train_loss: 2.8300
# Iteration: 28 of 31	train_loss: 2.9043
# Iteration: 30 of 31	train_loss: 2.3284
# Iteration: 31 of 31	train_loss: 2.9442
# Average Score for this Epoch: 2.745922088623047
# -------------------- Epoch 233 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.2044
# Iteration: 2 of 31	train_loss: 2.5765
# Iteration: 4 of 31	train_loss: 2.8531
# Iteration: 6 of 31	train_loss: 2.6438
# Iteration: 8 of 31	train_loss: 2.5411
# Iteration: 10 of 31	train_loss: 2.7538
# Iteration: 12 of 31	train_loss: 2.7455
# Iteration: 14 of 31	train_loss: 2.4336
# Iteration: 16 of 31	train_loss: 2.4212
# Iteration: 18 of 31	train_loss: 2.6257
# Iteration: 20 of 31	train_loss: 2.8235
# Iteration: 22 of 31	train_loss: 2.7232
# Iteration: 24 of 31	train_loss: 2.8091
# Iteration: 26 of 31	train_loss: 3.1090
# Iteration: 28 of 31	train_loss: 2.8492
# Iteration: 30 of 31	train_loss: 2.9327
# Iteration: 31 of 31	train_loss: 2.1556
# Average Score for this Epoch: 2.7268612384796143
# --- new best score ---
#
#
# -------------------- Epoch 234 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.8330
# Iteration: 2 of 31	train_loss: 2.2371
# Iteration: 4 of 31	train_loss: 2.6501
# Iteration: 6 of 31	train_loss: 2.5689
# Iteration: 8 of 31	train_loss: 2.8099
# Iteration: 10 of 31	train_loss: 2.4716
# Iteration: 12 of 31	train_loss: 2.7447
# Iteration: 14 of 31	train_loss: 3.1605
# Iteration: 16 of 31	train_loss: 2.5975
# Iteration: 18 of 31	train_loss: 2.8222
# Iteration: 20 of 31	train_loss: 2.7435
# Iteration: 22 of 31	train_loss: 2.7776
# Iteration: 24 of 31	train_loss: 2.7058
# Iteration: 26 of 31	train_loss: 2.8862
# Iteration: 28 of 31	train_loss: 2.5590
# Iteration: 30 of 31	train_loss: 2.9095
# Iteration: 31 of 31	train_loss: 2.7217
# Average Score for this Epoch: 2.731243848800659
# -------------------- Epoch 235 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.5705
# Iteration: 2 of 31	train_loss: 3.0838
# Iteration: 4 of 31	train_loss: 2.6184
# Iteration: 6 of 31	train_loss: 2.6105
# Iteration: 8 of 31	train_loss: 3.1000
# Iteration: 10 of 31	train_loss: 2.4319
# Iteration: 12 of 31	train_loss: 2.9977
# Iteration: 14 of 31	train_loss: 2.6790
# Iteration: 16 of 31	train_loss: 2.6724
# Iteration: 18 of 31	train_loss: 2.4856
# Iteration: 20 of 31	train_loss: 2.7007
# Iteration: 22 of 31	train_loss: 2.9746
# Iteration: 24 of 31	train_loss: 2.3597
# Iteration: 26 of 31	train_loss: 2.6678
# Iteration: 28 of 31	train_loss: 2.9425
# Iteration: 30 of 31	train_loss: 2.3676
# Iteration: 31 of 31	train_loss: 2.5443
# Average Score for this Epoch: 2.7088370323181152
# --- new best score ---
#
#
# -------------------- Epoch 236 of 250 --------------------
# Iteration: 0 of 31	train_loss: 3.0924
# Iteration: 2 of 31	train_loss: 2.5980
# Iteration: 4 of 31	train_loss: 2.7963
# Iteration: 6 of 31	train_loss: 2.1713
# Iteration: 8 of 31	train_loss: 2.8248
# Iteration: 10 of 31	train_loss: 2.5640
# Iteration: 12 of 31	train_loss: 2.0492
# Iteration: 14 of 31	train_loss: 2.7195
# Iteration: 16 of 31	train_loss: 2.5359
# Iteration: 18 of 31	train_loss: 2.9940
# Iteration: 20 of 31	train_loss: 2.5569
# Iteration: 22 of 31	train_loss: 2.8703
# Iteration: 24 of 31	train_loss: 2.6079
# Iteration: 26 of 31	train_loss: 2.6390
# Iteration: 28 of 31	train_loss: 2.7134
# Iteration: 30 of 31	train_loss: 3.0596
# Iteration: 31 of 31	train_loss: 3.0758
# Average Score for this Epoch: 2.713318347930908
# -------------------- Epoch 237 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.2004
# Iteration: 2 of 31	train_loss: 2.6026
# Iteration: 4 of 31	train_loss: 2.8806
# Iteration: 6 of 31	train_loss: 2.5721
# Iteration: 8 of 31	train_loss: 2.7763
# Iteration: 10 of 31	train_loss: 2.4931
# Iteration: 12 of 31	train_loss: 2.9059
# Iteration: 14 of 31	train_loss: 2.5528
# Iteration: 16 of 31	train_loss: 3.0031
# Iteration: 18 of 31	train_loss: 2.4353
# Iteration: 20 of 31	train_loss: 2.7461
# Iteration: 22 of 31	train_loss: 2.7652
# Iteration: 24 of 31	train_loss: 2.6119
# Iteration: 26 of 31	train_loss: 3.0145
# Iteration: 28 of 31	train_loss: 2.7915
# Iteration: 30 of 31	train_loss: 2.4244
# Iteration: 31 of 31	train_loss: 2.3269
# Average Score for this Epoch: 2.698566436767578
# --- new best score ---
#
#
# -------------------- Epoch 238 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7188
# Iteration: 2 of 31	train_loss: 2.9729
# Iteration: 4 of 31	train_loss: 2.7262
# Iteration: 6 of 31	train_loss: 2.6686
# Iteration: 8 of 31	train_loss: 2.4059
# Iteration: 10 of 31	train_loss: 2.5810
# Iteration: 12 of 31	train_loss: 2.7285
# Iteration: 14 of 31	train_loss: 2.8760
# Iteration: 16 of 31	train_loss: 2.6848
# Iteration: 18 of 31	train_loss: 3.0185
# Iteration: 20 of 31	train_loss: 2.4801
# Iteration: 22 of 31	train_loss: 2.3196
# Iteration: 24 of 31	train_loss: 2.5233
# Iteration: 26 of 31	train_loss: 2.9791
# Iteration: 28 of 31	train_loss: 3.0662
# Iteration: 30 of 31	train_loss: 2.9093
# Iteration: 31 of 31	train_loss: 2.7772
# Average Score for this Epoch: 2.710735321044922
# -------------------- Epoch 239 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7305
# Iteration: 2 of 31	train_loss: 2.5740
# Iteration: 4 of 31	train_loss: 2.7395
# Iteration: 6 of 31	train_loss: 2.5731
# Iteration: 8 of 31	train_loss: 2.4876
# Iteration: 10 of 31	train_loss: 2.6296
# Iteration: 12 of 31	train_loss: 2.8597
# Iteration: 14 of 31	train_loss: 2.6948
# Iteration: 16 of 31	train_loss: 2.6965
# Iteration: 18 of 31	train_loss: 2.9556
# Iteration: 20 of 31	train_loss: 2.7520
# Iteration: 22 of 31	train_loss: 2.4501
# Iteration: 24 of 31	train_loss: 2.7866
# Iteration: 26 of 31	train_loss: 2.7246
# Iteration: 28 of 31	train_loss: 2.7714
# Iteration: 30 of 31	train_loss: 2.7225
# Iteration: 31 of 31	train_loss: 2.7048
# Average Score for this Epoch: 2.709871768951416
# -------------------- Epoch 240 of 250 --------------------
# Iteration: 0 of 31	train_loss: 3.0919
# Iteration: 2 of 31	train_loss: 2.9803
# Iteration: 4 of 31	train_loss: 2.9103
# Iteration: 6 of 31	train_loss: 2.3631
# Iteration: 8 of 31	train_loss: 2.6892
# Iteration: 10 of 31	train_loss: 2.5151
# Iteration: 12 of 31	train_loss: 2.5666
# Iteration: 14 of 31	train_loss: 2.7186
# Iteration: 16 of 31	train_loss: 2.5405
# Iteration: 18 of 31	train_loss: 2.7360
# Iteration: 20 of 31	train_loss: 2.9804
# Iteration: 22 of 31	train_loss: 2.6832
# Iteration: 24 of 31	train_loss: 3.1431
# Iteration: 26 of 31	train_loss: 2.8267
# Iteration: 28 of 31	train_loss: 2.8992
# Iteration: 30 of 31	train_loss: 2.7134
# Iteration: 31 of 31	train_loss: 3.0314
# Average Score for this Epoch: 2.7044711112976074
# -------------------- Epoch 241 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.8771
# Iteration: 2 of 31	train_loss: 2.5928
# Iteration: 4 of 31	train_loss: 2.4774
# Iteration: 6 of 31	train_loss: 2.9210
# Iteration: 8 of 31	train_loss: 2.7977
# Iteration: 10 of 31	train_loss: 2.8157
# Iteration: 12 of 31	train_loss: 3.1627
# Iteration: 14 of 31	train_loss: 2.9742
# Iteration: 16 of 31	train_loss: 2.5932
# Iteration: 18 of 31	train_loss: 2.5644
# Iteration: 20 of 31	train_loss: 3.0491
# Iteration: 22 of 31	train_loss: 2.6307
# Iteration: 24 of 31	train_loss: 2.8262
# Iteration: 26 of 31	train_loss: 2.9757
# Iteration: 28 of 31	train_loss: 2.6388
# Iteration: 30 of 31	train_loss: 2.5737
# Iteration: 31 of 31	train_loss: 2.9645
# Average Score for this Epoch: 2.6978068351745605
# --- new best score ---
#
#
# -------------------- Epoch 242 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.4355
# Iteration: 2 of 31	train_loss: 2.5139
# Iteration: 4 of 31	train_loss: 2.9852
# Iteration: 6 of 31	train_loss: 2.4856
# Iteration: 8 of 31	train_loss: 2.8718
# Iteration: 10 of 31	train_loss: 2.6377
# Iteration: 12 of 31	train_loss: 2.6244
# Iteration: 14 of 31	train_loss: 2.5087
# Iteration: 16 of 31	train_loss: 2.5441
# Iteration: 18 of 31	train_loss: 2.5695
# Iteration: 20 of 31	train_loss: 2.5727
# Iteration: 22 of 31	train_loss: 2.7238
# Iteration: 24 of 31	train_loss: 2.3710
# Iteration: 26 of 31	train_loss: 2.7780
# Iteration: 28 of 31	train_loss: 3.0437
# Iteration: 30 of 31	train_loss: 2.7071
# Iteration: 31 of 31	train_loss: 2.2997
# Average Score for this Epoch: 2.6681158542633057
# --- new best score ---
#
#
# -------------------- Epoch 243 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7705
# Iteration: 2 of 31	train_loss: 2.5768
# Iteration: 4 of 31	train_loss: 2.7455
# Iteration: 6 of 31	train_loss: 2.5698
# Iteration: 8 of 31	train_loss: 2.5200
# Iteration: 10 of 31	train_loss: 2.8639
# Iteration: 12 of 31	train_loss: 2.6756
# Iteration: 14 of 31	train_loss: 2.6542
# Iteration: 16 of 31	train_loss: 2.5710
# Iteration: 18 of 31	train_loss: 2.6028
# Iteration: 20 of 31	train_loss: 2.7759
# Iteration: 22 of 31	train_loss: 2.5677
# Iteration: 24 of 31	train_loss: 2.7738
# Iteration: 26 of 31	train_loss: 2.8022
# Iteration: 28 of 31	train_loss: 2.9569
# Iteration: 30 of 31	train_loss: 2.8267
# Iteration: 31 of 31	train_loss: 2.6605
# Average Score for this Epoch: 2.689074993133545
# -------------------- Epoch 244 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7422
# Iteration: 2 of 31	train_loss: 2.5288
# Iteration: 4 of 31	train_loss: 2.6213
# Iteration: 6 of 31	train_loss: 2.6660
# Iteration: 8 of 31	train_loss: 2.5211
# Iteration: 10 of 31	train_loss: 2.3365
# Iteration: 12 of 31	train_loss: 2.8045
# Iteration: 14 of 31	train_loss: 2.5534
# Iteration: 16 of 31	train_loss: 2.7248
# Iteration: 18 of 31	train_loss: 2.4687
# Iteration: 20 of 31	train_loss: 2.7083
# Iteration: 22 of 31	train_loss: 2.9635
# Iteration: 24 of 31	train_loss: 2.5684
# Iteration: 26 of 31	train_loss: 2.9221
# Iteration: 28 of 31	train_loss: 2.8094
# Iteration: 30 of 31	train_loss: 2.5682
# Iteration: 31 of 31	train_loss: 2.7192
# Average Score for this Epoch: 2.685452938079834
# -------------------- Epoch 245 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.6709
# Iteration: 2 of 31	train_loss: 2.7459
# Iteration: 4 of 31	train_loss: 2.6286
# Iteration: 6 of 31	train_loss: 2.7874
# Iteration: 8 of 31	train_loss: 2.8505
# Iteration: 10 of 31	train_loss: 2.4088
# Iteration: 12 of 31	train_loss: 2.5960
# Iteration: 14 of 31	train_loss: 2.5956
# Iteration: 16 of 31	train_loss: 2.6410
# Iteration: 18 of 31	train_loss: 2.6910
# Iteration: 20 of 31	train_loss: 2.5318
# Iteration: 22 of 31	train_loss: 2.8549
# Iteration: 24 of 31	train_loss: 2.7789
# Iteration: 26 of 31	train_loss: 2.5835
# Iteration: 28 of 31	train_loss: 2.9597
# Iteration: 30 of 31	train_loss: 2.9593
# Iteration: 31 of 31	train_loss: 2.7209
# Average Score for this Epoch: 2.7037763595581055
# -------------------- Epoch 246 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.7467
# Iteration: 2 of 31	train_loss: 2.5071
# Iteration: 4 of 31	train_loss: 2.4689
# Iteration: 6 of 31	train_loss: 2.8203
# Iteration: 8 of 31	train_loss: 2.7253
# Iteration: 10 of 31	train_loss: 2.5065
# Iteration: 12 of 31	train_loss: 2.6285
# Iteration: 14 of 31	train_loss: 2.3941
# Iteration: 16 of 31	train_loss: 2.6895
# Iteration: 18 of 31	train_loss: 2.7619
# Iteration: 20 of 31	train_loss: 2.8799
# Iteration: 22 of 31	train_loss: 2.9082
# Iteration: 24 of 31	train_loss: 2.9545
# Iteration: 26 of 31	train_loss: 2.7298
# Iteration: 28 of 31	train_loss: 2.6510
# Iteration: 30 of 31	train_loss: 2.9055
# Iteration: 31 of 31	train_loss: 2.7762
# Average Score for this Epoch: 2.6864571571350098
# -------------------- Epoch 247 of 250 --------------------
# Iteration: 0 of 31	train_loss: 2.3453
# Iteration: 2 of 31	train_loss: 2.4686
# Iteration: 4 of 31	train_loss: 2.5230
# Iteration: 6 of 31	train_loss: 2.7185
# Iteration: 8 of 31	train_loss: 2.8422
# Iteration: 10 of 31	train_loss: 2.8461
# Iteration: 12 of 31	train_loss: 2.6037
# Iteration: 14 of 31	train_loss: 2.6145
# Iteration: 16 of 31	train_loss: 2.4265
# Iteration: 18 of 31	train_loss: 2.4529
# Iteration: 20 of 31	train_loss: 2.6772
# Iteration: 22 of 31	train_loss: 2.8388
# Iteration: 24 of 31	train_loss: 2.9142
# Iteration: 26 of 31	train_loss: 3.0487
# Iteration: 28 of 31	train_loss: 2.8259
# Iteration: 30 of 31	train_loss: 2.7273
# Iteration: 31 of 31	train_loss: 2.3387
# Average Score for this Epoch: 2.6703155040740967
# - early stopping 5 epochs without improvement

# %%
_de_inds, _de_unknowns = nmt_data_utils.convert_to_inds(de_preprocessed_clean, de_word2ind, sos = True,  eos = True)

# %%
# the inference model does not necessaryly need to get input batches. we can just give it. the whole input
# data, but the the batchsize has to be specified as the lenght of the input data.
nmt_model_utils.reset_graph()

nmt = NMT_Model.NMT(en_word2ind,
                    en_ind2word,
                    de_word2ind,
                    de_ind2word,
                    './models/local_one/my_model',
                    'INFER',
                    num_layers_encoder = num_layers_encoder,
                    num_layers_decoder = num_layers_decoder,
                    batch_size = len(en_inds[:50]),
                    keep_probability = 1.0,
                    learning_rate = 0.0,
                    beam_width = 0,
                    rnn_size_encoder = rnn_size_encoder,
                    rnn_size_decoder = rnn_size_decoder)

nmt.build_graph()
preds = nmt.infer(en_inds[:50], restore_path =  './models/local_one/my_model', targets = _de_inds[:50])
# Out:
# Graph built.
# Restore graph from  ./models/local_one/my_model
# INFO:tensorflow:Restoring parameters from ./models/local_one/my_model

# %%
# show some of the created translations
# Note: the way bleu score is probably not the perfect way to do it
nmt_model_utils.sample_results(preds, en_ind2word, de_ind2word, en_word2ind, de_word2ind, _de_inds[:50], en_inds[:50])
# Out:
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# wouldn ’ t you know it ?
#
# Actual translation:
# und es kam , wie es kommen musste .
#
# Created translation:
# was wie kam bis sie sie mit musste , allgemeine vorgibt
#
# Bleu-score: 1.4147351699132998e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# since then , the index has climbed above 10,000 .
#
# Actual translation:
# seit damals ist er auf über 10.000 punkte gestiegen .
#
# Created translation:
# die damals wird es es schon 10.000 punkte gestiegen . 160 ,
#
# Bleu-score: 0.22416933501922293
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# they departed pledging to revive europe 's growth .
#
# Actual translation:
# mit der zusicherung , das wachstum in europa wieder zu beleben , gingen sie auseinander .
#
# Created translation:
# der eine zusicherung , , zahlreichen verlieren dazu , zu beleben , , , auseinander riesige ,
#
# Bleu-score: 3.271341557643298e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# we 've heard that empty promise before .
#
# Actual translation:
# dieses leere versprechen haben wir schon einmal gehört .
#
# Created translation:
# gerade leere versprechen wir wir schon einmal gehört . , ,
#
# Bleu-score: 0.40352786374639904
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# many europeans are sick of british vetoes .
#
# Actual translation:
# viele europäer sind die britischen vetos leid .
#
# Created translation:
# viele ziel sind papier britischen vetos leid . , ,
#
# Bleu-score: 0.2907153684841096
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# precedents exist for this .
#
# Actual translation:
# hierfür existieren beispiele .
#
# Created translation:
# hierfür existieren beispiele . , experimente
#
# Bleu-score: 0.5081327481546147
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# nato has been flexible since its inception .
#
# Actual translation:
# die nato ist von anfang an flexibel gewesen .
#
# Created translation:
# die nato ist ist anfang krieg flexibel gewesen . ping
#
# Bleu-score: 6.44985558187996e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# these precedents can be extended .
#
# Actual translation:
# diese beispielsfälle kann man erweitern .
#
# Created translation:
# diese beispielsfälle kann sich erweitern . , ,
#
# Bleu-score: 5.614021910443866e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# i am not talking about a two‑speed europe .
#
# Actual translation:
# ich meine kein europa mit zwei unterschiedlichen geschwindigkeiten .
#
# Created translation:
# ich meine keine ein ein ein unterschiedlichen geschwindigkeiten . , ,
#
# Bleu-score: 4.284993070788676e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but i do n't want to block their way .
#
# Actual translation:
# aber ich möchte ihnen nicht im wege stehen .
#
# Created translation:
# doch ich möchte ihnen der wege wege ? . , ,
#
# Bleu-score: 3.8719283242189536e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# elected parliaments do not own our liberties .
#
# Actual translation:
# gewählte parlamente besitzen unsere freiheiten nicht .
#
# Created translation:
# gewählte parlamente besitzen unsere freiheiten nicht . , us-außenministerin
#
# Bleu-score: 0.7259795291154771
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but the big question remains : how ?
#
# Actual translation:
# aber eine große frage bleibt : wie ?
#
# Created translation:
# doch beispiel große bleibt bleibt : diese ? , ,
#
# Bleu-score: 6.8489908526642754e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the need for immediate action is clear .
#
# Actual translation:
# dass sofort gehandelt werden muss , ist eindeutig .
#
# Created translation:
# die sofort gehandelt haben aus regel etwas eindeutig . 160 ,
#
# Bleu-score: 8.190757052088229e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# the new year is looking grim .
#
# Actual translation:
# es sieht finster aus für das neue jahr .
#
# Created translation:
# man sieht finster aus sich eine neue . . , ,
#
# Bleu-score: 3.8719283242189536e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# france is flat-lining ( as is britain ) .
#
# Actual translation:
# frankreich stagniert ( und großbritannien auch ) .
#
# Created translation:
# frankreich stagniert ( großbritannien großbritannien wurden ) . # 160
#
# Bleu-score: 4.856474469839072e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# italy and spain have sunk into deep recession .
#
# Actual translation:
# italien und spanien sind tief in die rezession abgerutscht .
#
# Created translation:
# italien und spanien sind tief tief in rezession abgerutscht .
#
# Bleu-score: 0.5623413251903491
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# greece is in its fifth year of a slump .
#
# Actual translation:
# griechenland erlebt sein fünftes jahr des abschwungs .
#
# Created translation:
# griechenland erlebt der fünftes logik des abschwungs . , ,
#
# Bleu-score: 4.856474469839072e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a big new push for growth is therefore vital .
#
# Actual translation:
# ein neuer , starker wachstumsanschub ist daher unverzichtbar .
#
# Created translation:
# ein neuer sind starker wachstumsanschub wachstumsanschub daher unverzichtbar . nbsp nbsp
#
# Bleu-score: 5.008605395783359e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# boosting exports is also essential .
#
# Actual translation:
# eine ankurbelung des exports ist ebenfalls von zentraler bedeutung .
#
# Created translation:
# eine ankurbelung mächtiger exports ist ebenfalls zentraler zentraler . . riesiger riesiger
#
# Bleu-score: 4.337579510280189e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# that brings us to fiscal policy .
#
# Actual translation:
# dies bringt uns zur fiskalpolitik .
#
# Created translation:
# dies bringt nicht die fiskalpolitik . signalisieren signalisieren
#
# Bleu-score: 9.170599044431425e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# indeed , such hopes were misplaced .
#
# Actual translation:
# tatsächlich sind solche hoffnungen verloren gegangen .
#
# Created translation:
# tatsächlich sind solche hoffnungen verloren gegangen . und .
#
# Bleu-score: 0.7259795291154771
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# in fact , iraqi society is more complex than this .
#
# Actual translation:
# tatsächlich ist die irakische gesellschaft komplexer als dies .
#
# Created translation:
# tatsächlich ist sich irakische gesellschaft komplexer komplexer dies . , ,
#
# Bleu-score: 5.008605395783359e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# we are doing our part in terms of burden-sharing .
#
# Actual translation:
# wir leisten unseren teil , was die übernahme der lasten angeht .
#
# Created translation:
# wir leisten unseren sie , , manche übernahme eine lasten angeht . ,
#
# Bleu-score: 5.367249453774744e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# sensible europeans understand that .
#
# Actual translation:
# vernünftige europäer verstehen das .
#
# Created translation:
# vernünftige europäer verstehen alles . , ,
#
# Bleu-score: 5.395774370246974e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# to be sure , some of our neighbors are difficult .
#
# Actual translation:
# sicher , einige unserer nachbarn sind schwierig .
#
# Created translation:
# sicher also einige unserer nachbarn schwierig schwierig . , peking
#
# Bleu-score: 5.047284757449962e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# progress on disinflation is similarly impressive .
#
# Actual translation:
# der fortschritt hinsichtlich des inflationsrückgangs ist ähnlich beeindruckend .
#
# Created translation:
# der fortschritt hinsichtlich inflationsrückgangs inflationsrückgangs , ähnlich beeindruckend . ping
#
# Bleu-score: 6.44985558187996e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# in better shape , but not alone .
#
# Actual translation:
# in besserer verfassung , aber nicht allein .
#
# Created translation:
# in besserer verfassung nicht , nicht allein . , steuereinnahmen
#
# Bleu-score: 6.44985558187996e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# when the rich get less rich , the poor get poorer .
#
# Actual translation:
# wenn die reichen weniger reich werden , werden die armen ärmer .
#
# Created translation:
# aber ist reichen der reich reich reich und anderen armen ärmer . , ,
#
# Bleu-score: 3.3252037442622604e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# it all came about in a number of ways .
#
# Actual translation:
# verschiedene wege führten mich dorthin .
#
# Created translation:
# verschiedene wege führten verschiedene dorthin . , ,
#
# Bleu-score: 5.614021910443866e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# then i got distracted for about 40 years .
#
# Actual translation:
# anschließend war ich ungefähr 40 jahre lang anderweitig beschäftigt .
#
# Created translation:
# anschließend weiß präsident er 40 40 lang anderweitig beschäftigt .
#
# Bleu-score: 0.2907153684841096
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# not all are happy about this american notion .
#
# Actual translation:
# nicht alle sind mit dieser amerikanischen vorstellung glücklich .
#
# Created translation:
# nicht ein die , der amerikanischen vorstellung glücklich . , ,
#
# Bleu-score: 0.24808415001701817
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# this is the beginning of a new authoritarianism .
#
# Actual translation:
# dies ist der anfang eines neuen autoritarismus .
#
# Created translation:
# dies ist der anfang eines neuen autoritarismus . , ,
#
# Bleu-score: 0.7598356856515925
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# a diffuse anxiety is gaining ground .
#
# Actual translation:
# eine diffuse besorgnis greift um sich .
#
# Created translation:
# eine diffuse besorgnis greift im ist . einfach einfach
#
# Bleu-score: 0.3155984539112945
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but this , of course , is untrue .
#
# Actual translation:
# das entspricht natürlich nicht der wahrheit .
#
# Created translation:
# das entspricht natürlich natürlich nicht wahrheit . , ,
#
# Bleu-score: 5.705336763108155e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# could the answer be a bit of both ?
#
# Actual translation:
# oder könnte die antwort lauten : ein bisschen von beidem ?
#
# Created translation:
# und was antwort darauf lauten , nicht bisschen beidem beidem sensibilisiert sensibilisiert
#
# Bleu-score: 1.384292958842266e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# china is ; you are not . ”
#
# Actual translation:
# china ist es ; ihr nicht. “
#
# Created translation:
# die ist ganz ; , nicht. handeln sinne abgestimmt
#
# Bleu-score: 1.384292958842266e-231
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# what do you want back ?
#
# Actual translation:
# was wollt ihr zurück ?
#
# Created translation:
# was wollt kam zurück ? ? ?
#
# Bleu-score: 9.85444998995587e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# these principles are clear .
#
# Actual translation:
# diese prinzipien sind klar .
#
# Created translation:
# diese prinzipien ist klar . haushaltsüberschuss ,
#
# Bleu-score: 9.85444998995587e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# in the short term , time may be on russia ’ s side .
#
# Actual translation:
# kurzfristig betrachtet , mag die zeit aufseiten russlands sein .
#
# Created translation:
# kurzfristig betrachtet eine mag mag nicht aufseiten russlands sein .
#
# Bleu-score: 0.32466791547509893
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# both figures are , again , the lowest in the eu .
#
# Actual translation:
# beide werte sind ebenfalls die niedrigsten in der ganzen eu .
#
# Created translation:
# beide werte sind ebenfalls niedrigsten niedrigsten eu der ganzen eu . , ,
#
# Bleu-score: 0.39832871551569504
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but the agreement has three major flaws .
#
# Actual translation:
# doch die einigung hat drei wichtige fehler .
#
# Created translation:
# die die einigung ist drei wichtige fehler . steuereinnahmen ,
#
# Bleu-score: 0.31239399369202553
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# what 's the ordinary european to think ?
#
# Actual translation:
# was soll der normale europäer davon halten ?
#
# Created translation:
# was soll der normale europäer davon halten . ,
#
# Bleu-score: 0.7259795291154771
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but what is the right level ?
#
# Actual translation:
# aber welche ebene ist die richtige ?
#
# Created translation:
# aber was ebene ist die richtige ? , ,
#
# Bleu-score: 0.4671379777282001
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# much the same is true in europe .
#
# Actual translation:
# in europa ist es nicht viel anders .
#
# Created translation:
# ein ist natürlich für für schwer anders . , ,
#
# Bleu-score: 6.373704167435469e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# so `` no centralization without representation . ''
#
# Actual translation:
# also `` keine zentralisierung ohne repräsentation '' .
#
# Created translation:
# wahrscheinlich `` von zentralisierung ohne repräsentation '' . , ,
#
# Bleu-score: 0.4111336169005197
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# activities of eu institutions ( percent of total )
#
# Actual translation:
# aufteilung nach tätigkeitsbereichen der europäischen union
#
# Created translation:
# aufteilung nach tätigkeitsbereichen europäischen europäischen union gerechtfertigt gerechtfertigt
#
# Bleu-score: 5.614021910443866e-78
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# europe faces an historic opportunity .
#
# Actual translation:
# europa eröffnet sich eine historische gelegenheit .
#
# Created translation:
# diese eröffnet eine eine historische gelegenheit . gefällt .
#
# Bleu-score: 0.3155984539112945
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# but this scenario failed to materialize .
#
# Actual translation:
# doch hat sich dieses szenario nicht bewahrheitet .
#
# Created translation:
# doch gibt sich bleibt szenario nicht bewahrheitet . , staatseigenen
#
# Bleu-score: 0.2907153684841096
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# this means two things .
#
# Actual translation:
# daraus ergeben sich zwei dinge .
#
# Created translation:
# dies ergeben nicht nicht dinge . , ,
#
# Bleu-score: 7.176381577237209e-155
#
#
#
#  ----------------------------------------------------------------------------------------------------
# Actual Text:
# officially , this has not yet been acknowledged .
#
# Actual translation:
# offiziell wurde dies noch nicht anerkannt .
#
# Created translation:
# offiziell ist zu nicht nicht anerkannt . , выдало
#
# Bleu-score: 4.335118471269586e-78
#
#
#
# Total Bleu Score: 0.1660206985542417
# C:\Users\ASUS\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ASUS\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\ASUS\Anaconda3\lib\site-packages\nltk\translate\bleu_score.py:523: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
